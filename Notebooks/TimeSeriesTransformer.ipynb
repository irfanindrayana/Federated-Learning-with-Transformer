# %% [markdown]
# # **Importing Modules and Libraries**

# %%
# %pip install transformers scikit-learn matplotlib pandas
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import pickle
import os

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

import re

# %%
import os
#os.environ['AMD_SERIALIZE_KERNEL'] ='3'
#os.environ['TORCH_USE_HIP_DSA'] ='1'
#os.environ['HIP_VISIBLE_DEVICES']='0'
#os.environ['PYTORCH_ROCM_ARCH'] = '"gfx1031"'
os.environ['HSA_OVERRIDE_GFX_VERSION'] ='10.3.0'

import torch

# Checking if ROCm is available
if torch.backends.mps.is_available():
    print("ROCm backend is available")

# This will list the ROCm-supported devices
if torch.cuda.is_available():
    print(f"Available AMD GPU: {torch.cuda.get_device_name(0)}")
else:
    print("No ROCm-compatible GPU detected")
# Out:
# Available AMD GPU: Tesla T4

# %% [markdown]
# # **Importing Datasets**

# %%
file_name = 'obfuscated-malware-memory-2022-cic'

if not os.path.exists(file_name):
    print(f"{file_name} does not exist. Downloading now...")
    # !wget https://www.kaggle.com/api/v1/datasets/download/luccagodoy/obfuscated-malware-memory-2022-cic -O {file_name}
else:
    print(f"{file_name} already exists. Skipping download.")

if not os.path.exists("Obfuscated-MalMem2022.csv"):
    print("Unzipping the file...")
    # !unzip {file_name}
else:
    print("File already unzipped. Skipping unzip.")
# Out:
# obfuscated-malware-memory-2022-cic does not exist. Downloading now...
# --2026-01-14 12:37:34--  https://www.kaggle.com/api/v1/datasets/download/luccagodoy/obfuscated-malware-memory-2022-cic
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com:443/kaggle-data-sets/2329998/3924163/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260114%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260114T122142Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# --2026-01-14 12:37:34--  https://storage.googleapis.com/kaggle-data-sets/2329998/3924163/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260114%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260114T122142Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.98.207, 74.125.135.207, 74.125.142.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.98.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4025038 (3.8M) [application/zip]
# Saving to: ‘obfuscated-malware-memory-2022-cic’
#
# obfuscated-malware- 100%[===================>]   3.84M  --.-KB/s    in 0.02s
#
# 2026-01-14 12:37:34 (253 MB/s) - ‘obfuscated-malware-memory-2022-cic’ saved [4025038/4025038]
#
# Unzipping the file...
# Archive:  obfuscated-malware-memory-2022-cic
#   inflating: Obfuscated-MalMem2022.csv

# %%
data = pd.read_csv('Obfuscated-MalMem2022.csv')

# %% [markdown]
# #**Data Cleaning**

# %%
data.head(n=5)
# Out:
#   Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# 0   Benign            45            17           10.555556
# 1   Benign            47            19           11.531915
# 2   Benign            40            14           14.725000
# 3   Benign            32            13           13.500000
# 4   Benign            42            16           11.452381
#
#    pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# 0                   0           202.844444           1694
# 1                   0           242.234043           2074
# 2                   0           288.225000           1932
# 3                   0           264.281250           1445
# 4                   0           281.333333           2067
#
#    dlllist.avg_dlls_per_proc  handles.nhandles  handles.avg_handles_per_proc  \
# 0                  38.500000              9129                    212.302326
# 1                  44.127660             11385                    242.234043
# 2                  48.300000             11529                    288.225000
# 3                  45.156250              8457                    264.281250
# 4                  49.214286             11816                    281.333333
#
#    ...  svcscan.kernel_drivers  svcscan.fs_drivers  svcscan.process_services  \
# 0  ...                     221                  26                        24
# 1  ...                     222                  26                        24
# 2  ...                     222                  26                        27
# 3  ...                     222                  26                        27
# 4  ...                     222                  26                        24
#
#    svcscan.shared_process_services  svcscan.interactive_process_services  \
# 0                              116                                     0
# 1                              118                                     0
# 2                              118                                     0
# 3                              118                                     0
# 4                              118                                     0
#
#    svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# 0              121                    87                     0
# 1              122                    87                     0
# 2              120                    88                     0
# 3              120                    88                     0
# 4              124                    87                     0
#
#    callbacks.ngeneric   Class
# 0                   8  Benign
# 1                   8  Benign
# 2                   8  Benign
# 3                   8  Benign
# 4                   8  Benign
#
# [5 rows x 57 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58596 entries, 0 to 58595
# Data columns (total 57 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Category                                58596 non-null  object
#  1   pslist.nproc                            58596 non-null  int64
#  2   pslist.nppid                            58596 non-null  int64
#  3   pslist.avg_threads                      58596 non-null  float64
#  4   pslist.nprocs64bit                      58596 non-null  int64
#  5   pslist.avg_handlers                     58596 non-null  float64
#  6   dlllist.ndlls                           58596 non-null  int64
#  7   dlllist.avg_dlls_per_proc               58596 non-null  float64
#  8   handles.nhandles                        58596 non-null  int64
#  9   handles.avg_handles_per_proc            58596 non-null  float64
#  10  handles.nport                           58596 non-null  int64
#  11  handles.nfile                           58596 non-null  int64
#  12  handles.nevent                          58596 non-null  int64
#  13  handles.ndesktop                        58596 non-null  int64
#  14  handles.nkey                            58596 non-null  int64
#  15  handles.nthread                         58596 non-null  int64
#  16  handles.ndirectory                      58596 non-null  int64
#  17  handles.nsemaphore                      58596 non-null  int64
#  18  handles.ntimer                          58596 non-null  int64
#  19  handles.nsection                        58596 non-null  int64
#  20  handles.nmutant                         58596 non-null  int64
#  21  ldrmodules.not_in_load                  58596 non-null  int64
#  22  ldrmodules.not_in_init                  58596 non-null  int64
#  23  ldrmodules.not_in_mem                   58596 non-null  int64
#  24  ldrmodules.not_in_load_avg              58596 non-null  float64
#  25  ldrmodules.not_in_init_avg              58596 non-null  float64
#  26  ldrmodules.not_in_mem_avg               58596 non-null  float64
#  27  malfind.ninjections                     58596 non-null  int64
#  28  malfind.commitCharge                    58596 non-null  int64
#  29  malfind.protection                      58596 non-null  int64
#  30  malfind.uniqueInjections                58596 non-null  float64
#  31  psxview.not_in_pslist                   58596 non-null  int64
#  32  psxview.not_in_eprocess_pool            58596 non-null  int64
#  33  psxview.not_in_ethread_pool             58596 non-null  int64
#  34  psxview.not_in_pspcid_list              58596 non-null  int64
#  35  psxview.not_in_csrss_handles            58596 non-null  int64
#  36  psxview.not_in_session                  58596 non-null  int64
#  37  psxview.not_in_deskthrd                 58596 non-null  int64
#  38  psxview.not_in_pslist_false_avg         58596 non-null  float64
#  39  psxview.not_in_eprocess_pool_false_avg  58596 non-null  float64
#  40  psxview.not_in_ethread_pool_false_avg   58596 non-null  float64
#  41  psxview.not_in_pspcid_list_false_avg    58596 non-null  float64
#  42  psxview.not_in_csrss_handles_false_avg  58596 non-null  float64
#  43  psxview.not_in_session_false_avg        58596 non-null  float64
#  44  psxview.not_in_deskthrd_false_avg       58596 non-null  float64
#  45  modules.nmodules                        58596 non-null  int64
#  46  svcscan.nservices                       58596 non-null  int64
#  47  svcscan.kernel_drivers                  58596 non-null  int64
#  48  svcscan.fs_drivers                      58596 non-null  int64
#  49  svcscan.process_services                58596 non-null  int64
#  50  svcscan.shared_process_services         58596 non-null  int64
#  51  svcscan.interactive_process_services    58596 non-null  int64
#  52  svcscan.nactive                         58596 non-null  int64
#  53  callbacks.ncallbacks                    58596 non-null  int64
#  54  callbacks.nanonymous                    58596 non-null  int64
#  55  callbacks.ngeneric                      58596 non-null  int64
#  56  Class                                   58596 non-null  object
# dtypes: float64(15), int64(40), object(2)
# memory usage: 25.5+ MB

# %% [markdown]
# ##Mengatasi missing value

# %%
data.isnull().sum()
# Out:
# Category                                  0
# pslist.nproc                              0
# pslist.nppid                              0
# pslist.avg_threads                        0
# pslist.nprocs64bit                        0
# pslist.avg_handlers                       0
# dlllist.ndlls                             0
# dlllist.avg_dlls_per_proc                 0
# handles.nhandles                          0
# handles.avg_handles_per_proc              0
# handles.nport                             0
# handles.nfile                             0
# handles.nevent                            0
# handles.ndesktop                          0
# handles.nkey                              0
# handles.nthread                           0
# handles.ndirectory                        0
# handles.nsemaphore                        0
# handles.ntimer                            0
# handles.nsection                          0
# handles.nmutant                           0
# ldrmodules.not_in_load                    0
# ldrmodules.not_in_init                    0
# ldrmodules.not_in_mem                     0
# ldrmodules.not_in_load_avg                0
# ldrmodules.not_in_init_avg                0
# ldrmodules.not_in_mem_avg                 0
# malfind.ninjections                       0
# malfind.commitCharge                      0
# malfind.protection                        0
# malfind.uniqueInjections                  0
# psxview.not_in_pslist                     0
# psxview.not_in_eprocess_pool              0
# psxview.not_in_ethread_pool               0
# psxview.not_in_pspcid_list                0
# psxview.not_in_csrss_handles              0
# psxview.not_in_session                    0
# psxview.not_in_deskthrd                   0
# psxview.not_in_pslist_false_avg           0
# psxview.not_in_eprocess_pool_false_avg    0
# psxview.not_in_ethread_pool_false_avg     0
# psxview.not_in_pspcid_list_false_avg      0
# psxview.not_in_csrss_handles_false_avg    0
# psxview.not_in_session_false_avg          0
# psxview.not_in_deskthrd_false_avg         0
# modules.nmodules                          0
# svcscan.nservices                         0
# svcscan.kernel_drivers                    0
# svcscan.fs_drivers                        0
# svcscan.process_services                  0
# svcscan.shared_process_services           0
# svcscan.interactive_process_services      0
# svcscan.nactive                           0
# callbacks.ncallbacks                      0
# callbacks.nanonymous                      0
# callbacks.ngeneric                        0
# Class                                     0
# dtype: int64

# %%
data.shape
# Out:
# (58596, 57)

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (58596, 57)

# %% [markdown]
# ##Memeriksa distribusi kategori

# %%
data['Category'].value_counts()
# Out:
# Category
# Benign                                                                                     29298
# Spyware-Gator-1c227a11e3d4987630bf89b1712442a4d3e5cb551d13273811ec47c237a8b303-7.raw           2
# Spyware-Gator-1bd318a4df278d1bd30e910b858aec9a1db674474b0e6d2d803648a43aa8023d-6.raw           2
# Spyware-Gator-1bd318a4df278d1bd30e910b858aec9a1db674474b0e6d2d803648a43aa8023d-7.raw           2
# Spyware-Gator-1bd318a4df278d1bd30e910b858aec9a1db674474b0e6d2d803648a43aa8023d-8.raw           2
#                                                                                            ...
# Ransomware-Ako-00a2c6bab1e53f679cdd4fdc772cd291928c109b9b747652639a1700d844f719-3.raw          1
# Ransomware-Ako-00a2c6bab1e53f679cdd4fdc772cd291928c109b9b747652639a1700d844f719-2.raw          1
# Ransomware-Ako-00a2c6bab1e53f679cdd4fdc772cd291928c109b9b747652639a1700d844f719-10.raw         1
# Ransomware-Ako-00a2c6bab1e53f679cdd4fdc772cd291928c109b9b747652639a1700d844f719-1.raw          1
# Ransomware-Shade-955d9af38346c1755527bd196668edfad6d3f001d217b04d2380eb99e0760585-8.raw        1
# Name: count, Length: 28346, dtype: int64

# %% [markdown]
# ##Merubah Kategori

# %% [markdown]
# Dua kolom ditambahkan seperti *Sub_Category* dan *Main_Category* agar bisa diperjelas

# %%
def extract_category(value):
    match = re.match(r'^[^-]+-[^-]+', value)
    if match:
        return match.group()
    return value

# %%
data['Cleaned_Category'] = data['Category'].apply(extract_category)

# %%
data['Cleaned_Category'].value_counts()
# Out:
# Cleaned_Category
# Benign                  29298
# Spyware-Transponder      2410
# Spyware-Gator            2200
# Ransomware-Shade         2128
# Spyware-CWS              2000
# Trojan-Scar              2000
# Spyware-180solutions     2000
# Ransomware-Ako           2000
# Trojan-Refroso           2000
# Ransomware-Conti         1988
# Trojan-Emotet            1967
# Ransomware-Maze          1958
# Trojan-Zeus              1950
# Ransomware-Pysa          1717
# Trojan-Reconyc           1570
# Spyware-TIBS             1410
# Name: count, dtype: int64

# %%
data['Main_Category'] = data['Cleaned_Category'].apply(lambda x: x.split('-')[0])

# %%
data['Main_Category'].value_counts()
# Out:
# Main_Category
# Benign        29298
# Spyware       10020
# Ransomware     9791
# Trojan         9487
# Name: count, dtype: int64

# %%
data = data[~data['Main_Category'].isin(['Spyware', 'Trojan'])]
data['Main_Category'].value_counts()
# Out:
# Main_Category
# Benign        29298
# Ransomware     9791
# Name: count, dtype: int64

# %%
data['Sub_Category'] = data['Cleaned_Category'].apply(lambda x: x.split('-')[1] if '-' in x else x)

# %%
data['Sub_Category'].value_counts()
# Out:
# Sub_Category
# Benign    29298
# Shade      2128
# Ako        2000
# Conti      1988
# Maze       1958
# Pysa       1717
# Name: count, dtype: int64

# %%
data.drop(columns="Category",inplace=True)
data.drop(columns="Class", inplace=True)
data.drop(columns="Cleaned_Category",inplace=True)
data.drop(columns="Main_Category",inplace=True)

# %%
data.to_csv('data.csv')

# %% [markdown]
# ##**Merubah data menjadi numerik**

# %%
# Identifying different types of columns
nominal_names = data.select_dtypes(include=['object']).columns
integer_names = data.select_dtypes(include=['int', 'int64']).columns
binary_names = []
float_names = data.select_dtypes(include=['float', 'float64']).columns

# %%
# Identifying binary columns (with only two unique values, e.g., 0 and 1)
for c in data.columns:
    if data[c].nunique() == 2 and data[c].dtype in ['int64', 'int', 'float64']:
        binary_names.append(c)

# Converting integer columns to numeric
for c in integer_names:
    data[c] = pd.to_numeric(data[c])

# Converting binary columns to numeric (optional step if already int/float)
for c in binary_names:
    data[c] = pd.to_numeric(data[c])

# Converting float columns to numeric
for c in float_names:
    data[c] = pd.to_numeric(data[c])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39089 entries, 0 to 58595
# Data columns (total 56 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   pslist.nproc                            39089 non-null  int64
#  1   pslist.nppid                            39089 non-null  int64
#  2   pslist.avg_threads                      39089 non-null  float64
#  3   pslist.nprocs64bit                      39089 non-null  int64
#  4   pslist.avg_handlers                     39089 non-null  float64
#  5   dlllist.ndlls                           39089 non-null  int64
#  6   dlllist.avg_dlls_per_proc               39089 non-null  float64
#  7   handles.nhandles                        39089 non-null  int64
#  8   handles.avg_handles_per_proc            39089 non-null  float64
#  9   handles.nport                           39089 non-null  int64
#  10  handles.nfile                           39089 non-null  int64
#  11  handles.nevent                          39089 non-null  int64
#  12  handles.ndesktop                        39089 non-null  int64
#  13  handles.nkey                            39089 non-null  int64
#  14  handles.nthread                         39089 non-null  int64
#  15  handles.ndirectory                      39089 non-null  int64
#  16  handles.nsemaphore                      39089 non-null  int64
#  17  handles.ntimer                          39089 non-null  int64
#  18  handles.nsection                        39089 non-null  int64
#  19  handles.nmutant                         39089 non-null  int64
#  20  ldrmodules.not_in_load                  39089 non-null  int64
#  21  ldrmodules.not_in_init                  39089 non-null  int64
#  22  ldrmodules.not_in_mem                   39089 non-null  int64
#  23  ldrmodules.not_in_load_avg              39089 non-null  float64
#  24  ldrmodules.not_in_init_avg              39089 non-null  float64
#  25  ldrmodules.not_in_mem_avg               39089 non-null  float64
#  26  malfind.ninjections                     39089 non-null  int64
#  27  malfind.commitCharge                    39089 non-null  int64
#  28  malfind.protection                      39089 non-null  int64
#  29  malfind.uniqueInjections                39089 non-null  float64
#  30  psxview.not_in_pslist                   39089 non-null  int64
#  31  psxview.not_in_eprocess_pool            39089 non-null  int64
#  32  psxview.not_in_ethread_pool             39089 non-null  int64
#  33  psxview.not_in_pspcid_list              39089 non-null  int64
#  34  psxview.not_in_csrss_handles            39089 non-null  int64
#  35  psxview.not_in_session                  39089 non-null  int64
#  36  psxview.not_in_deskthrd                 39089 non-null  int64
#  37  psxview.not_in_pslist_false_avg         39089 non-null  float64
#  38  psxview.not_in_eprocess_pool_false_avg  39089 non-null  float64
#  39  psxview.not_in_ethread_pool_false_avg   39089 non-null  float64
#  40  psxview.not_in_pspcid_list_false_avg    39089 non-null  float64
#  41  psxview.not_in_csrss_handles_false_avg  39089 non-null  float64
#  42  psxview.not_in_session_false_avg        39089 non-null  float64
#  43  psxview.not_in_deskthrd_false_avg       39089 non-null  float64
#  44  modules.nmodules                        39089 non-null  int64
#  45  svcscan.nservices                       39089 non-null  int64
#  46  svcscan.kernel_drivers                  39089 non-null  int64
#  47  svcscan.fs_drivers                      39089 non-null  int64
#  48  svcscan.process_services                39089 non-null  int64
#  49  svcscan.shared_process_services         39089 non-null  int64
#  50  svcscan.interactive_process_services    39089 non-null  int64
#  51  svcscan.nactive                         39089 non-null  int64
#  52  callbacks.ncallbacks                    39089 non-null  int64
#  53  callbacks.nanonymous                    39089 non-null  int64
#  54  callbacks.ngeneric                      39089 non-null  int64
#  55  Sub_Category                            39089 non-null  object
# dtypes: float64(15), int64(40), object(1)
# memory usage: 17.0+ MB

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ##**Sub-Class Visualization**

# %%
plt.figure(figsize=(8,8))
plt.pie(data.Sub_Category.value_counts(),labels=data.Sub_Category.unique(),autopct='%0.2f%%')
plt.title('Distribusi diagram lingkaran Sub-Class')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #**Label Encoding**

# %%
bin_label = pd.DataFrame(data.Sub_Category)

# %%
bin_data = data.copy()

# %%
le1 = preprocessing.LabelEncoder()
enc_label = bin_label.apply(le1.fit_transform)
bin_data['Sub_Category'] = enc_label

# %%
le1.classes_
# Out:
# array(['Ako', 'Benign', 'Conti', 'Maze', 'Pysa', 'Shade'], dtype=object)

# %%
np.save("le1_classes.npy",le1.classes_,allow_pickle=True)

# %% [markdown]
# # **Correlation between features of dataset**

# %%
plt.figure(figsize=(20,8))
corr_bin = bin_data.corr()
sns.heatmap(corr_bin,vmax=1.0,annot=False)
plt.title('Correlation Matrix for Binary Labels',fontsize=16)
plt.show()

# %% [markdown]
# # **Feature Selection**

# %%
corr_ybin = abs(corr_bin['Sub_Category'])
highest_corr_bin = corr_ybin[corr_ybin >= 0.20]
highest_corr_bin.sort_values(ascending=True)
# Out:
# handles.ndesktop                   0.221005
# callbacks.ncallbacks               0.228917
# pslist.nppid                       0.274871
# svcscan.nservices                  0.389798
# ldrmodules.not_in_init             0.414736
# svcscan.nactive                    0.418488
# handles.nkey                       0.438590
# svcscan.process_services           0.440829
# svcscan.shared_process_services    0.459790
# ldrmodules.not_in_mem              0.461366
# ldrmodules.not_in_load             0.461412
# handles.nsemaphore                 0.504964
# dlllist.ndlls                      0.513934
# pslist.avg_threads                 0.514737
# handles.ntimer                     0.526619
# handles.nmutant                    0.530116
# handles.nthread                    0.543016
# handles.nevent                     0.549885
# dlllist.avg_dlls_per_proc          0.576765
# handles.nsection                   0.579873
# Sub_Category                       1.000000
# Name: Sub_Category, dtype: float64

# %%
bin_cols = highest_corr_bin.index
bin_cols
# Out:
# Index(['pslist.nppid', 'pslist.avg_threads', 'dlllist.ndlls',
#        'dlllist.avg_dlls_per_proc', 'handles.nevent', 'handles.ndesktop',
#        'handles.nkey', 'handles.nthread', 'handles.nsemaphore',
#        'handles.ntimer', 'handles.nsection', 'handles.nmutant',
#        'ldrmodules.not_in_load', 'ldrmodules.not_in_init',
#        'ldrmodules.not_in_mem', 'svcscan.nservices',
#        'svcscan.process_services', 'svcscan.shared_process_services',
#        'svcscan.nactive', 'callbacks.ncallbacks', 'Sub_Category'],
#       dtype='object')

# %%
bin_data = bin_data[bin_cols].copy()
bin_data
# Out:
#        pslist.nppid  pslist.avg_threads  dlllist.ndlls  \
# 0                17           10.555556           1694
# 1                19           11.531915           2074
# 2                14           14.725000           1932
# 3                13           13.500000           1445
# 4                16           11.452381           2067
# ...             ...                 ...            ...
# 58591            15           10.108108           1453
# 58592            14            9.945946           1347
# 58593            15            9.842105           1448
# 58594            15           10.243243           1452
# 58595            15            9.868421           1487
#
#        dlllist.avg_dlls_per_proc  handles.nevent  handles.ndesktop  \
# 0                      38.500000            3161                46
# 1                      44.127660            3761                51
# 2                      48.300000            3996                45
# 3                      45.156250            2961                36
# 4                      49.214286            3834                45
# ...                          ...             ...               ...
# 58591                  39.270270            2819                40
# 58592                  36.405405            2394                39
# 58593                  38.105263            2816                40
# 58594                  39.243243            2819                40
# 58595                  39.131579            2843                41
#
#        handles.nkey  handles.nthread  handles.nsemaphore  handles.ntimer  ...  \
# 0               716              887                 671             125  ...
# 1              1011             1030                 766             148  ...
# 2               784             1241                 645             138  ...
# 3               654              792                 567             127  ...
# 4              1252              942                 825             135  ...
# ...             ...              ...                 ...             ...  ...
# 58591           668              664                 596             113  ...
# 58592           555              624                 482             102  ...
# 58593           673              661                 596             113  ...
# 58594           668              667                 596             113  ...
# 58595           683              669                 598             116  ...
#
#        handles.nmutant  ldrmodules.not_in_load  ldrmodules.not_in_init  \
# 0                  257                      53                      95
# 1                  394                      77                     123
# 2                  338                      51                      89
# 3                  242                      31                      62
# 4                  429                     102                     143
# ...                ...                     ...                     ...
# 58591              230                      43                      79
# 58592              203                      43                      79
# 58593              230                      43                      79
# 58594              230                      43                      79
# 58595              236                      44                      81
#
#        ldrmodules.not_in_mem  svcscan.nservices  svcscan.process_services  \
# 0                         53                389                        24
# 1                         77                392                        24
# 2                         51                395                        27
# 3                         31                395                        27
# 4                        102                392                        24
# ...                      ...                ...                       ...
# 58591                     43                389                        24
# 58592                     43                389                        24
# 58593                     43                389                        24
# 58594                     43                389                        24
# 58595                     44                389                        24
#
#        svcscan.shared_process_services  svcscan.nactive  callbacks.ncallbacks  \
# 0                                  116              121                    87
# 1                                  118              122                    87
# 2                                  118              120                    88
# 3                                  118              120                    88
# 4                                  118              124                    87
# ...                                ...              ...                   ...
# 58591                              116              120                    86
# 58592                              116              116                    88
# 58593                              116              120                    88
# 58594                              116              120                    87
# 58595                              116              120                    86
#
#        Sub_Category
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 58591             5
# 58592             5
# 58593             5
# 58594             5
# 58595             5
#
# [39089 rows x 21 columns]

# %%
#value_map = {
#    0: 'Benign',
#    1: 'Ransomware',
#    2: 'Spyware',
#    3: 'Trojan'
#}

#bin_data['Main_Category'] = bin_data['Main_Category'].map(value_map)

# %%
bin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39089 entries, 0 to 58595
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pslist.nppid                     39089 non-null  int64
#  1   pslist.avg_threads               39089 non-null  float64
#  2   dlllist.ndlls                    39089 non-null  int64
#  3   dlllist.avg_dlls_per_proc        39089 non-null  float64
#  4   handles.nevent                   39089 non-null  int64
#  5   handles.ndesktop                 39089 non-null  int64
#  6   handles.nkey                     39089 non-null  int64
#  7   handles.nthread                  39089 non-null  int64
#  8   handles.nsemaphore               39089 non-null  int64
#  9   handles.ntimer                   39089 non-null  int64
#  10  handles.nsection                 39089 non-null  int64
#  11  handles.nmutant                  39089 non-null  int64
#  12  ldrmodules.not_in_load           39089 non-null  int64
#  13  ldrmodules.not_in_init           39089 non-null  int64
#  14  ldrmodules.not_in_mem            39089 non-null  int64
#  15  svcscan.nservices                39089 non-null  int64
#  16  svcscan.process_services         39089 non-null  int64
#  17  svcscan.shared_process_services  39089 non-null  int64
#  18  svcscan.nactive                  39089 non-null  int64
#  19  callbacks.ncallbacks             39089 non-null  int64
#  20  Sub_Category                     39089 non-null  int64
# dtypes: float64(2), int64(19)
# memory usage: 6.6 MB

# %% [markdown]
# # **Data Normalization**

# %%
X_n = bin_data.drop(columns=['Sub_Category'])
y_n = bin_data['Sub_Category']

# %%
# Using boxplots to check for outliers in each feature
plt.figure(figsize=(15, 20))
num_features = X_n.columns

# Creating subplots for each feature to visualize outliers
for i, feature in enumerate(num_features):
    plt.subplot(7, 3, i + 1)  # Creating subplots in a grid of 7 rows and 3 columns
    sns.boxplot(x=X_n[feature], color='lightblue')
    plt.title(feature)
    plt.tight_layout()

plt.show()

# %%
import numpy as np

# Calculate the first and third quartiles
Q1 = np.percentile(X_n, 25, axis=0)
Q3 = np.percentile(X_n, 75, axis=0)
IQR = Q3 - Q1

# Define the outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Create a mask to filter out rows where all features are within the bounds
non_outlier_mask = ((X_n >= lower_bound) & (X_n <= upper_bound)).all(axis=1)

# Filter the dataset
X_no_outliers = X_n[non_outlier_mask]

# X_no_outliers = X_n[non_outlier_mask]

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_no_outliers)

# %%
X_scaled_df = pd.DataFrame(X_scaled, columns=X_n.columns)

# %%
# Using boxplots to check for outliers in each feature
plt.figure(figsize=(15, 20))
num_features_s = X_scaled_df.columns

# Creating subplots for each feature to visualize outliers
for i, feature in enumerate(num_features_s):
    plt.subplot(7, 3, i + 1)  # Creating subplots in a grid of 7 rows and 3 columns
    sns.boxplot(x=X_scaled_df[feature], color='lightblue')
    plt.title(feature)
    plt.tight_layout()

plt.show()

# %%
combined_data = pd.concat([X_scaled_df, y_n.reset_index(drop=True)], axis=1)

# %%
# Total number of rows in the DataFrame
total_rows = len(combined_data)

# Calculate percentage of null values
null_percentage = (combined_data.isnull().sum() / total_rows) * 100

# Display the percentage of null values for each column
print(null_percentage)
# Out:
# pslist.nppid                       15.324004
# pslist.avg_threads                 15.324004
# dlllist.ndlls                      15.324004
# dlllist.avg_dlls_per_proc          15.324004
# handles.nevent                     15.324004
# handles.ndesktop                   15.324004
# handles.nkey                       15.324004
# handles.nthread                    15.324004
# handles.nsemaphore                 15.324004
# handles.ntimer                     15.324004
# handles.nsection                   15.324004
# handles.nmutant                    15.324004
# ldrmodules.not_in_load             15.324004
# ldrmodules.not_in_init             15.324004
# ldrmodules.not_in_mem              15.324004
# svcscan.nservices                  15.324004
# svcscan.process_services           15.324004
# svcscan.shared_process_services    15.324004
# svcscan.nactive                    15.324004
# callbacks.ncallbacks               15.324004
# Sub_Category                        0.000000
# dtype: float64

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
combined_data.iloc[:, :] = imputer.fit_transform(combined_data)

# %%
# Total number of rows in the DataFrame
total_rows = len(combined_data)

# Calculate percentage of null values
null_percentage = (combined_data.isnull().sum() / total_rows) * 100

# Display the percentage of null values for each column
print(null_percentage)
# Out:
# pslist.nppid                       0.0
# pslist.avg_threads                 0.0
# dlllist.ndlls                      0.0
# dlllist.avg_dlls_per_proc          0.0
# handles.nevent                     0.0
# handles.ndesktop                   0.0
# handles.nkey                       0.0
# handles.nthread                    0.0
# handles.nsemaphore                 0.0
# handles.ntimer                     0.0
# handles.nsection                   0.0
# handles.nmutant                    0.0
# ldrmodules.not_in_load             0.0
# ldrmodules.not_in_init             0.0
# ldrmodules.not_in_mem              0.0
# svcscan.nservices                  0.0
# svcscan.process_services           0.0
# svcscan.shared_process_services    0.0
# svcscan.nactive                    0.0
# callbacks.ncallbacks               0.0
# Sub_Category                       0.0
# dtype: float64

# %%
combined_data['Sub_Category'].value_counts()
# Out:
# Sub_Category
# 1    29298
# 5     2128
# 0     2000
# 2     1988
# 3     1958
# 4     1717
# Name: count, dtype: int64

# %%
combined_data.to_csv('bin_data_scaled.csv', index=False)

# %% [markdown]
# # **Data Balancing**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
data_bin = pd.read_csv("bin_data_scaled.csv")

# %%
# Assuming data_bin is your DataFrame with features and 'Sub_Category' as the target column
# Separate features (X) and target (y)
X_bin = data_bin.drop(columns=['Sub_Category']).values
y_bin = data_bin['Sub_Category'].values

# Split central and client data
X_central, X_clients, y_central, y_clients = train_test_split(X_bin, y_bin, test_size=0.7, random_state=55)

# Shuffle the indices
indices = np.arange(len(X_clients))
np.random.shuffle(indices)

# Split the shuffled indices into 3 clients
client_splits = np.array_split(indices, 3)

# Create client data based on the new splits
client_data = [(X_clients[split_indices], y_clients[split_indices]) for split_indices in client_splits]

# Export client data to CSV files with the correct feature names
feature_columns = data_bin.drop(columns=['Sub_Category']).columns

for i, (X_client, y_client) in enumerate(client_data, start=1):
    df_client = pd.DataFrame(X_client, columns=feature_columns)  # Use actual feature names
    df_client['Sub_Category'] = y_client
    df_client.to_csv(f"client_data_{i}.csv", index=False)

# %%
# Visualize the distribution before SMOTE
def visualize_distribution(y_data, title):
    counter = Counter(y_data)
    print(counter.keys(),counter.values())
    plt.bar(counter.keys(), counter.values())
    plt.title(title)
    plt.xlabel('Class')
    plt.ylabel('Frequency')
    plt.show()

# %%
# Apply SMOTE to each client and visualize the distribution after SMOTE
smote = SMOTE(random_state=120)

# %%
# Visualize distribution for central data before SMOTE
visualize_distribution(y_central, title='Central Class Distribution Before SMOTE')
# Out:
# dict_keys([np.int64(2), np.int64(1), np.int64(3), np.int64(4), np.int64(5), np.int64(0)]) dict_values([576, 8782, 616, 519, 634, 599])

# %%
# Apply SMOTE to central data and visualize the distribution after SMOTE
X_central_resampled, y_central_resampled = smote.fit_resample(X_central, y_central)
visualize_distribution(y_central_resampled, title='Central Class Distribution After SMOTE')
# Out:
# dict_keys([np.int64(2), np.int64(1), np.int64(3), np.int64(4), np.int64(5), np.int64(0)]) dict_values([8782, 8782, 8782, 8782, 8782, 8782])

# %%
# Visualize distribution for each client before SMOTE
for i, (X_client, y_client) in enumerate(client_data):
    visualize_distribution(y_client, title=f'Client {i+1} Class Distribution Before SMOTE')
# Out:
# dict_keys([np.int64(1), np.int64(0), np.int64(2), np.int64(4), np.int64(5), np.int64(3)]) dict_values([6821, 494, 483, 379, 498, 446])
# dict_keys([np.int64(1), np.int64(3), np.int64(0), np.int64(2), np.int64(4), np.int64(5)]) dict_values([6835, 473, 451, 482, 409, 471])
# dict_keys([np.int64(1), np.int64(0), np.int64(5), np.int64(4), np.int64(3), np.int64(2)]) dict_values([6860, 456, 525, 410, 423, 447])

# %%
client_data_smoted = []
for i, (X_client, y_client) in enumerate(client_data):
    X_client_resampled, y_client_resampled = smote.fit_resample(X_client, y_client)
    client_data_smoted.append((X_client_resampled, y_client_resampled))
    visualize_distribution(y_client_resampled, title=f'Client {i+1} Class Distribution After SMOTE')

# Further split client data into 5 clients
client_splits_smoted = np.array_split(np.arange(len(X_client_resampled)), 3)
# Out:
# dict_keys([np.int64(1), np.int64(0), np.int64(2), np.int64(4), np.int64(5), np.int64(3)]) dict_values([6821, 6821, 6821, 6821, 6821, 6821])
# dict_keys([np.int64(1), np.int64(3), np.int64(0), np.int64(2), np.int64(4), np.int64(5)]) dict_values([6835, 6835, 6835, 6835, 6835, 6835])
# dict_keys([np.int64(1), np.int64(0), np.int64(5), np.int64(4), np.int64(3), np.int64(2)]) dict_values([6860, 6860, 6860, 6860, 6860, 6860])

# %% [markdown]
# # **Training**

# %% [markdown]
# **NOTE** \\
# Penggunaan Variable untuk Balance dan Imbalance sebagai berikut:
# - X_central: Imbalance (untuk Central sebelum SMOTE)
# - X_clients: Imbalance (untuk Client sebelum SMOTE)
# - X_central_resampled: Balanced (untuk Central setelah SMOTE)
# - X_client_resampled: Balanced (untuk masing-masing Client setelah SMOTE)
# - y_central: Imbalance (untuk Central sebelum SMOTE)
# - y_clients: Imbalance (untuk Client sebelum SMOTE)
# - y_central_resampled: Balanced (untuk Central setelah SMOTE)
# - y_client_resampled: Balanced (untuk masing-masing Client setelah SMOTE)

# %%
folder_name = 'Imbalanced'

if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    print(f"Folder '{folder_name}' created successfully.")
else:
    print(f"{folder_name} already exists. Skipping Folder Creation.")
# Out:
# Folder 'Imbalanced' created successfully.

# %%
import torch
import math
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    confusion_matrix,
    roc_auc_score,
)
from torch.utils.data import DataLoader, Subset, TensorDataset, random_split
from sklearn.model_selection import KFold
import numpy as np
import matplotlib.pyplot as plt
import warnings
from torch.optim.lr_scheduler import ReduceLROnPlateau# Import necessary library
from sklearn.model_selection import train_test_split
import itertools

# %%
central_dataset = TensorDataset(
    torch.tensor(X_central, dtype=torch.float32), torch.tensor(y_central, dtype=torch.long)
)
client_datasets = [
    TensorDataset(
        torch.tensor(X_clients[indices], dtype=torch.float32),
        torch.tensor(y_clients[indices], dtype=torch.long),
    )
    for indices in client_splits
]

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("GPU is available and being used" if torch.cuda.is_available() else "Using CPU due to lack of GPU")
# Out:
# GPU is available and being used

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return x

class TimeSeriesTransformer(nn.Module):
    def __init__(self, num_continuous, dim=512, depth=4, heads=8, attn_dropout=0.3, ff_dropout=0.1, output_dim=1, mlp_hidden_mults=(4, 2), mlp_act=nn.GELU()):
        super(TimeSeriesTransformer, self).__init__()
        self.dim = dim
        self.input_proj = nn.Linear(num_continuous, dim)
        self.pos_encoder = PositionalEncoding(dim)

        # Transformer encoder layers
        encoder_layer = nn.TransformerEncoderLayer(d_model=dim, nhead=heads, dropout=attn_dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=depth)

        # MLP Head
        mlp_hidden_dim1 = dim * mlp_hidden_mults[0]
        mlp_hidden_dim2 = dim * mlp_hidden_mults[1]
        self.mlp = nn.Sequential(
            nn.Linear(dim, mlp_hidden_dim1),
            mlp_act,
            nn.Dropout(ff_dropout),
            nn.Linear(mlp_hidden_dim1, mlp_hidden_dim2),
            mlp_act,
            nn.Dropout(ff_dropout),
            nn.Linear(mlp_hidden_dim2, output_dim)
        )

    def forward(self, src):
        src = self.input_proj(src) * math.sqrt(self.dim)
        src = self.pos_encoder(src)

        # Transformer encoder forward pass
        output = self.transformer_encoder(src)
        output = self.mlp(output[-1, :, :])  # Use the last time step's output for prediction
        return output

# %%
# Hyperparameters
num_continuous = X_central.shape[1]

dim = 256
depth = 4
heads = 8
attn_dropout = 0.3
ff_dropout = 0.1
mlp_hidden_mults = (4, 2)
mlp_act = nn.GELU()
output_dim = len(np.unique(y_bin))
num_epochs = 10
clients = 3
num_rounds = 3
k_folds = 5
batch_size = 32

# %%
warnings.filterwarnings("ignore")

import pandas as pd  # Import pandas for DataFrame operations
from sklearn.metrics import ConfusionMatrixDisplay
from torch.utils.data import ConcatDataset

# Function to train a local model
def train_local_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=num_epochs, client_id=None, fold=None, round_num=None):
    model.train()
    train_epoch_metrics = {'loss': [], 'accuracy': [], 'precision': [], 'recall': [], 'f1': [], 'roc_auc': []}
    val_epoch_metrics = {'loss': [], 'accuracy': [], 'precision': [], 'recall': [], 'f1': [], 'roc_auc': []}

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        total_loss = 0
        all_probs = []
        all_preds = []
        all_labels = []
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            # Get probabilities and predictions
            probabilities = torch.softmax(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            all_probs.extend(probabilities.detach().cpu().numpy())
            all_preds.extend(predicted.detach().cpu().numpy())
            all_labels.extend(labels.detach().cpu().numpy())

        # Calculate training metrics for the epoch
        accuracy = accuracy_score(all_labels, all_preds)
        precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
        recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)
        f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)
        try:
            roc_auc = roc_auc_score(all_labels, np.array(all_probs), multi_class='ovr')
        except ValueError:
            roc_auc = 0

        avg_loss = total_loss / len(train_loader)
        train_epoch_metrics['loss'].append(avg_loss)
        train_epoch_metrics['accuracy'].append(accuracy)
        train_epoch_metrics['precision'].append(precision)
        train_epoch_metrics['recall'].append(recall)
        train_epoch_metrics['f1'].append(f1)
        train_epoch_metrics['roc_auc'].append(roc_auc)

        print(f'Train Epoch {epoch + 1}')
        print(f'Accuracy: {accuracy:.4f}, Loss: {avg_loss:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}, ROC-AUC: {roc_auc:.4f}')

        # Validation phase
        model.eval()
        val_loss = 0
        val_all_probs = []
        val_all_preds = []
        val_all_labels = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                probabilities = torch.softmax(outputs, dim=1)
                _, predicted = torch.max(outputs, 1)

                val_all_probs.extend(probabilities.detach().cpu().numpy())
                val_all_preds.extend(predicted.detach().cpu().numpy())
                val_all_labels.extend(labels.detach().cpu().numpy())

        # Calculate validation metrics for the epoch
        val_accuracy = accuracy_score(val_all_labels, val_all_preds)
        val_precision = precision_score(val_all_labels, val_all_preds, average='weighted', zero_division=0)
        val_recall = recall_score(val_all_labels, val_all_preds, average='weighted', zero_division=0)
        val_f1 = f1_score(val_all_labels, val_all_preds, average='weighted', zero_division=0)
        try:
            val_roc_auc = roc_auc_score(val_all_labels, np.array(val_all_probs), multi_class='ovr')
        except ValueError:
            val_roc_auc = 0

        avg_val_loss = val_loss / len(val_loader)
        val_epoch_metrics['loss'].append(avg_val_loss)
        val_epoch_metrics['accuracy'].append(val_accuracy)
        val_epoch_metrics['precision'].append(val_precision)
        val_epoch_metrics['recall'].append(val_recall)
        val_epoch_metrics['f1'].append(val_f1)
        val_epoch_metrics['roc_auc'].append(val_roc_auc)

        print(f'Validation Epoch {epoch + 1}')
        print(f'Accuracy: {val_accuracy:.4f}, Loss: {avg_val_loss:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}, F1-Score: {val_f1:.4f}, ROC-AUC: {val_roc_auc:.4f}')
        scheduler.step(val_accuracy)

    # Prepare a DataFrame with the metrics
    epochs = range(1, num_epochs + 1)
    metrics_df = pd.DataFrame({
        'epoch': epochs,
        'train_loss': train_epoch_metrics['loss'],
        'train_accuracy': train_epoch_metrics['accuracy'],
        'train_precision': train_epoch_metrics['precision'],
        'train_recall': train_epoch_metrics['recall'],
        'train_f1': train_epoch_metrics['f1'],
        'train_roc_auc': train_epoch_metrics['roc_auc'],
        'val_loss': val_epoch_metrics['loss'],
        'val_accuracy': val_epoch_metrics['accuracy'],
        'val_precision': val_epoch_metrics['precision'],
        'val_recall': val_epoch_metrics['recall'],
        'val_f1': val_epoch_metrics['f1'],
        'val_roc_auc': val_epoch_metrics['roc_auc']
    })
    # Save the DataFrame to CSV
    metrics_df.to_csv(f'{folder_name}/client_{client_id}_metrics_fold_{fold}_round_{round_num}.csv', index=False)

    print("All metrics saved into CSV file.")

    return model.state_dict()  # Return model weights after training

# Federated Averaging Function
def federated_avg(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.mean(
            torch.stack([client_model[k].float() for client_model in client_models]), dim=0
        )
    global_model.load_state_dict(global_dict)
    return global_model

# Evaluation Function
def evaluate_model(model, data_loader, criterion=None):
    model.eval()
    all_probs = []
    all_preds = []
    all_labels = []
    total_loss = 0
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            if criterion is not None:
                loss = criterion(outputs, labels)
                total_loss += loss.item()
            probabilities = torch.softmax(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            all_probs.extend(probabilities.detach().cpu().numpy())
            all_preds.extend(predicted.detach().cpu().numpy())
            all_labels.extend(labels.detach().cpu().numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)
    precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)

    # Calculate ROC AUC
    try:
        roc_auc = roc_auc_score(all_labels, np.array(all_probs), multi_class='ovr')
    except ValueError:
        roc_auc = 0

    if criterion is not None and len(data_loader) > 0:
        avg_loss = total_loss / len(data_loader)
    else:
        avg_loss = None

    conf_matrix = confusion_matrix(all_labels, all_preds, labels=list(range(output_dim)))
    #conf_matrix = confusion_matrix(all_labels, all_preds)


    return accuracy, f1, precision, recall, roc_auc, conf_matrix, avg_loss

# Initialize tracking lists for global metricsconf_matrix = confusion_matrix(all_labels, all_preds)
global_metrics = {
    'train_loss': [],
    'train_accuracy': [],
    'train_precision': [],
    'train_recall': [],
    'train_f1': [],
    'train_roc_auc': [],
    'val_loss': [],
    'val_accuracy': [],
    'val_precision': [],
    'val_recall': [],
    'val_f1': [],
    'val_roc_auc': []
}

# K-Fold Cross Validation setup
kf = KFold(n_splits=k_folds, shuffle=True, random_state=80)
fold_results = []

for fold, (train_idx, val_idx) in enumerate(kf.split(central_dataset)):
    print(f"\nFold {fold + 1}/{k_folds}")

    # Split the central dataset into train and validation sets for this fold
    train_subset = Subset(central_dataset, train_idx)
    val_subset = Subset(central_dataset, val_idx)

    central_train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    central_val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    # Split each client dataset into training and validation subsets
    client_train_loaders = []
    client_val_loaders = []
    combined_datasets_clients = []

    for client_id, client_dataset in enumerate(client_datasets):
        dataset_size = len(client_dataset)
        val_size = int(0.2 * dataset_size)
        train_size = dataset_size - val_size
        train_subset_client, val_subset_client = random_split(
            client_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(fold + client_id)
        )
        train_loader_client = DataLoader(train_subset_client, batch_size=batch_size, shuffle=True)
        val_loader_client = DataLoader(val_subset_client, batch_size=batch_size, shuffle=False)
        client_train_loaders.append(train_loader_client)
        client_val_loaders.append(val_loader_client)

        # Create combined dataset for the client
        combined_dataset_client = ConcatDataset([train_subset_client, val_subset_client])
        combined_datasets_clients.append(combined_dataset_client)

    # Reset global model and metrics for each fold
    global_model = TimeSeriesTransformer(num_continuous=num_continuous,
                                     dim=dim,
                                     depth=depth,
                                     heads=heads,
                                     attn_dropout=attn_dropout,
                                     ff_dropout=ff_dropout,
                                     output_dim=output_dim,
                                     mlp_hidden_mults=mlp_hidden_mults,
                                     mlp_act=mlp_act).to(device)
    criterion = nn.CrossEntropyLoss()

    # Clear metrics lists for each fold
    for key in global_metrics.keys():
        global_metrics[key].clear()

    # Federated Learning Rounds
    for round in range(num_rounds):
        print(f"\nRound {round+1}/{num_rounds}")
        client_models = []
        client_metrics = []

        for client_id, (train_loader, val_loader) in enumerate(zip(client_train_loaders, client_val_loaders)):
            print(f"\nTraining on Client {client_id + 1}")
            local_model = TimeSeriesTransformer(num_continuous=num_continuous,
                                        dim=dim,
                                        depth=depth,
                                        heads=heads,
                                        attn_dropout=attn_dropout,
                                        ff_dropout=ff_dropout,
                                        output_dim=output_dim,
                                        mlp_hidden_mults=mlp_hidden_mults,
                                        mlp_act=mlp_act).to(device)
            local_model.load_state_dict(global_model.state_dict())  # Start from global model
            optimizer = optim.AdamW(local_model.parameters(), lr=1e-4)
            scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.2, patience=2)
            # Train local model
            print(f"Client {client_id + 1}: Starting training with {len(train_loader)} batches...")
            client_model_weights = train_local_model(
                local_model, train_loader, val_loader, criterion, optimizer, num_epochs, client_id=client_id + 1, fold=fold + 1, round_num=round + 1
            )
            print(f"Client {client_id + 1}: Finished training. Returning model weights.")

            # Create combined loader for the client
            combined_loader = DataLoader(combined_datasets_clients[client_id], batch_size=batch_size, shuffle=False)

            # Evaluate client model on combined training and validation data
            val_accuracy, val_f1, val_precision, val_recall, val_roc_auc, conf_matrix, val_loss = evaluate_model(
                local_model, combined_loader, criterion
            )
            client_metrics.append(
                {
                    "accuracy": val_accuracy,
                    "precision": val_precision,
                    "recall": val_recall,
                    "f1": val_f1,
                    "roc_auc": val_roc_auc,
                    "loss": val_loss
                }
            )

            # Print confusion matrix
            print(f"Client {client_id + 1} Combined Training and Validation Confusion Matrix:")
            print(conf_matrix)

            # Plot and save confusion matrix with round indicator
            classes = [str(i) for i in range(output_dim)]
            disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=classes)
            disp.plot(cmap=plt.cm.Blues)
            plt.title(f'Client {client_id + 1} Confusion Matrix on Combined Data (Fold {fold + 1}, Round {round + 1})')
            plt.savefig(f'{folder_name}/client_{client_id + 1}_confusion_matrix_combined_fold_{fold + 1}_round_{round + 1}.png')
            plt.close()

            client_models.append(client_model_weights)

        # Calculate average client metrics
        avg_client_accuracy = np.mean([metric["accuracy"] for metric in client_metrics])
        avg_client_precision = np.mean([metric["precision"] for metric in client_metrics])
        avg_client_recall = np.mean([metric["recall"] for metric in client_metrics])
        avg_client_f1 = np.mean([metric["f1"] for metric in client_metrics])
        avg_client_roc_auc = np.mean([metric["roc_auc"] for metric in client_metrics])

        # Perform Federated Averaging
        print("Performing Federated Averaging to update the global model...")
        global_model = federated_avg(global_model, client_models)
        print("Global model updated.")

        # Create combined dataset and loader for all clients
        combined_clients_dataset = ConcatDataset(combined_datasets_clients)
        combined_clients_loader = DataLoader(combined_clients_dataset, batch_size=batch_size, shuffle=False)

        # Evaluate the global model on the combined client data (train data)
        train_accuracy, train_f1, train_precision, train_recall, train_roc_auc, train_conf_matrix, train_loss = evaluate_model(
            global_model, combined_clients_loader, criterion
        )
        global_metrics['train_loss'].append(train_loss)
        global_metrics['train_accuracy'].append(train_accuracy)
        global_metrics['train_precision'].append(train_precision)
        global_metrics['train_recall'].append(train_recall)
        global_metrics['train_f1'].append(train_f1)
        global_metrics['train_roc_auc'].append(train_roc_auc)

        # Evaluate the global model on the central validation set
        val_accuracy, val_f1, val_precision, val_recall, val_roc_auc, val_conf_matrix, val_loss = evaluate_model(
            global_model, central_val_loader, criterion
        )
        global_metrics['val_loss'].append(val_loss)
        global_metrics['val_accuracy'].append(val_accuracy)
        global_metrics['val_precision'].append(val_precision)
        global_metrics['val_recall'].append(val_recall)
        global_metrics['val_f1'].append(val_f1)
        global_metrics['val_roc_auc'].append(val_roc_auc)

        # Print confusion matrix for combined client data
        print(f"Global Model Confusion Matrix on Combined Client Data for Fold {fold + 1}, Round {round + 1}:")
        print(train_conf_matrix)

        # Plot and save confusion matrix
        classes = [str(i) for i in range(output_dim)]
        disp = ConfusionMatrixDisplay(confusion_matrix=train_conf_matrix, display_labels=classes)
        disp.plot(cmap=plt.cm.Blues)
        plt.title(f'Global Model Confusion Matrix on Combined Client Data (Fold {fold + 1}, Round {round + 1})')
        plt.savefig(f'{folder_name}/global_model_confusion_matrix_combined_clients_fold_{fold + 1}_round_{round + 1}.png')
        plt.close()

        # Print confusion matrix for central validation data
        print(f"Global Model Validation Confusion Matrix for Fold {fold + 1}, Round {round + 1}:")
        print(val_conf_matrix)

        # Plot and save confusion matrix
        disp = ConfusionMatrixDisplay(confusion_matrix=val_conf_matrix, display_labels=classes)
        disp.plot(cmap=plt.cm.Blues)
        plt.title(f'Global Model Confusion Matrix on Central Validation Data (Fold {fold + 1}, Round {round + 1})')
        plt.savefig(f'{folder_name}/global_model_confusion_matrix_central_val_fold_{fold + 1}_round_{round + 1}.png')
        plt.close()

        print(f"Round {round+1}/{num_rounds}, Global Model Metrics:")
        print(f"On Combined Client Data (Train):")
        print(
            f"Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.4f}, Precision: {train_precision:.4f}, "
            f"Recall: {train_recall:.4f}, F1 Score: {train_f1:.4f}, ROC AUC: {train_roc_auc:.4f}"
        )
        print(f"On Central Validation Data:")
        print(
            f"Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}, Precision: {val_precision:.4f}, "
            f"Recall: {val_recall:.4f}, F1 Score: {val_f1:.4f}, ROC AUC: {val_roc_auc:.4f}"
        )

    # Prepare a DataFrame with the global metrics over rounds
    rounds = range(1, num_rounds + 1)
    global_metrics_df = pd.DataFrame({
        'round': rounds,
        'train_loss': global_metrics['train_loss'],
        'train_accuracy': global_metrics['train_accuracy'],
        'train_precision': global_metrics['train_precision'],
        'train_recall': global_metrics['train_recall'],
        'train_f1': global_metrics['train_f1'],
        'train_roc_auc': global_metrics['train_roc_auc'],
        'val_loss': global_metrics['val_loss'],
        'val_accuracy': global_metrics['val_accuracy'],
        'val_precision': global_metrics['val_precision'],
        'val_recall': global_metrics['val_recall'],
        'val_f1': global_metrics['val_f1'],
        'val_roc_auc': global_metrics['val_roc_auc']
    })
    # Save the DataFrame to CSV
    global_metrics_df.to_csv(f'{folder_name}/global_model_metrics_fold_{fold + 1}.csv', index=False)
    print("Global model metrics over rounds saved into CSV file.")

    # Evaluation on the combined client data and central validation data after federated training for this fold
    # Evaluate on combined client data
    train_accuracy, train_f1, train_precision, train_recall, train_roc_auc, train_conf_matrix, train_loss = evaluate_model(
        global_model, combined_clients_loader, criterion
    )

    # Evaluate on central validation data
    val_accuracy, val_f1, val_precision, val_recall, val_roc_auc, val_conf_matrix, val_loss = evaluate_model(
        global_model, central_val_loader, criterion
    )

    # Print confusion matrix for combined client data
    print(f"Final Global Model Confusion Matrix on Combined Client Data for Fold {fold + 1}:")
    print(train_conf_matrix)

    # Plot and save confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=train_conf_matrix, display_labels=classes)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Final Global Model Confusion Matrix on Combined Client Data (Fold {fold + 1})')
    plt.savefig(f'{folder_name}/final_global_model_confusion_matrix_combined_clients_fold_{fold + 1}.png')
    plt.close()

    # Print confusion matrix for central validation data
    print(f"Final Global Model Validation Confusion Matrix for Fold {fold + 1}:")
    print(val_conf_matrix)

    # Plot and save confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=val_conf_matrix, display_labels=classes)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Final Global Model Confusion Matrix on Central Validation Data (Fold {fold + 1})')
    plt.savefig(f'{folder_name}/final_global_model_confusion_matrix_central_val_fold_{fold + 1}.png')
    plt.close()

    # Store fold results
    fold_results.append(
        {
            "fold": fold + 1,
            "train_accuracy": train_accuracy,
            "train_f1": train_f1,
            "train_precision": train_precision,
            "train_recall": train_recall,
            "train_roc_auc": train_roc_auc,
            "train_loss": train_loss,
            "val_accuracy": val_accuracy,
            "val_f1": val_f1,
            "val_precision": val_precision,
            "val_recall": val_recall,
            "val_roc_auc": val_roc_auc,
            "val_loss": val_loss
        }
    )

# Print overall results
def save_kfold_results(fold_results):
    # Convert fold_results to DataFrame
    fold_results_df = pd.DataFrame(fold_results)
    # Save to CSV
    fold_results_df.to_csv(f'{folder_name}/kfold_metrics.csv', index=False)
    print("K-Fold cross-validation metrics saved into CSV file.")

# Call the function to save K-Fold results
save_kfold_results(fold_results)
# Out:
# Fold 1/5
#
# Round 1/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.7796, Loss: 0.5748, Precision: 0.7266, Recall: 0.7796, F1-Score: 0.7335, ROC-AUC: 0.9055
# Validation Epoch 1
# Accuracy: 0.8317, Loss: 0.3849, Precision: 0.7054, Recall: 0.8317, F1-Score: 0.7615, ROC-AUC: 0.9625
# Train Epoch 2
# Accuracy: 0.8901, Loss: 0.2669, Precision: 0.8520, Recall: 0.8901, F1-Score: 0.8619, ROC-AUC: 0.9676
# Validation Epoch 2
# Accuracy: 0.8925, Loss: 0.2530, Precision: 0.8611, Recall: 0.8925, F1-Score: 0.8634, ROC-AUC: 0.9707
# Train Epoch 3
# Accuracy: 0.8983, Loss: 0.2463, Precision: 0.8689, Recall: 0.8983, F1-Score: 0.8666, ROC-AUC: 0.9692
# Validation Epoch 3
# Accuracy: 0.8986, Loss: 0.2456, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9684
# Train Epoch 4
# Accuracy: 0.9041, Loss: 0.2292, Precision: 0.8731, Recall: 0.9041, F1-Score: 0.8709, ROC-AUC: 0.9690
# Validation Epoch 4
# Accuracy: 0.8969, Loss: 0.2474, Precision: 0.8513, Recall: 0.8969, F1-Score: 0.8606, ROC-AUC: 0.9713
# Train Epoch 5
# Accuracy: 0.9041, Loss: 0.2252, Precision: 0.9125, Recall: 0.9041, F1-Score: 0.8701, ROC-AUC: 0.9712
# Validation Epoch 5
# Accuracy: 0.8975, Loss: 0.2423, Precision: 0.8519, Recall: 0.8975, F1-Score: 0.8612, ROC-AUC: 0.9700
# Train Epoch 6
# Accuracy: 0.9015, Loss: 0.2362, Precision: 0.8737, Recall: 0.9015, F1-Score: 0.8696, ROC-AUC: 0.9688
# Validation Epoch 6
# Accuracy: 0.8986, Loss: 0.2389, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9698
# Train Epoch 7
# Accuracy: 0.9045, Loss: 0.2222, Precision: 0.8634, Recall: 0.9045, F1-Score: 0.8702, ROC-AUC: 0.9725
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2365, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9698
# Train Epoch 8
# Accuracy: 0.9045, Loss: 0.2273, Precision: 0.8637, Recall: 0.9045, F1-Score: 0.8704, ROC-AUC: 0.9727
# Validation Epoch 8
# Accuracy: 0.8986, Loss: 0.2374, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9698
# Train Epoch 9
# Accuracy: 0.9045, Loss: 0.2269, Precision: 0.8767, Recall: 0.9045, F1-Score: 0.8706, ROC-AUC: 0.9721
# Validation Epoch 9
# Accuracy: 0.8986, Loss: 0.2366, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9697
# Train Epoch 10
# Accuracy: 0.9045, Loss: 0.2205, Precision: 0.8634, Recall: 0.9045, F1-Score: 0.8702, ROC-AUC: 0.9728
# Validation Epoch 10
# Accuracy: 0.8986, Loss: 0.2372, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9699
# All metrics saved into CSV file.
# Client 1: Finished training. Returning model weights.
# Client 1 Combined Training and Validation Confusion Matrix:
# [[ 430   64    0    0    0    0]
#  [   0 6821    0    0    0    0]
#  [   0  483    0    0    0    0]
#  [   0  333    0  113    0    0]
#  [   0    0    0    0  379    0]
#  [   0    0    0    0    2  496]]
#
# Training on Client 2
# Client 2: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.7711, Loss: 0.5914, Precision: 0.7089, Recall: 0.7711, F1-Score: 0.7244, ROC-AUC: 0.8967
# Validation Epoch 1
# Accuracy: 0.7950, Loss: 0.4525, Precision: 0.6827, Recall: 0.7950, F1-Score: 0.7314, ROC-AUC: 0.9531
# Train Epoch 2
# Accuracy: 0.8850, Loss: 0.2755, Precision: 0.8473, Recall: 0.8850, F1-Score: 0.8560, ROC-AUC: 0.9661
# Validation Epoch 2
# Accuracy: 0.9013, Loss: 0.2456, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9672
# Train Epoch 3
# Accuracy: 0.8902, Loss: 0.2724, Precision: 0.8549, Recall: 0.8902, F1-Score: 0.8581, ROC-AUC: 0.9682
# Validation Epoch 3
# Accuracy: 0.8914, Loss: 0.3001, Precision: 0.8372, Recall: 0.8914, F1-Score: 0.8598, ROC-AUC: 0.9675
# Train Epoch 4
# Accuracy: 0.8957, Loss: 0.2711, Precision: 0.8549, Recall: 0.8957, F1-Score: 0.8617, ROC-AUC: 0.9678
# Validation Epoch 4
# Accuracy: 0.8969, Loss: 0.2432, Precision: 0.8653, Recall: 0.8969, F1-Score: 0.8649, ROC-AUC: 0.9691
# Train Epoch 5
# Accuracy: 0.8965, Loss: 0.2573, Precision: 0.8733, Recall: 0.8965, F1-Score: 0.8645, ROC-AUC: 0.9674
# Validation Epoch 5
# Accuracy: 0.9013, Loss: 0.2364, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9685
# Train Epoch 6
# Accuracy: 0.9009, Loss: 0.2380, Precision: 0.8596, Recall: 0.9009, F1-Score: 0.8661, ROC-AUC: 0.9690
# Validation Epoch 6
# Accuracy: 0.9013, Loss: 0.2342, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9696
# Train Epoch 7
# Accuracy: 0.9008, Loss: 0.2306, Precision: 0.8596, Recall: 0.9008, F1-Score: 0.8660, ROC-AUC: 0.9706
# Validation Epoch 7
# Accuracy: 0.9013, Loss: 0.2346, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9694
# Train Epoch 8
# Accuracy: 0.9011, Loss: 0.2304, Precision: 0.9126, Recall: 0.9011, F1-Score: 0.8664, ROC-AUC: 0.9702
# Validation Epoch 8
# Accuracy: 0.9002, Loss: 0.2358, Precision: 0.8713, Recall: 0.9002, F1-Score: 0.8674, ROC-AUC: 0.9693
# Train Epoch 9
# Accuracy: 0.9005, Loss: 0.2301, Precision: 0.8790, Recall: 0.9005, F1-Score: 0.8672, ROC-AUC: 0.9707
# Validation Epoch 9
# Accuracy: 0.9013, Loss: 0.2342, Precision: 0.8606, Recall: 0.9013, F1-Score: 0.8669, ROC-AUC: 0.9692
# Train Epoch 10
# Accuracy: 0.9009, Loss: 0.2329, Precision: 0.8811, Recall: 0.9009, F1-Score: 0.8666, ROC-AUC: 0.9702
# Validation Epoch 10
# Accuracy: 0.9013, Loss: 0.2339, Precision: 0.8606, Recall: 0.9013, F1-Score: 0.8669, ROC-AUC: 0.9693
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 378   73    0    0    0    0]
#  [   0 6834    1    0    0    0]
#  [   0  479    3    0    0    0]
#  [   0  347    1  125    0    0]
#  [   0    0    0    0  409    0]
#  [   0    0    0    0    0  471]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.7772, Loss: 0.5831, Precision: 0.7328, Recall: 0.7772, F1-Score: 0.7297, ROC-AUC: 0.8996
# Validation Epoch 1
# Accuracy: 0.8734, Loss: 0.3305, Precision: 0.8144, Recall: 0.8734, F1-Score: 0.8390, ROC-AUC: 0.9613
# Train Epoch 2
# Accuracy: 0.8957, Loss: 0.2556, Precision: 0.8663, Recall: 0.8957, F1-Score: 0.8673, ROC-AUC: 0.9692
# Validation Epoch 2
# Accuracy: 0.8986, Loss: 0.2491, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9663
# Train Epoch 3
# Accuracy: 0.9032, Loss: 0.2318, Precision: 0.8667, Recall: 0.9032, F1-Score: 0.8721, ROC-AUC: 0.9690
# Validation Epoch 3
# Accuracy: 0.8986, Loss: 0.2573, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9664
# Train Epoch 4
# Accuracy: 0.8961, Loss: 0.2637, Precision: 0.8588, Recall: 0.8961, F1-Score: 0.8615, ROC-AUC: 0.9665
# Validation Epoch 4
# Accuracy: 0.8947, Loss: 0.2718, Precision: 0.8564, Recall: 0.8947, F1-Score: 0.8591, ROC-AUC: 0.9659
# Train Epoch 5
# Accuracy: 0.9053, Loss: 0.2279, Precision: 0.8671, Recall: 0.9053, F1-Score: 0.8705, ROC-AUC: 0.9690
# Validation Epoch 5
# Accuracy: 0.8986, Loss: 0.2390, Precision: 0.8605, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9671
# Train Epoch 6
# Accuracy: 0.9053, Loss: 0.2239, Precision: 0.8671, Recall: 0.9053, F1-Score: 0.8705, ROC-AUC: 0.9704
# Validation Epoch 6
# Accuracy: 0.8986, Loss: 0.2374, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9679
# Train Epoch 7
# Accuracy: 0.9054, Loss: 0.2237, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9708
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2380, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9679
# Train Epoch 8
# Accuracy: 0.9053, Loss: 0.2458, Precision: 0.8671, Recall: 0.9053, F1-Score: 0.8706, ROC-AUC: 0.9700
# Validation Epoch 8
# Accuracy: 0.8980, Loss: 0.2380, Precision: 0.8605, Recall: 0.8980, F1-Score: 0.8626, ROC-AUC: 0.9678
# Train Epoch 9
# Accuracy: 0.9054, Loss: 0.2239, Precision: 0.8837, Recall: 0.9054, F1-Score: 0.8710, ROC-AUC: 0.9705
# Validation Epoch 9
# Accuracy: 0.8980, Loss: 0.2411, Precision: 0.8599, Recall: 0.8980, F1-Score: 0.8623, ROC-AUC: 0.9679
# Train Epoch 10
# Accuracy: 0.9054, Loss: 0.2234, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9712
# Validation Epoch 10
# Accuracy: 0.8980, Loss: 0.2393, Precision: 0.8599, Recall: 0.8980, F1-Score: 0.8623, ROC-AUC: 0.9679
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 372   82    0    0    0    2]
#  [   0 6859    0    0    0    1]
#  [   0  447    0    0    0    0]
#  [   0  342    1   80    0    0]
#  [   0    0    0    0  410    0]
#  [   0    1    0    0    0  524]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 1, Round 1:
# [[ 1180   209     0     0     5     7]
#  [    0 20408     0     0    51    57]
#  [    0  1370     0     0    13    29]
#  [  318  1002     0     0     4    18]
#  [    0     0     0     0  1198     0]
#  [    3     0     0     0     0  1491]]
# Global Model Validation Confusion Matrix for Fold 1, Round 1:
# [[ 113   12    0    0    0    1]
#  [   0 1724    0    0    8    5]
#  [   0  110    0    0    0    2]
#  [  31   91    0    0    0    2]
#  [   0    0    0    0  108    0]
#  [   0    0    0    0    0  139]]
# Round 1/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2567, Accuracy: 0.8872, Precision: 0.7979, Recall: 0.8872, F1 Score: 0.8401, ROC AUC: 0.9701
# On Central Validation Data:
# Loss: 0.2552, Accuracy: 0.8883, Precision: 0.7993, Recall: 0.8883, F1 Score: 0.8414, ROC AUC: 0.9692
#
# Round 2/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8963, Loss: 0.2542, Precision: 0.8647, Recall: 0.8963, F1-Score: 0.8637, ROC-AUC: 0.9674
# Validation Epoch 1
# Accuracy: 0.8936, Loss: 0.2586, Precision: 0.8368, Recall: 0.8936, F1-Score: 0.8592, ROC-AUC: 0.9692
# Train Epoch 2
# Accuracy: 0.9041, Loss: 0.2264, Precision: 0.8625, Recall: 0.9041, F1-Score: 0.8698, ROC-AUC: 0.9702
# Validation Epoch 2
# Accuracy: 0.8986, Loss: 0.2389, Precision: 0.8530, Recall: 0.8986, F1-Score: 0.8622, ROC-AUC: 0.9675
# Train Epoch 3
# Accuracy: 0.9045, Loss: 0.2246, Precision: 0.8634, Recall: 0.9045, F1-Score: 0.8702, ROC-AUC: 0.9704
# Validation Epoch 3
# Accuracy: 0.8986, Loss: 0.2421, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9691
# Train Epoch 4
# Accuracy: 0.9043, Loss: 0.2243, Precision: 0.8635, Recall: 0.9043, F1-Score: 0.8702, ROC-AUC: 0.9706
# Validation Epoch 4
# Accuracy: 0.8986, Loss: 0.2401, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9685
# Train Epoch 5
# Accuracy: 0.9045, Loss: 0.2236, Precision: 0.8771, Recall: 0.9045, F1-Score: 0.8710, ROC-AUC: 0.9704
# Validation Epoch 5
# Accuracy: 0.8986, Loss: 0.2360, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9702
# Train Epoch 6
# Accuracy: 0.9048, Loss: 0.2206, Precision: 0.8637, Recall: 0.9048, F1-Score: 0.8705, ROC-AUC: 0.9717
# Validation Epoch 6
# Accuracy: 0.8986, Loss: 0.2377, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9711
# Train Epoch 7
# Accuracy: 0.9048, Loss: 0.2196, Precision: 0.8637, Recall: 0.9048, F1-Score: 0.8705, ROC-AUC: 0.9725
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2366, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9716
# Train Epoch 8
# Accuracy: 0.9048, Loss: 0.2199, Precision: 0.8638, Recall: 0.9048, F1-Score: 0.8706, ROC-AUC: 0.9717
# Validation Epoch 8
# Accuracy: 0.8986, Loss: 0.2370, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9715
# Train Epoch 9
# Accuracy: 0.9050, Loss: 0.2181, Precision: 0.8900, Recall: 0.9050, F1-Score: 0.8713, ROC-AUC: 0.9736
# Validation Epoch 9
# Accuracy: 0.8997, Loss: 0.2361, Precision: 0.8928, Recall: 0.8997, F1-Score: 0.8651, ROC-AUC: 0.9718
# Train Epoch 10
# Accuracy: 0.9052, Loss: 0.2201, Precision: 0.8947, Recall: 0.9052, F1-Score: 0.8726, ROC-AUC: 0.9741
# Validation Epoch 10
# Accuracy: 0.8969, Loss: 0.2380, Precision: 0.8735, Recall: 0.8969, F1-Score: 0.8632, ROC-AUC: 0.9718
# All metrics saved into CSV file.
# Client 1: Finished training. Returning model weights.
# Client 1 Combined Training and Validation Confusion Matrix:
# [[ 430   62    2    0    0    0]
#  [   0 6807    4   10    0    0]
#  [   0  472    9    2    0    0]
#  [   0  321    9  116    0    0]
#  [   0    0    0    0  379    0]
#  [   0    0    0    0    0  498]]
#
# Training on Client 2
# Client 2: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9005, Loss: 0.2357, Precision: 0.8587, Recall: 0.9005, F1-Score: 0.8658, ROC-AUC: 0.9681
# Validation Epoch 1
# Accuracy: 0.9013, Loss: 0.2370, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9713
# Train Epoch 2
# Accuracy: 0.8930, Loss: 0.2581, Precision: 0.8589, Recall: 0.8930, F1-Score: 0.8587, ROC-AUC: 0.9668
# Validation Epoch 2
# Accuracy: 0.8832, Loss: 0.2789, Precision: 0.7914, Recall: 0.8832, F1-Score: 0.8346, ROC-AUC: 0.9621
# Train Epoch 3
# Accuracy: 0.9005, Loss: 0.2369, Precision: 0.8593, Recall: 0.9005, F1-Score: 0.8655, ROC-AUC: 0.9688
# Validation Epoch 3
# Accuracy: 0.9013, Loss: 0.2360, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9702
# Train Epoch 4
# Accuracy: 0.9009, Loss: 0.2376, Precision: 0.8596, Recall: 0.9009, F1-Score: 0.8661, ROC-AUC: 0.9681
# Validation Epoch 4
# Accuracy: 0.9013, Loss: 0.2361, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9686
# Train Epoch 5
# Accuracy: 0.9009, Loss: 0.2310, Precision: 0.8596, Recall: 0.9009, F1-Score: 0.8661, ROC-AUC: 0.9688
# Validation Epoch 5
# Accuracy: 0.9013, Loss: 0.2334, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9687
# Train Epoch 6
# Accuracy: 0.9009, Loss: 0.2298, Precision: 0.8596, Recall: 0.9009, F1-Score: 0.8661, ROC-AUC: 0.9690
# Validation Epoch 6
# Accuracy: 0.9013, Loss: 0.2332, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9696
# Train Epoch 7
# Accuracy: 0.9009, Loss: 0.2297, Precision: 0.8596, Recall: 0.9009, F1-Score: 0.8661, ROC-AUC: 0.9700
# Validation Epoch 7
# Accuracy: 0.9013, Loss: 0.2331, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9697
# Train Epoch 8
# Accuracy: 0.9009, Loss: 0.2289, Precision: 0.8596, Recall: 0.9009, F1-Score: 0.8661, ROC-AUC: 0.9710
# Validation Epoch 8
# Accuracy: 0.9013, Loss: 0.2331, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9698
# Train Epoch 9
# Accuracy: 0.9009, Loss: 0.2294, Precision: 0.8596, Recall: 0.9009, F1-Score: 0.8661, ROC-AUC: 0.9698
# Validation Epoch 9
# Accuracy: 0.9013, Loss: 0.2332, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9699
# Train Epoch 10
# Accuracy: 0.9009, Loss: 0.2289, Precision: 0.8596, Recall: 0.9009, F1-Score: 0.8661, ROC-AUC: 0.9707
# Validation Epoch 10
# Accuracy: 0.9013, Loss: 0.2331, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9700
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 378   73    0    0    0    0]
#  [   0 6835    0    0    0    0]
#  [   0  481    0    0    1    0]
#  [   0  348    0  125    0    0]
#  [   0    0    0    0  409    0]
#  [   0    0    0    0    0  471]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9004, Loss: 0.2472, Precision: 0.8637, Recall: 0.9004, F1-Score: 0.8660, ROC-AUC: 0.9680
# Validation Epoch 1
# Accuracy: 0.8980, Loss: 0.2394, Precision: 0.8601, Recall: 0.8980, F1-Score: 0.8624, ROC-AUC: 0.9694
# Train Epoch 2
# Accuracy: 0.9046, Loss: 0.2294, Precision: 0.8665, Recall: 0.9046, F1-Score: 0.8699, ROC-AUC: 0.9679
# Validation Epoch 2
# Accuracy: 0.8986, Loss: 0.2366, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9682
# Train Epoch 3
# Accuracy: 0.9054, Loss: 0.2290, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9685
# Validation Epoch 3
# Accuracy: 0.8986, Loss: 0.2390, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9674
# Train Epoch 4
# Accuracy: 0.9054, Loss: 0.2256, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9682
# Validation Epoch 4
# Accuracy: 0.8986, Loss: 0.2393, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9684
# Train Epoch 5
# Accuracy: 0.9054, Loss: 0.2241, Precision: 0.9160, Recall: 0.9054, F1-Score: 0.8709, ROC-AUC: 0.9696
# Validation Epoch 5
# Accuracy: 0.8986, Loss: 0.2381, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9683
# Train Epoch 6
# Accuracy: 0.9054, Loss: 0.2235, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9705
# Validation Epoch 6
# Accuracy: 0.8986, Loss: 0.2361, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9685
# Train Epoch 7
# Accuracy: 0.9054, Loss: 0.2228, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9703
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2381, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9686
# Train Epoch 8
# Accuracy: 0.9054, Loss: 0.2232, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9698
# Validation Epoch 8
# Accuracy: 0.8986, Loss: 0.2378, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9684
# Train Epoch 9
# Accuracy: 0.9054, Loss: 0.2222, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9712
# Validation Epoch 9
# Accuracy: 0.8986, Loss: 0.2367, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9685
# Train Epoch 10
# Accuracy: 0.9054, Loss: 0.2219, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9715
# Validation Epoch 10
# Accuracy: 0.8986, Loss: 0.2364, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9686
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 372   84    0    0    0    0]
#  [   0 6860    0    0    0    0]
#  [   0  447    0    0    0    0]
#  [   0  343    0   80    0    0]
#  [   0    0    0    0  410    0]
#  [   0    0    0    0    1  524]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 1, Round 2:
# [[ 1180   221     0     0     0     0]
#  [    0 20496     8     0     0    12]
#  [    0  1396     8     0     0     8]
#  [    0  1022     2   318     0     0]
#  [    0     0     0     0  1198     0]
#  [    3     0     0     0     0  1491]]
# Global Model Validation Confusion Matrix for Fold 1, Round 2:
# [[ 113   13    0    0    0    0]
#  [   0 1736    1    0    0    0]
#  [   0  112    0    0    0    0]
#  [   0   93    0   31    0    0]
#  [   0    0    0    0  108    0]
#  [   0    0    0    0    0  139]]
# Round 2/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2292, Accuracy: 0.9023, Precision: 0.8850, Recall: 0.9023, F1 Score: 0.8682, ROC AUC: 0.9720
# On Central Validation Data:
# Loss: 0.2252, Accuracy: 0.9066, Precision: 0.8697, Recall: 0.9066, F1 Score: 0.8737, ROC AUC: 0.9713
#
# Round 3/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9032, Loss: 0.2312, Precision: 0.8620, Recall: 0.9032, F1-Score: 0.8690, ROC-AUC: 0.9703
# Validation Epoch 1
# Accuracy: 0.8975, Loss: 0.2448, Precision: 0.8519, Recall: 0.8975, F1-Score: 0.8612, ROC-AUC: 0.9697
# Train Epoch 2
# Accuracy: 0.9043, Loss: 0.2303, Precision: 0.8765, Recall: 0.9043, F1-Score: 0.8705, ROC-AUC: 0.9711
# Validation Epoch 2
# Accuracy: 0.8986, Loss: 0.2369, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9709
# Train Epoch 3
# Accuracy: 0.9037, Loss: 0.2299, Precision: 0.8619, Recall: 0.9037, F1-Score: 0.8694, ROC-AUC: 0.9707
# Validation Epoch 3
# Accuracy: 0.8980, Loss: 0.2398, Precision: 0.8525, Recall: 0.8980, F1-Score: 0.8617, ROC-AUC: 0.9711
# Train Epoch 4
# Accuracy: 0.9048, Loss: 0.2226, Precision: 0.8617, Recall: 0.9048, F1-Score: 0.8708, ROC-AUC: 0.9706
# Validation Epoch 4
# Accuracy: 0.8986, Loss: 0.2381, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9729
# Train Epoch 5
# Accuracy: 0.9032, Loss: 0.2347, Precision: 0.8825, Recall: 0.9032, F1-Score: 0.8694, ROC-AUC: 0.9698
# Validation Epoch 5
# Accuracy: 0.8986, Loss: 0.2385, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9712
# Train Epoch 6
# Accuracy: 0.9042, Loss: 0.2303, Precision: 0.8624, Recall: 0.9042, F1-Score: 0.8700, ROC-AUC: 0.9701
# Validation Epoch 6
# Accuracy: 0.8986, Loss: 0.2372, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9713
# Train Epoch 7
# Accuracy: 0.9045, Loss: 0.2219, Precision: 0.8636, Recall: 0.9045, F1-Score: 0.8703, ROC-AUC: 0.9715
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2369, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9713
# Train Epoch 8
# Accuracy: 0.9045, Loss: 0.2221, Precision: 0.8631, Recall: 0.9045, F1-Score: 0.8702, ROC-AUC: 0.9713
# Validation Epoch 8
# Accuracy: 0.8986, Loss: 0.2353, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9727
# Train Epoch 9
# Accuracy: 0.9045, Loss: 0.2213, Precision: 0.8634, Recall: 0.9045, F1-Score: 0.8702, ROC-AUC: 0.9736
# Validation Epoch 9
# Accuracy: 0.8986, Loss: 0.2353, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9727
# Train Epoch 10
# Accuracy: 0.9045, Loss: 0.2211, Precision: 0.8634, Recall: 0.9045, F1-Score: 0.8702, ROC-AUC: 0.9726
# Validation Epoch 10
# Accuracy: 0.8986, Loss: 0.2350, Precision: 0.8531, Recall: 0.8986, F1-Score: 0.8623, ROC-AUC: 0.9726
# All metrics saved into CSV file.
# Client 1: Finished training. Returning model weights.
# Client 1 Combined Training and Validation Confusion Matrix:
# [[ 430   64    0    0    0    0]
#  [   0 6821    0    0    0    0]
#  [   0  483    0    0    0    0]
#  [   0  333    0  113    0    0]
#  [   0    0    0    0  379    0]
#  [   0    0    0    0    2  496]]
#
# Training on Client 2
# Client 2: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8998, Loss: 0.2350, Precision: 0.8575, Recall: 0.8998, F1-Score: 0.8651, ROC-AUC: 0.9696
# Validation Epoch 1
# Accuracy: 0.9013, Loss: 0.2350, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9704
# Train Epoch 2
# Accuracy: 0.9009, Loss: 0.2304, Precision: 0.8861, Recall: 0.9009, F1-Score: 0.8663, ROC-AUC: 0.9699
# Validation Epoch 2
# Accuracy: 0.9013, Loss: 0.2345, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9689
# Train Epoch 3
# Accuracy: 0.9015, Loss: 0.2301, Precision: 0.9025, Recall: 0.9015, F1-Score: 0.8674, ROC-AUC: 0.9704
# Validation Epoch 3
# Accuracy: 0.9024, Loss: 0.2335, Precision: 0.8885, Recall: 0.9024, F1-Score: 0.8707, ROC-AUC: 0.9704
# Train Epoch 4
# Accuracy: 0.9009, Loss: 0.2305, Precision: 0.8776, Recall: 0.9009, F1-Score: 0.8691, ROC-AUC: 0.9698
# Validation Epoch 4
# Accuracy: 0.9013, Loss: 0.2343, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9698
# Train Epoch 5
# Accuracy: 0.9008, Loss: 0.2299, Precision: 0.8688, Recall: 0.9008, F1-Score: 0.8664, ROC-AUC: 0.9700
# Validation Epoch 5
# Accuracy: 0.9013, Loss: 0.2328, Precision: 0.8601, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9704
# Train Epoch 6
# Accuracy: 0.8865, Loss: 0.2863, Precision: 0.8639, Recall: 0.8865, F1-Score: 0.8559, ROC-AUC: 0.9675
# Validation Epoch 6
# Accuracy: 0.8783, Loss: 0.3049, Precision: 0.7865, Recall: 0.8783, F1-Score: 0.8297, ROC-AUC: 0.9588
# Train Epoch 7
# Accuracy: 0.8854, Loss: 0.2647, Precision: 0.7949, Recall: 0.8854, F1-Score: 0.8367, ROC-AUC: 0.9651
# Validation Epoch 7
# Accuracy: 0.8860, Loss: 0.2609, Precision: 0.7952, Recall: 0.8860, F1-Score: 0.8370, ROC-AUC: 0.9675
# Train Epoch 8
# Accuracy: 0.8872, Loss: 0.2530, Precision: 0.7974, Recall: 0.8872, F1-Score: 0.8385, ROC-AUC: 0.9679
# Validation Epoch 8
# Accuracy: 0.9008, Loss: 0.2539, Precision: 0.8595, Recall: 0.9008, F1-Score: 0.8662, ROC-AUC: 0.9689
# Train Epoch 9
# Accuracy: 0.8987, Loss: 0.2437, Precision: 0.8564, Recall: 0.8987, F1-Score: 0.8626, ROC-AUC: 0.9695
# Validation Epoch 9
# Accuracy: 0.9008, Loss: 0.2451, Precision: 0.8595, Recall: 0.9008, F1-Score: 0.8662, ROC-AUC: 0.9684
# Train Epoch 10
# Accuracy: 0.9009, Loss: 0.2386, Precision: 0.8857, Recall: 0.9009, F1-Score: 0.8663, ROC-AUC: 0.9686
# Validation Epoch 10
# Accuracy: 0.9008, Loss: 0.2427, Precision: 0.8595, Recall: 0.9008, F1-Score: 0.8662, ROC-AUC: 0.9690
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 378   73    0    0    0    0]
#  [   0 6829    0    4    2    0]
#  [   0  482    0    0    0    0]
#  [   0  346    1  126    0    0]
#  [   0    0    0    0  409    0]
#  [   0    0    0    0    0  471]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9041, Loss: 0.2315, Precision: 0.8770, Recall: 0.9041, F1-Score: 0.8696, ROC-AUC: 0.9683
# Validation Epoch 1
# Accuracy: 0.8986, Loss: 0.2427, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9696
# Train Epoch 2
# Accuracy: 0.9023, Loss: 0.2504, Precision: 0.8632, Recall: 0.9023, F1-Score: 0.8671, ROC-AUC: 0.9670
# Validation Epoch 2
# Accuracy: 0.8986, Loss: 0.2366, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9674
# Train Epoch 3
# Accuracy: 0.9053, Loss: 0.2249, Precision: 0.8666, Recall: 0.9053, F1-Score: 0.8706, ROC-AUC: 0.9690
# Validation Epoch 3
# Accuracy: 0.8980, Loss: 0.2508, Precision: 0.8601, Recall: 0.8980, F1-Score: 0.8624, ROC-AUC: 0.9672
# Train Epoch 4
# Accuracy: 0.9054, Loss: 0.2241, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9693
# Validation Epoch 4
# Accuracy: 0.8986, Loss: 0.2381, Precision: 0.8607, Recall: 0.8986, F1-Score: 0.8629, ROC-AUC: 0.9670
# Train Epoch 5
# Accuracy: 0.9056, Loss: 0.2285, Precision: 0.8673, Recall: 0.9056, F1-Score: 0.8708, ROC-AUC: 0.9706
# Validation Epoch 5
# Accuracy: 0.8980, Loss: 0.2397, Precision: 0.8601, Recall: 0.8980, F1-Score: 0.8624, ROC-AUC: 0.9672
# Train Epoch 6
# Accuracy: 0.9056, Loss: 0.2254, Precision: 0.8673, Recall: 0.9056, F1-Score: 0.8708, ROC-AUC: 0.9704
# Validation Epoch 6
# Accuracy: 0.8980, Loss: 0.2403, Precision: 0.8601, Recall: 0.8980, F1-Score: 0.8624, ROC-AUC: 0.9679
# Train Epoch 7
# Accuracy: 0.9056, Loss: 0.2220, Precision: 0.8673, Recall: 0.9056, F1-Score: 0.8708, ROC-AUC: 0.9702
# Validation Epoch 7
# Accuracy: 0.8980, Loss: 0.2425, Precision: 0.8599, Recall: 0.8980, F1-Score: 0.8623, ROC-AUC: 0.9681
# Train Epoch 8
# Accuracy: 0.9056, Loss: 0.2209, Precision: 0.8673, Recall: 0.9056, F1-Score: 0.8708, ROC-AUC: 0.9720
# Validation Epoch 8
# Accuracy: 0.8980, Loss: 0.2411, Precision: 0.8601, Recall: 0.8980, F1-Score: 0.8624, ROC-AUC: 0.9685
# Train Epoch 9
# Accuracy: 0.9054, Loss: 0.2210, Precision: 0.8672, Recall: 0.9054, F1-Score: 0.8707, ROC-AUC: 0.9721
# Validation Epoch 9
# Accuracy: 0.8980, Loss: 0.2401, Precision: 0.8601, Recall: 0.8980, F1-Score: 0.8624, ROC-AUC: 0.9686
# Train Epoch 10
# Accuracy: 0.9056, Loss: 0.2210, Precision: 0.8673, Recall: 0.9056, F1-Score: 0.8708, ROC-AUC: 0.9726
# Validation Epoch 10
# Accuracy: 0.8980, Loss: 0.2413, Precision: 0.8601, Recall: 0.8980, F1-Score: 0.8624, ROC-AUC: 0.9684
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 372   84    0    0    0    0]
#  [   0 6859    0    0    1    0]
#  [   0  447    0    0    0    0]
#  [   0  343    0   80    0    0]
#  [   0    0    0    0  410    0]
#  [   0    0    0    0    0  525]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 1, Round 3:
# [[ 1180   221     0     0     0     0]
#  [    0 20501     0    10     4     1]
#  [    0  1408     0     2     2     0]
#  [  318  1019     0     4     0     1]
#  [    0     0     0     0  1198     0]
#  [    3     0     0     0     0  1491]]
# Global Model Validation Confusion Matrix for Fold 1, Round 3:
# [[ 113   13    0    0    0    0]
#  [   0 1737    0    0    0    0]
#  [   0  111    0    1    0    0]
#  [  31   92    0    0    0    1]
#  [   0    0    0    0  108    0]
#  [   0    0    0    0    0  139]]
# Round 3/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2576, Accuracy: 0.8908, Precision: 0.8146, Recall: 0.8908, F1 Score: 0.8442, ROC AUC: 0.9664
# On Central Validation Data:
# Loss: 0.2592, Accuracy: 0.8939, Precision: 0.8055, Recall: 0.8939, F1 Score: 0.8471, ROC AUC: 0.9646
# Global model metrics over rounds saved into CSV file.
# Final Global Model Confusion Matrix on Combined Client Data for Fold 1:
# [[ 1180   221     0     0     0     0]
#  [    0 20501     0    10     4     1]
#  [    0  1408     0     2     2     0]
#  [  318  1019     0     4     0     1]
#  [    0     0     0     0  1198     0]
#  [    3     0     0     0     0  1491]]
# Final Global Model Validation Confusion Matrix for Fold 1:
# [[ 113   13    0    0    0    0]
#  [   0 1737    0    0    0    0]
#  [   0  111    0    1    0    0]
#  [  31   92    0    0    0    1]
#  [   0    0    0    0  108    0]
#  [   0    0    0    0    0  139]]
#
# Fold 2/5
#
# Round 1/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.7990, Loss: 0.5393, Precision: 0.7508, Recall: 0.7990, F1-Score: 0.7602, ROC-AUC: 0.9174
# Validation Epoch 1
# Accuracy: 0.9002, Loss: 0.2681, Precision: 0.8627, Recall: 0.9002, F1-Score: 0.8655, ROC-AUC: 0.9657
# Train Epoch 2
# Accuracy: 0.8961, Loss: 0.2465, Precision: 0.8718, Recall: 0.8961, F1-Score: 0.8725, ROC-AUC: 0.9695
# Validation Epoch 2
# Accuracy: 0.9019, Loss: 0.2551, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9653
# Train Epoch 3
# Accuracy: 0.9023, Loss: 0.2290, Precision: 0.8697, Recall: 0.9023, F1-Score: 0.8693, ROC-AUC: 0.9706
# Validation Epoch 3
# Accuracy: 0.8575, Loss: 0.2545, Precision: 0.9084, Recall: 0.8575, F1-Score: 0.8672, ROC-AUC: 0.9662
# Train Epoch 4
# Accuracy: 0.8952, Loss: 0.2572, Precision: 0.8620, Recall: 0.8952, F1-Score: 0.8639, ROC-AUC: 0.9698
# Validation Epoch 4
# Accuracy: 0.9019, Loss: 0.2426, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9663
# Train Epoch 5
# Accuracy: 0.9016, Loss: 0.2261, Precision: 0.8493, Recall: 0.9016, F1-Score: 0.8697, ROC-AUC: 0.9707
# Validation Epoch 5
# Accuracy: 0.9019, Loss: 0.2410, Precision: 0.8644, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9710
# Train Epoch 6
# Accuracy: 0.9037, Loss: 0.2219, Precision: 0.8606, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9718
# Validation Epoch 6
# Accuracy: 0.9019, Loss: 0.2369, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9714
# Train Epoch 7
# Accuracy: 0.9037, Loss: 0.2227, Precision: 0.8607, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9701
# Validation Epoch 7
# Accuracy: 0.9019, Loss: 0.2413, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9693
# Train Epoch 8
# Accuracy: 0.9037, Loss: 0.2221, Precision: 0.8606, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9713
# Validation Epoch 8
# Accuracy: 0.9019, Loss: 0.2366, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9697
# Train Epoch 9
# Accuracy: 0.9037, Loss: 0.2205, Precision: 0.8607, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9726
# Validation Epoch 9
# Accuracy: 0.9019, Loss: 0.2378, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9692
# Train Epoch 10
# Accuracy: 0.9037, Loss: 0.2204, Precision: 0.8606, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9727
# Validation Epoch 10
# Accuracy: 0.9019, Loss: 0.2371, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9693
# All metrics saved into CSV file.
# Client 1: Finished training. Returning model weights.
# Client 1 Combined Training and Validation Confusion Matrix:
# [[ 430   64    0    0    0    0]
#  [   0 6821    0    0    0    0]
#  [   0  483    0    0    0    0]
#  [   0  333    0  113    0    0]
#  [   0    0    0    0  379    0]
#  [   0    0    0    0    2  496]]
#
# Training on Client 2
# Client 2: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8102, Loss: 0.5138, Precision: 0.7689, Recall: 0.8102, F1-Score: 0.7716, ROC-AUC: 0.9247
# Validation Epoch 1
# Accuracy: 0.8613, Loss: 0.2713, Precision: 0.8532, Recall: 0.8613, F1-Score: 0.8567, ROC-AUC: 0.9670
# Train Epoch 2
# Accuracy: 0.8930, Loss: 0.2647, Precision: 0.8585, Recall: 0.8930, F1-Score: 0.8643, ROC-AUC: 0.9675
# Validation Epoch 2
# Accuracy: 0.8745, Loss: 0.2392, Precision: 0.9147, Recall: 0.8745, F1-Score: 0.8814, ROC-AUC: 0.9710
# Train Epoch 3
# Accuracy: 0.8974, Loss: 0.2395, Precision: 0.8576, Recall: 0.8974, F1-Score: 0.8683, ROC-AUC: 0.9690
# Validation Epoch 3
# Accuracy: 0.8986, Loss: 0.2273, Precision: 0.8582, Recall: 0.8986, F1-Score: 0.8637, ROC-AUC: 0.9719
# Train Epoch 4
# Accuracy: 0.9002, Loss: 0.2344, Precision: 0.8741, Recall: 0.9002, F1-Score: 0.8699, ROC-AUC: 0.9697
# Validation Epoch 4
# Accuracy: 0.8986, Loss: 0.2305, Precision: 0.8873, Recall: 0.8986, F1-Score: 0.8773, ROC-AUC: 0.9717
# Train Epoch 5
# Accuracy: 0.8865, Loss: 0.2752, Precision: 0.8584, Recall: 0.8865, F1-Score: 0.8541, ROC-AUC: 0.9657
# Validation Epoch 5
# Accuracy: 0.8997, Loss: 0.2428, Precision: 0.8583, Recall: 0.8997, F1-Score: 0.8642, ROC-AUC: 0.9706
# Train Epoch 6
# Accuracy: 0.9019, Loss: 0.2373, Precision: 0.8816, Recall: 0.9019, F1-Score: 0.8708, ROC-AUC: 0.9710
# Validation Epoch 6
# Accuracy: 0.8997, Loss: 0.2301, Precision: 0.8583, Recall: 0.8997, F1-Score: 0.8642, ROC-AUC: 0.9725
# Train Epoch 7
# Accuracy: 0.9013, Loss: 0.2355, Precision: 0.8835, Recall: 0.9013, F1-Score: 0.8771, ROC-AUC: 0.9703
# Validation Epoch 7
# Accuracy: 0.9002, Loss: 0.2300, Precision: 0.8588, Recall: 0.9002, F1-Score: 0.8652, ROC-AUC: 0.9702
# Train Epoch 8
# Accuracy: 0.9019, Loss: 0.2321, Precision: 0.8950, Recall: 0.9019, F1-Score: 0.8680, ROC-AUC: 0.9699
# Validation Epoch 8
# Accuracy: 0.8975, Loss: 0.2275, Precision: 0.8744, Recall: 0.8975, F1-Score: 0.8718, ROC-AUC: 0.9712
# Train Epoch 9
# Accuracy: 0.9017, Loss: 0.2320, Precision: 0.8809, Recall: 0.9017, F1-Score: 0.8724, ROC-AUC: 0.9695
# Validation Epoch 9
# Accuracy: 0.8997, Loss: 0.2304, Precision: 0.8583, Recall: 0.8997, F1-Score: 0.8642, ROC-AUC: 0.9723
# Train Epoch 10
# Accuracy: 0.9016, Loss: 0.2318, Precision: 0.8806, Recall: 0.9016, F1-Score: 0.8710, ROC-AUC: 0.9697
# Validation Epoch 10
# Accuracy: 0.8997, Loss: 0.2265, Precision: 0.8583, Recall: 0.8997, F1-Score: 0.8642, ROC-AUC: 0.9723
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 378   73    0    0    0    0]
#  [   0 6835    0    0    0    0]
#  [   0  482    0    0    0    0]
#  [   0  348    0  125    0    0]
#  [   0    0    0    0  409    0]
#  [   0    0    0    0    0  471]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.7921, Loss: 0.5459, Precision: 0.7468, Recall: 0.7921, F1-Score: 0.7519, ROC-AUC: 0.9138
# Validation Epoch 1
# Accuracy: 0.9145, Loss: 0.2472, Precision: 0.8815, Recall: 0.9145, F1-Score: 0.8869, ROC-AUC: 0.9721
# Train Epoch 2
# Accuracy: 0.8924, Loss: 0.2650, Precision: 0.8586, Recall: 0.8924, F1-Score: 0.8662, ROC-AUC: 0.9669
# Validation Epoch 2
# Accuracy: 0.9194, Loss: 0.2135, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9709
# Train Epoch 3
# Accuracy: 0.8956, Loss: 0.2417, Precision: 0.8712, Recall: 0.8956, F1-Score: 0.8683, ROC-AUC: 0.9679
# Validation Epoch 3
# Accuracy: 0.9194, Loss: 0.2061, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9715
# Train Epoch 4
# Accuracy: 0.9001, Loss: 0.2355, Precision: 0.8609, Recall: 0.9001, F1-Score: 0.8634, ROC-AUC: 0.9677
# Validation Epoch 4
# Accuracy: 0.9194, Loss: 0.2049, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9726
# Train Epoch 5
# Accuracy: 0.8861, Loss: 0.2837, Precision: 0.8481, Recall: 0.8861, F1-Score: 0.8481, ROC-AUC: 0.9642
# Validation Epoch 5
# Accuracy: 0.9073, Loss: 0.2738, Precision: 0.8836, Recall: 0.9073, F1-Score: 0.8856, ROC-AUC: 0.9707
# Train Epoch 6
# Accuracy: 0.8987, Loss: 0.2430, Precision: 0.8634, Recall: 0.8987, F1-Score: 0.8628, ROC-AUC: 0.9690
# Validation Epoch 6
# Accuracy: 0.9167, Loss: 0.2127, Precision: 0.8841, Recall: 0.9167, F1-Score: 0.8893, ROC-AUC: 0.9718
# Train Epoch 7
# Accuracy: 0.9005, Loss: 0.2350, Precision: 0.8953, Recall: 0.9005, F1-Score: 0.8642, ROC-AUC: 0.9684
# Validation Epoch 7
# Accuracy: 0.9189, Loss: 0.2080, Precision: 0.8854, Recall: 0.9189, F1-Score: 0.8910, ROC-AUC: 0.9715
# Train Epoch 8
# Accuracy: 0.9002, Loss: 0.2333, Precision: 0.8852, Recall: 0.9002, F1-Score: 0.8638, ROC-AUC: 0.9685
# Validation Epoch 8
# Accuracy: 0.9178, Loss: 0.2074, Precision: 0.8853, Recall: 0.9178, F1-Score: 0.8904, ROC-AUC: 0.9716
# Train Epoch 9
# Accuracy: 0.9008, Loss: 0.2330, Precision: 0.9124, Recall: 0.9008, F1-Score: 0.8648, ROC-AUC: 0.9687
# Validation Epoch 9
# Accuracy: 0.9189, Loss: 0.2066, Precision: 0.8854, Recall: 0.9189, F1-Score: 0.8910, ROC-AUC: 0.9718
# Train Epoch 10
# Accuracy: 0.9004, Loss: 0.2318, Precision: 0.9120, Recall: 0.9004, F1-Score: 0.8638, ROC-AUC: 0.9703
# Validation Epoch 10
# Accuracy: 0.9178, Loss: 0.2078, Precision: 0.8853, Recall: 0.9178, F1-Score: 0.8904, ROC-AUC: 0.9717
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 372   84    0    0    0    0]
#  [   0 6856    3    0    0    1]
#  [   0  446    1    0    0    0]
#  [   0  343    0   80    0    0]
#  [   0    0    0    0  410    0]
#  [   0    1    0    0    0  524]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 2, Round 1:
# [[ 1180   214     0     0     0     7]
#  [    0 20463     2     0     2    49]
#  [    0  1379     3     0     0    30]
#  [    0  1004     2   318     1    17]
#  [    0     0     0     0  1198     0]
#  [    0     0     0     0     3  1491]]
# Global Model Validation Confusion Matrix for Fold 2, Round 1:
# [[ 101   26    0    0    0    0]
#  [   0 1742    0    0    0    5]
#  [   0  110    0    0    0    2]
#  [   0  104    1   27    0    0]
#  [   0    0    0    0  110    0]
#  [   0    0    0    0    0  117]]
# Round 1/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2379, Accuracy: 0.9010, Precision: 0.8823, Recall: 0.9010, F1 Score: 0.8664, ROC AUC: 0.9705
# On Central Validation Data:
# Loss: 0.2509, Accuracy: 0.8942, Precision: 0.8592, Recall: 0.8942, F1 Score: 0.8585, ROC AUC: 0.9680
#
# Round 2/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9034, Loss: 0.2267, Precision: 0.8604, Recall: 0.9034, F1-Score: 0.8688, ROC-AUC: 0.9695
# Validation Epoch 1
# Accuracy: 0.9019, Loss: 0.2408, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9678
# Train Epoch 2
# Accuracy: 0.9011, Loss: 0.2359, Precision: 0.8572, Recall: 0.9011, F1-Score: 0.8662, ROC-AUC: 0.9704
# Validation Epoch 2
# Accuracy: 0.9019, Loss: 0.2396, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9683
# Train Epoch 3
# Accuracy: 0.9035, Loss: 0.2250, Precision: 0.8605, Recall: 0.9035, F1-Score: 0.8689, ROC-AUC: 0.9704
# Validation Epoch 3
# Accuracy: 0.9002, Loss: 0.2409, Precision: 0.8624, Recall: 0.9002, F1-Score: 0.8653, ROC-AUC: 0.9678
# Train Epoch 4
# Accuracy: 0.9035, Loss: 0.2244, Precision: 0.8607, Recall: 0.9035, F1-Score: 0.8690, ROC-AUC: 0.9696
# Validation Epoch 4
# Accuracy: 0.9019, Loss: 0.2392, Precision: 0.8644, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9702
# Train Epoch 5
# Accuracy: 0.9037, Loss: 0.2283, Precision: 0.8606, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9722
# Validation Epoch 5
# Accuracy: 0.9019, Loss: 0.2381, Precision: 0.8644, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9702
# Train Epoch 6
# Accuracy: 0.9037, Loss: 0.2205, Precision: 0.8607, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9723
# Validation Epoch 6
# Accuracy: 0.9019, Loss: 0.2373, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9709
# Train Epoch 7
# Accuracy: 0.9037, Loss: 0.2200, Precision: 0.8610, Recall: 0.9037, F1-Score: 0.8692, ROC-AUC: 0.9727
# Validation Epoch 7
# Accuracy: 0.9019, Loss: 0.2356, Precision: 0.8644, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9712
# Train Epoch 8
# Accuracy: 0.9037, Loss: 0.2192, Precision: 0.8607, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9735
# Validation Epoch 8
# Accuracy: 0.9019, Loss: 0.2352, Precision: 0.8644, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9711
# Train Epoch 9
# Accuracy: 0.9037, Loss: 0.2192, Precision: 0.8609, Recall: 0.9037, F1-Score: 0.8691, ROC-AUC: 0.9734
# Validation Epoch 9
# Accuracy: 0.9019, Loss: 0.2350, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9712
# Train Epoch 10
# Accuracy: 0.9039, Loss: 0.2179, Precision: 0.8969, Recall: 0.9039, F1-Score: 0.8697, ROC-AUC: 0.9746
# Validation Epoch 10
# Accuracy: 0.9019, Loss: 0.2349, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9714
# All metrics saved into CSV file.
# Client 1: Finished training. Returning model weights.
# Client 1 Combined Training and Validation Confusion Matrix:
# [[ 430   64    0    0    0    0]
#  [   0 6821    0    0    0    0]
#  [   0  483    0    0    0    0]
#  [   0  333    0  113    0    0]
#  [   0    0    0    0  379    0]
#  [   0    0    0    0    2  496]]
#
# Training on Client 2
# Client 2: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9011, Loss: 0.2354, Precision: 0.8805, Recall: 0.9011, F1-Score: 0.8681, ROC-AUC: 0.9683
# Validation Epoch 1
# Accuracy: 0.9008, Loss: 0.2296, Precision: 0.8993, Recall: 0.9008, F1-Score: 0.8678, ROC-AUC: 0.9713
# Train Epoch 2
# Accuracy: 0.9012, Loss: 0.2412, Precision: 0.8651, Recall: 0.9012, F1-Score: 0.8674, ROC-AUC: 0.9695
# Validation Epoch 2
# Accuracy: 0.8997, Loss: 0.2266, Precision: 0.8588, Recall: 0.8997, F1-Score: 0.8645, ROC-AUC: 0.9720
# Train Epoch 3
# Accuracy: 0.8852, Loss: 0.2847, Precision: 0.8376, Recall: 0.8852, F1-Score: 0.8514, ROC-AUC: 0.9676
# Validation Epoch 3
# Accuracy: 0.8322, Loss: 0.4134, Precision: 0.8061, Recall: 0.8322, F1-Score: 0.7982, ROC-AUC: 0.9544
# Train Epoch 4
# Accuracy: 0.8982, Loss: 0.2395, Precision: 0.8766, Recall: 0.8982, F1-Score: 0.8650, ROC-AUC: 0.9701
# Validation Epoch 4
# Accuracy: 0.8997, Loss: 0.2306, Precision: 0.8583, Recall: 0.8997, F1-Score: 0.8642, ROC-AUC: 0.9701
# Train Epoch 5
# Accuracy: 0.9013, Loss: 0.2311, Precision: 0.8600, Recall: 0.9013, F1-Score: 0.8667, ROC-AUC: 0.9700
# Validation Epoch 5
# Accuracy: 0.8997, Loss: 0.2287, Precision: 0.8583, Recall: 0.8997, F1-Score: 0.8642, ROC-AUC: 0.9713
# Train Epoch 6
# Accuracy: 0.9015, Loss: 0.2305, Precision: 0.8868, Recall: 0.9015, F1-Score: 0.8676, ROC-AUC: 0.9702
# Validation Epoch 6
# Accuracy: 0.8997, Loss: 0.2290, Precision: 0.8583, Recall: 0.8997, F1-Score: 0.8642, ROC-AUC: 0.9715
# Train Epoch 7
# Accuracy: 0.9019, Loss: 0.2328, Precision: 0.8913, Recall: 0.9019, F1-Score: 0.8688, ROC-AUC: 0.9706
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2282, Precision: 0.8670, Recall: 0.8986, F1-Score: 0.8656, ROC-AUC: 0.9716
# Train Epoch 8
# Accuracy: 0.9013, Loss: 0.2326, Precision: 0.8794, Recall: 0.9013, F1-Score: 0.8682, ROC-AUC: 0.9704
# Validation Epoch 8
# Accuracy: 0.8991, Loss: 0.2282, Precision: 0.8680, Recall: 0.8991, F1-Score: 0.8659, ROC-AUC: 0.9716
# Train Epoch 9
# Accuracy: 0.9020, Loss: 0.2294, Precision: 0.8882, Recall: 0.9020, F1-Score: 0.8696, ROC-AUC: 0.9714
# Validation Epoch 9
# Accuracy: 0.8991, Loss: 0.2283, Precision: 0.8680, Recall: 0.8991, F1-Score: 0.8659, ROC-AUC: 0.9717
# Train Epoch 10
# Accuracy: 0.9019, Loss: 0.2289, Precision: 0.8888, Recall: 0.9019, F1-Score: 0.8694, ROC-AUC: 0.9714
# Validation Epoch 10
# Accuracy: 0.8986, Loss: 0.2282, Precision: 0.8654, Recall: 0.8986, F1-Score: 0.8657, ROC-AUC: 0.9717
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 378   72    1    0    0    0]
#  [   0 6823    9    3    0    0]
#  [   0  462   17    3    0    0]
#  [   0  331   13  129    0    0]
#  [   0    0    0    0  409    0]
#  [   0    0    0    0    0  471]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8989, Loss: 0.2397, Precision: 0.8564, Recall: 0.8989, F1-Score: 0.8624, ROC-AUC: 0.9686
# Validation Epoch 1
# Accuracy: 0.9194, Loss: 0.2045, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9712
# Train Epoch 2
# Accuracy: 0.9004, Loss: 0.2391, Precision: 0.8833, Recall: 0.9004, F1-Score: 0.8658, ROC-AUC: 0.9687
# Validation Epoch 2
# Accuracy: 0.9194, Loss: 0.2043, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9746
# Train Epoch 3
# Accuracy: 0.8976, Loss: 0.2416, Precision: 0.8765, Recall: 0.8976, F1-Score: 0.8670, ROC-AUC: 0.9665
# Validation Epoch 3
# Accuracy: 0.9194, Loss: 0.2013, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9729
# Train Epoch 4
# Accuracy: 0.8993, Loss: 0.2391, Precision: 0.8552, Recall: 0.8993, F1-Score: 0.8630, ROC-AUC: 0.9683
# Validation Epoch 4
# Accuracy: 0.9189, Loss: 0.2012, Precision: 0.8854, Recall: 0.9189, F1-Score: 0.8910, ROC-AUC: 0.9751
# Train Epoch 5
# Accuracy: 0.9002, Loss: 0.2321, Precision: 0.8609, Recall: 0.9002, F1-Score: 0.8635, ROC-AUC: 0.9687
# Validation Epoch 5
# Accuracy: 0.9194, Loss: 0.2008, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9751
# Train Epoch 6
# Accuracy: 0.9002, Loss: 0.2323, Precision: 0.8609, Recall: 0.9002, F1-Score: 0.8635, ROC-AUC: 0.9703
# Validation Epoch 6
# Accuracy: 0.9194, Loss: 0.2007, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9748
# Train Epoch 7
# Accuracy: 0.9002, Loss: 0.2313, Precision: 0.8609, Recall: 0.9002, F1-Score: 0.8635, ROC-AUC: 0.9692
# Validation Epoch 7
# Accuracy: 0.9194, Loss: 0.2013, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9742
# Train Epoch 8
# Accuracy: 0.9002, Loss: 0.2364, Precision: 0.8610, Recall: 0.9002, F1-Score: 0.8635, ROC-AUC: 0.9703
# Validation Epoch 8
# Accuracy: 0.9189, Loss: 0.2015, Precision: 0.8854, Recall: 0.9189, F1-Score: 0.8910, ROC-AUC: 0.9739
# Train Epoch 9
# Accuracy: 0.9002, Loss: 0.2304, Precision: 0.8610, Recall: 0.9002, F1-Score: 0.8635, ROC-AUC: 0.9700
# Validation Epoch 9
# Accuracy: 0.9189, Loss: 0.2016, Precision: 0.8854, Recall: 0.9189, F1-Score: 0.8910, ROC-AUC: 0.9740
# Train Epoch 10
# Accuracy: 0.9002, Loss: 0.2298, Precision: 0.8610, Recall: 0.9002, F1-Score: 0.8635, ROC-AUC: 0.9701
# Validation Epoch 10
# Accuracy: 0.9194, Loss: 0.2013, Precision: 0.8860, Recall: 0.9194, F1-Score: 0.8915, ROC-AUC: 0.9740
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 372   84    0    0    0    0]
#  [   0 6860    0    0    0    0]
#  [   0  447    0    0    0    0]
#  [   0  343    0   80    0    0]
#  [   0    0    0    0  410    0]
#  [   0    0    0    0    1  524]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 2, Round 2:
# [[ 1180   221     0     0     0     0]
#  [    0 20514     2     0     0     0]
#  [    0  1410     2     0     0     0]
#  [    0  1021     2   318     0     1]
#  [    0     0     0     0  1198     0]
#  [    0     0     0     0     3  1491]]
# Global Model Validation Confusion Matrix for Fold 2, Round 2:
# [[ 101   26    0    0    0    0]
#  [   0 1747    0    0    0    0]
#  [   0  111    1    0    0    0]
#  [   0  105    0   27    0    0]
#  [   0    0    0    0  110    0]
#  [   0    0    0    0    0  117]]
# Round 2/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2263, Accuracy: 0.9028, Precision: 0.8796, Recall: 0.9028, F1 Score: 0.8682, ROC AUC: 0.9716
# On Central Validation Data:
# Loss: 0.2418, Accuracy: 0.8968, Precision: 0.9094, Recall: 0.8968, F1 Score: 0.8615, ROC AUC: 0.9689
#
# Round 3/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9019, Loss: 0.2346, Precision: 0.8571, Recall: 0.9019, F1-Score: 0.8675, ROC-AUC: 0.9693
# Validation Epoch 1
# Accuracy: 0.9019, Loss: 0.2472, Precision: 0.8642, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9649
# Train Epoch 2
# Accuracy: 0.9035, Loss: 0.2243, Precision: 0.8597, Recall: 0.9035, F1-Score: 0.8689, ROC-AUC: 0.9696
# Validation Epoch 2
# Accuracy: 0.9019, Loss: 0.2412, Precision: 0.8642, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9692
# Train Epoch 3
# Accuracy: 0.9037, Loss: 0.2258, Precision: 0.8607, Recall: 0.9037, F1-Score: 0.8690, ROC-AUC: 0.9710
# Validation Epoch 3
# Accuracy: 0.9019, Loss: 0.2404, Precision: 0.8643, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9694
# Train Epoch 4
# Accuracy: 0.9024, Loss: 0.2259, Precision: 0.8742, Recall: 0.9024, F1-Score: 0.8693, ROC-AUC: 0.9704
# Validation Epoch 4
# Accuracy: 0.9019, Loss: 0.2409, Precision: 0.8644, Recall: 0.9019, F1-Score: 0.8670, ROC-AUC: 0.9668
# Train Epoch 5
# ...
# Accuracy: 0.8991, Loss: 0.2318, Precision: 0.9112, Recall: 0.8991, F1-Score: 0.8639, ROC-AUC: 0.9690
# Train Epoch 3
# Accuracy: 0.8998, Loss: 0.2322, Precision: 0.8632, Recall: 0.8998, F1-Score: 0.8672, ROC-AUC: 0.9707
# Validation Epoch 3
# Accuracy: 0.8871, Loss: 0.2477, Precision: 0.8361, Recall: 0.8871, F1-Score: 0.8599, ROC-AUC: 0.9696
# Train Epoch 4
# Accuracy: 0.9016, Loss: 0.2319, Precision: 0.8854, Recall: 0.9016, F1-Score: 0.8690, ROC-AUC: 0.9698
# Validation Epoch 4
# Accuracy: 0.8986, Loss: 0.2370, Precision: 0.8679, Recall: 0.8986, F1-Score: 0.8645, ROC-AUC: 0.9695
# Train Epoch 5
# Accuracy: 0.9020, Loss: 0.2606, Precision: 0.8910, Recall: 0.9020, F1-Score: 0.8696, ROC-AUC: 0.9701
# Validation Epoch 5
# Accuracy: 0.8980, Loss: 0.2346, Precision: 0.8520, Recall: 0.8980, F1-Score: 0.8622, ROC-AUC: 0.9690
# Train Epoch 6
# Accuracy: 0.9012, Loss: 0.2307, Precision: 0.8765, Recall: 0.9012, F1-Score: 0.8673, ROC-AUC: 0.9717
# Validation Epoch 6
# Accuracy: 0.8986, Loss: 0.2327, Precision: 0.8570, Recall: 0.8986, F1-Score: 0.8626, ROC-AUC: 0.9699
# Train Epoch 7
# Accuracy: 0.9017, Loss: 0.2283, Precision: 0.8605, Recall: 0.9017, F1-Score: 0.8673, ROC-AUC: 0.9721
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2317, Precision: 0.8570, Recall: 0.8986, F1-Score: 0.8626, ROC-AUC: 0.9707
# Train Epoch 8
# Accuracy: 0.9011, Loss: 0.2286, Precision: 0.8684, Recall: 0.9011, F1-Score: 0.8671, ROC-AUC: 0.9718
# Validation Epoch 8
# Accuracy: 0.8980, Loss: 0.2344, Precision: 0.8549, Recall: 0.8980, F1-Score: 0.8621, ROC-AUC: 0.9703
# Train Epoch 9
# Accuracy: 0.9011, Loss: 0.2274, Precision: 0.8752, Recall: 0.9011, F1-Score: 0.8676, ROC-AUC: 0.9724
# Validation Epoch 9
# Accuracy: 0.8986, Loss: 0.2333, Precision: 0.9091, Recall: 0.8986, F1-Score: 0.8634, ROC-AUC: 0.9707
# Train Epoch 10
# Accuracy: 0.9017, Loss: 0.2263, Precision: 0.8838, Recall: 0.9017, F1-Score: 0.8698, ROC-AUC: 0.9733
# Validation Epoch 10
# Accuracy: 0.8980, Loss: 0.2334, Precision: 0.8807, Recall: 0.8980, F1-Score: 0.8632, ROC-AUC: 0.9710
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 378   72    1    0    0    0]
#  [   0 6826    4    5    0    0]
#  [   0  471    9    2    0    0]
#  [   0  340    6  127    0    0]
#  [   0    0    0    0  409    0]
#  [   0    0    0    0    0  471]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9020, Loss: 0.2380, Precision: 0.8593, Recall: 0.9020, F1-Score: 0.8673, ROC-AUC: 0.9690
# Validation Epoch 1
# Accuracy: 0.9079, Loss: 0.2267, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9684
# Train Epoch 2
# Accuracy: 0.8986, Loss: 0.2445, Precision: 0.8784, Recall: 0.8986, F1-Score: 0.8690, ROC-AUC: 0.9684
# Validation Epoch 2
# Accuracy: 0.9079, Loss: 0.2251, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9672
# Train Epoch 3
# Accuracy: 0.9031, Loss: 0.2285, Precision: 0.8650, Recall: 0.9031, F1-Score: 0.8681, ROC-AUC: 0.9691
# Validation Epoch 3
# Accuracy: 0.9062, Loss: 0.2313, Precision: 0.8678, Recall: 0.9062, F1-Score: 0.8714, ROC-AUC: 0.9678
# Train Epoch 4
# Accuracy: 0.9016, Loss: 0.2335, Precision: 0.8630, Recall: 0.9016, F1-Score: 0.8667, ROC-AUC: 0.9690
# Validation Epoch 4
# Accuracy: 0.9079, Loss: 0.2355, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9680
# Train Epoch 5
# Accuracy: 0.9031, Loss: 0.2277, Precision: 0.8650, Recall: 0.9031, F1-Score: 0.8681, ROC-AUC: 0.9701
# Validation Epoch 5
# Accuracy: 0.9079, Loss: 0.2250, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9684
# Train Epoch 6
# Accuracy: 0.9031, Loss: 0.2263, Precision: 0.8650, Recall: 0.9031, F1-Score: 0.8681, ROC-AUC: 0.9700
# Validation Epoch 6
# Accuracy: 0.9079, Loss: 0.2255, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9678
# Train Epoch 7
# Accuracy: 0.9031, Loss: 0.2258, Precision: 0.8649, Recall: 0.9031, F1-Score: 0.8681, ROC-AUC: 0.9707
# Validation Epoch 7
# Accuracy: 0.9079, Loss: 0.2243, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9679
# Train Epoch 8
# Accuracy: 0.9031, Loss: 0.2255, Precision: 0.8650, Recall: 0.9031, F1-Score: 0.8681, ROC-AUC: 0.9707
# Validation Epoch 8
# Accuracy: 0.9079, Loss: 0.2242, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9680
# Train Epoch 9
# Accuracy: 0.9031, Loss: 0.2243, Precision: 0.8649, Recall: 0.9031, F1-Score: 0.8681, ROC-AUC: 0.9721
# Validation Epoch 9
# Accuracy: 0.9079, Loss: 0.2242, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9680
# Train Epoch 10
# Accuracy: 0.9031, Loss: 0.2243, Precision: 0.8649, Recall: 0.9031, F1-Score: 0.8681, ROC-AUC: 0.9721
# Validation Epoch 10
# Accuracy: 0.9079, Loss: 0.2242, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9684
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 372   84    0    0    0    0]
#  [   0 6860    0    0    0    0]
#  [   0  447    0    0    0    0]
#  [   0  343    0   80    0    0]
#  [   0    0    0    0  410    0]
#  [   0    0    0    0    1  524]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 5, Round 2:
# [[ 1180   221     0     0     0     0]
#  [    0 20513     2     0     1     0]
#  [    0  1409     2     0     1     0]
#  [    0  1022     2   318     0     0]
#  [    0     0     0     0  1198     0]
#  [    0     0     0     0     3  1491]]
# Global Model Validation Confusion Matrix for Fold 5, Round 2:
# [[  92   17    0    0    0    0]
#  [   0 1774    0    0    0    0]
#  [   0  109    0    0    0    0]
#  [   0   92    0   28    0    0]
#  [   0    0    0    0   97    0]
#  [   0    0    0    0    0  136]]
# Round 2/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2264, Accuracy: 0.9028, Precision: 0.8796, Recall: 0.9028, F1 Score: 0.8682, ROC AUC: 0.9720
# On Central Validation Data:
# Loss: 0.2195, Accuracy: 0.9070, Precision: 0.8707, Recall: 0.9070, F1 Score: 0.8740, ROC AUC: 0.9716
#
# Round 3/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9038, Loss: 0.2318, Precision: 0.8618, Recall: 0.9038, F1-Score: 0.8698, ROC-AUC: 0.9697
# Validation Epoch 1
# Accuracy: 0.9002, Loss: 0.2266, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9715
# Train Epoch 2
# Accuracy: 0.9041, Loss: 0.2287, Precision: 0.8625, Recall: 0.9041, F1-Score: 0.8700, ROC-AUC: 0.9690
# Validation Epoch 2
# Accuracy: 0.9002, Loss: 0.2396, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9698
# Train Epoch 3
# Accuracy: 0.9020, Loss: 0.2384, Precision: 0.8601, Recall: 0.9020, F1-Score: 0.8679, ROC-AUC: 0.9687
# Validation Epoch 3
# Accuracy: 0.9002, Loss: 0.2357, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9694
# Train Epoch 4
# Accuracy: 0.9042, Loss: 0.2269, Precision: 0.8631, Recall: 0.9042, F1-Score: 0.8702, ROC-AUC: 0.9689
# Validation Epoch 4
# Accuracy: 0.9002, Loss: 0.2226, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9709
# Train Epoch 5
# Accuracy: 0.9043, Loss: 0.2244, Precision: 0.8632, Recall: 0.9043, F1-Score: 0.8704, ROC-AUC: 0.9707
# Validation Epoch 5
# Accuracy: 0.9002, Loss: 0.2224, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9705
# Train Epoch 6
# Accuracy: 0.9043, Loss: 0.2301, Precision: 0.8632, Recall: 0.9043, F1-Score: 0.8704, ROC-AUC: 0.9707
# Validation Epoch 6
# Accuracy: 0.9002, Loss: 0.2228, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9704
# Train Epoch 7
# Accuracy: 0.9043, Loss: 0.2235, Precision: 0.8632, Recall: 0.9043, F1-Score: 0.8704, ROC-AUC: 0.9720
# Validation Epoch 7
# Accuracy: 0.9002, Loss: 0.2226, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9705
# Train Epoch 8
# Accuracy: 0.9043, Loss: 0.2225, Precision: 0.8632, Recall: 0.9043, F1-Score: 0.8704, ROC-AUC: 0.9732
# Validation Epoch 8
# Accuracy: 0.9002, Loss: 0.2232, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9707
# Train Epoch 9
# Accuracy: 0.9043, Loss: 0.2282, Precision: 0.8632, Recall: 0.9043, F1-Score: 0.8704, ROC-AUC: 0.9732
# Validation Epoch 9
# Accuracy: 0.9002, Loss: 0.2231, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9709
# Train Epoch 10
# Accuracy: 0.9043, Loss: 0.2223, Precision: 0.8632, Recall: 0.9043, F1-Score: 0.8704, ROC-AUC: 0.9730
# Validation Epoch 10
# Accuracy: 0.9002, Loss: 0.2226, Precision: 0.8550, Recall: 0.9002, F1-Score: 0.8627, ROC-AUC: 0.9710
# All metrics saved into CSV file.
# Client 1: Finished training. Returning model weights.
# Client 1 Combined Training and Validation Confusion Matrix:
# [[ 430   64    0    0    0    0]
#  [   0 6821    0    0    0    0]
#  [   0  483    0    0    0    0]
#  [   0  333    0  113    0    0]
#  [   0    0    0    0  379    0]
#  [   0    0    0    0    0  498]]
#
# Training on Client 2
# Client 2: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9008, Loss: 0.2316, Precision: 0.8842, Recall: 0.9008, F1-Score: 0.8670, ROC-AUC: 0.9712
# Validation Epoch 1
# Accuracy: 0.8986, Loss: 0.2378, Precision: 0.8570, Recall: 0.8986, F1-Score: 0.8626, ROC-AUC: 0.9708
# Train Epoch 2
# Accuracy: 0.9015, Loss: 0.2311, Precision: 0.8600, Recall: 0.9015, F1-Score: 0.8670, ROC-AUC: 0.9704
# Validation Epoch 2
# Accuracy: 0.8986, Loss: 0.2379, Precision: 0.8570, Recall: 0.8986, F1-Score: 0.8626, ROC-AUC: 0.9682
# Train Epoch 3
# Accuracy: 0.9017, Loss: 0.2329, Precision: 0.8836, Recall: 0.9017, F1-Score: 0.8712, ROC-AUC: 0.9716
# Validation Epoch 3
# Accuracy: 0.8986, Loss: 0.2354, Precision: 0.8570, Recall: 0.8986, F1-Score: 0.8626, ROC-AUC: 0.9680
# Train Epoch 4
# Accuracy: 0.9020, Loss: 0.2312, Precision: 0.8754, Recall: 0.9020, F1-Score: 0.8703, ROC-AUC: 0.9705
# Validation Epoch 4
# Accuracy: 0.8991, Loss: 0.2346, Precision: 0.8721, Recall: 0.8991, F1-Score: 0.8646, ROC-AUC: 0.9697
# Train Epoch 5
# Accuracy: 0.8919, Loss: 0.2770, Precision: 0.8674, Recall: 0.8919, F1-Score: 0.8591, ROC-AUC: 0.9666
# Validation Epoch 5
# Accuracy: 0.8772, Loss: 0.3016, Precision: 0.7825, Recall: 0.8772, F1-Score: 0.8265, ROC-AUC: 0.9661
# Train Epoch 6
# Accuracy: 0.8975, Loss: 0.2410, Precision: 0.8725, Recall: 0.8975, F1-Score: 0.8607, ROC-AUC: 0.9684
# Validation Epoch 6
# Accuracy: 0.8986, Loss: 0.2312, Precision: 0.8570, Recall: 0.8986, F1-Score: 0.8626, ROC-AUC: 0.9696
# Train Epoch 7
# Accuracy: 0.9019, Loss: 0.2311, Precision: 0.8820, Recall: 0.9019, F1-Score: 0.8679, ROC-AUC: 0.9700
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2316, Precision: 0.8570, Recall: 0.8986, F1-Score: 0.8626, ROC-AUC: 0.9697
# Train Epoch 8
# Accuracy: 0.9022, Loss: 0.2286, Precision: 0.8905, Recall: 0.9022, F1-Score: 0.8688, ROC-AUC: 0.9721
# Validation Epoch 8
# Accuracy: 0.8953, Loss: 0.2318, Precision: 0.8633, Recall: 0.8953, F1-Score: 0.8633, ROC-AUC: 0.9698
# Train Epoch 9
# Accuracy: 0.9017, Loss: 0.2338, Precision: 0.8784, Recall: 0.9017, F1-Score: 0.8679, ROC-AUC: 0.9724
# Validation Epoch 9
# Accuracy: 0.8991, Loss: 0.2306, Precision: 0.8699, Recall: 0.8991, F1-Score: 0.8648, ROC-AUC: 0.9694
# Train Epoch 10
# Accuracy: 0.9012, Loss: 0.2275, Precision: 0.8813, Recall: 0.9012, F1-Score: 0.8721, ROC-AUC: 0.9730
# Validation Epoch 10
# Accuracy: 0.8953, Loss: 0.2342, Precision: 0.8667, Recall: 0.8953, F1-Score: 0.8644, ROC-AUC: 0.9701
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 378   70    3    0    0    0]
#  [   0 6800   35    0    0    0]
#  [   0  447   35    0    0    0]
#  [   0  320   27  125    0    1]
#  [   0    0    0    0  409    0]
#  [   0    0    0    0    0  471]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.9017, Loss: 0.2376, Precision: 0.8626, Recall: 0.9017, F1-Score: 0.8669, ROC-AUC: 0.9688
# Validation Epoch 1
# Accuracy: 0.8498, Loss: 0.7292, Precision: 0.7859, Recall: 0.8498, F1-Score: 0.8021, ROC-AUC: 0.9319
# Train Epoch 2
# Accuracy: 0.9017, Loss: 0.2324, Precision: 0.8612, Recall: 0.9017, F1-Score: 0.8666, ROC-AUC: 0.9693
# Validation Epoch 2
# Accuracy: 0.9079, Loss: 0.2273, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9675
# Train Epoch 3
# Accuracy: 0.9031, Loss: 0.2272, Precision: 0.8649, Recall: 0.9031, F1-Score: 0.8681, ROC-AUC: 0.9698
# Validation Epoch 3
# Accuracy: 0.9079, Loss: 0.2235, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9682
# Train Epoch 4
# Accuracy: 0.9027, Loss: 0.2275, Precision: 0.8647, Recall: 0.9027, F1-Score: 0.8678, ROC-AUC: 0.9690
# Validation Epoch 4
# Accuracy: 0.9079, Loss: 0.2233, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9684
# Train Epoch 5
# Accuracy: 0.9031, Loss: 0.2258, Precision: 0.8645, Recall: 0.9031, F1-Score: 0.8682, ROC-AUC: 0.9701
# Validation Epoch 5
# Accuracy: 0.9079, Loss: 0.2232, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9696
# Train Epoch 6
# Accuracy: 0.9032, Loss: 0.2244, Precision: 0.8651, Recall: 0.9032, F1-Score: 0.8683, ROC-AUC: 0.9712
# Validation Epoch 6
# Accuracy: 0.9079, Loss: 0.2228, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9703
# Train Epoch 7
# Accuracy: 0.9032, Loss: 0.2235, Precision: 0.8651, Recall: 0.9032, F1-Score: 0.8683, ROC-AUC: 0.9721
# Validation Epoch 7
# Accuracy: 0.9079, Loss: 0.2233, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9707
# Train Epoch 8
# Accuracy: 0.9032, Loss: 0.2308, Precision: 0.8645, Recall: 0.9032, F1-Score: 0.8683, ROC-AUC: 0.9727
# Validation Epoch 8
# Accuracy: 0.9079, Loss: 0.2236, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9699
# Train Epoch 9
# Accuracy: 0.9032, Loss: 0.2283, Precision: 0.8651, Recall: 0.9032, F1-Score: 0.8683, ROC-AUC: 0.9736
# Validation Epoch 9
# Accuracy: 0.9079, Loss: 0.2232, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9704
# Train Epoch 10
# Accuracy: 0.9032, Loss: 0.2224, Precision: 0.8651, Recall: 0.9032, F1-Score: 0.8683, ROC-AUC: 0.9732
# Validation Epoch 10
# Accuracy: 0.9079, Loss: 0.2233, Precision: 0.8697, Recall: 0.9079, F1-Score: 0.8730, ROC-AUC: 0.9706
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 372   84    0    0    0    0]
#  [   0 6860    0    0    0    0]
#  [   0  446    0    0    0    1]
#  [   0  343    0   80    0    0]
#  [   0    0    0    0  410    0]
#  [   0    0    0    0    0  525]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 5, Round 3:
# [[ 1180   213     8     0     0     0]
#  [    0 20498    17     0     0     1]
#  [    0  1378    32     0     1     1]
#  [    0   993    29   318     0     2]
#  [    0     0     0     0  1198     0]
#  [    3     0     0     0     0  1491]]
# Global Model Validation Confusion Matrix for Fold 5, Round 3:
# [[  92   17    0    0    0    0]
#  [   0 1771    3    0    0    0]
#  [   0  108    1    0    0    0]
#  [   0   90    2   28    0    0]
#  [   0    0    0    0   97    0]
#  [   0    0    0    0    0  136]]
# Round 3/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2261, Accuracy: 0.9033, Precision: 0.8834, Recall: 0.9033, F1 Score: 0.8710, ROC AUC: 0.9729
# On Central Validation Data:
# Loss: 0.2185, Accuracy: 0.9062, Precision: 0.8794, Recall: 0.9062, F1 Score: 0.8747, ROC AUC: 0.9727
# Global model metrics over rounds saved into CSV file.
# Final Global Model Confusion Matrix on Combined Client Data for Fold 5:
# [[ 1180   213     8     0     0     0]
#  [    0 20498    17     0     0     1]
#  [    0  1378    32     0     1     1]
#  [    0   993    29   318     0     2]
#  [    0     0     0     0  1198     0]
#  [    3     0     0     0     0  1491]]
# Final Global Model Validation Confusion Matrix for Fold 5:
# [[  92   17    0    0    0    0]
#  [   0 1771    3    0    0    0]
#  [   0  108    1    0    0    0]
#  [   0   90    2   28    0    0]
#  [   0    0    0    0   97    0]
#  [   0    0    0    0    0  136]]
# K-Fold cross-validation metrics saved into CSV file.

# %%
import time

# Modified TimeSeriesTransformer to handle (batch_size, num_features) input
class TimeSeriesTransformer(nn.Module):
    def __init__(self, num_continuous, dim=512, depth=4, heads=8, attn_dropout=0.3, ff_dropout=0.1, output_dim=1, mlp_hidden_mults=(4, 2), mlp_act=nn.GELU()):
        super(TimeSeriesTransformer, self).__init__()
        self.dim = dim
        self.input_proj = nn.Linear(num_continuous, dim)
        self.pos_encoder = PositionalEncoding(dim)

        # Transformer encoder layers
        encoder_layer = nn.TransformerEncoderLayer(d_model=dim, nhead=heads, dropout=attn_dropout, batch_first=True) # Changed to batch_first=True
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=depth)

        # MLP Head
        mlp_hidden_dim1 = dim * mlp_hidden_mults[0]
        mlp_hidden_dim2 = dim * mlp_hidden_mults[1]
        self.mlp = nn.Sequential(
            nn.Linear(dim, mlp_hidden_dim1),
            mlp_act,
            nn.Dropout(ff_dropout),
            nn.Linear(mlp_hidden_dim1, mlp_hidden_dim2),
            mlp_act,
            nn.Dropout(ff_dropout),
            nn.Linear(mlp_hidden_dim2, output_dim)
        )

    def forward(self, src): # src will be (batch_size, num_continuous)
        # Assuming each sample is a sequence of length 1 for this dataset
        # Reshape src to (batch_size, sequence_length=1, num_continuous) for transformer input
        src = src.unsqueeze(1) # Now src is (batch_size, 1, num_continuous)

        src = self.input_proj(src) * math.sqrt(self.dim) # (batch_size, 1, dim)
        src = self.pos_encoder(src) # (batch_size, 1, dim) - PositionalEncoding currently handles (seq_len, batch, feature), need to adjust if this became (batch, seq_len, feature)
        # For PositionalEncoding, if input is (B, S, F), it needs to be adapted or removed for S=1
        # Given S=1, pos_encoder will operate on the single time step. No change needed here for S=1 scenario.

        # Transformer encoder forward pass
        output = self.transformer_encoder(src) # (batch_size, 1, dim)
        output = self.mlp(output.squeeze(1))  # Squeeze sequence length dimension (dim 1), (batch_size, dim) for MLP
        return output

def measure_efficiency(model, train_loader, test_loader, device):
    """
    Measures the efficiency metrics of a PyTorch model.

    Args:
        model (nn.Module): The PyTorch model to evaluate.
        train_loader (DataLoader): DataLoader for training data.
        test_loader (DataLoader): DataLoader for test data (for inference latency).
        device (torch.device): The device (CPU or CUDA) to run the measurements on.

    Returns:
        dict: A dictionary containing the efficiency metrics.
    """
    results = {}
    model.eval()  # Set model to evaluation mode
    model.to(device)

    # 1. Model Size (MB) and Total Parameters
    total_params = sum(p.numel() for p in model.parameters())
    results['Total Parameters'] = total_params
    results['Model Size (MB)'] = total_params * 4 / (1024**2) # Assuming Float32 (4 bytes per parameter)

    # Get one batch for VRAM and latency measurements
    try:
        one_batch_X, one_batch_y = next(iter(train_loader))
    except StopIteration:
        print("Train loader is empty, cannot perform measurements.")
        return {'Error': 'Train loader is empty'}

    one_batch_X = one_batch_X.to(device)
    one_batch_y = one_batch_y.to(device)

    # 2. Peak Memory Usage (MB)
    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats(device)
        model.train()  # Set to train mode for backward pass
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)  # Dummy optimizer
        criterion = nn.CrossEntropyLoss()  # Dummy criterion for backward pass

        optimizer.zero_grad()
        outputs = model(one_batch_X)
        loss = criterion(outputs, one_batch_y)
        loss.backward()
        optimizer.step()
        peak_vram = torch.cuda.max_memory_allocated(device) / (1024**2)  # MB
        results['Peak Memory Usage (MB)'] = peak_vram
        model.eval()  # Set back to eval mode
    else:
        results['Peak Memory Usage (MB)'] = 'N/A (CUDA not available)'

    # 3. Training Throughput (samples/sec)
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    start_time_train = time.time()
    total_samples_trained = 0
    for i, (X_batch, y_batch) in enumerate(train_loader):
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        total_samples_trained += X_batch.size(0)
    end_time_train = time.time()
    avg_train_speed_epoch = end_time_train - start_time_train
    # results['Avg Training Speed per Epoch (s)'] = avg_train_speed_epoch # Removed as per user request
    results['Training Throughput (samples/sec)'] = total_samples_trained / avg_train_speed_epoch
    model.eval()

    # 4. Inference Latency (ms/sample)
    total_inference_time = 0  # in milliseconds
    total_samples_inferred = 0
    num_warmup_batches = 5  # Warm-up GPU
    num_measurement_batches = 10  # Batches to measure latency

    with torch.no_grad():
        # Warm-up
        for _ in range(num_warmup_batches):
            try:
                X_batch, _ = next(iter(test_loader))
                _ = model(X_batch.to(device))
            except StopIteration:
                # If test_loader is smaller than num_warmup_batches
                break

        # Measure
        for _ in range(num_measurement_batches):
            try:
                X_batch, _ = next(iter(test_loader))
                X_batch = X_batch.to(device)

                if torch.cuda.is_available():
                    start_event = torch.cuda.Event(enable_timing=True)
                    end_event = torch.cuda.Event(enable_timing=True)
                    start_event.record()
                    _ = model(X_batch)
                    end_event.record()
                    torch.cuda.synchronize()
                    total_inference_time += start_event.elapsed_time(end_event)  # milliseconds
                else:
                    start_time_inference = time.time()
                    _ = model(X_batch)
                    end_time_inference = time.time()
                    total_inference_time += (end_time_inference - start_time_inference) * 1000  # milliseconds

                total_samples_inferred += X_batch.size(0)
            except StopIteration:
                # If test_loader is smaller than num_measurement_batches
                break

    if total_samples_inferred > 0:
        avg_inference_latency_ms = total_inference_time / total_samples_inferred
        results['Inference Latency (ms/sample)'] = avg_inference_latency_ms
    else:
        results['Inference Latency (ms/sample)'] = 'N/A (No samples in test_loader for measurement)'

    return results

# Prepare Data Loaders and Model Instance
# Split X_central_resampled and y_central_resampled into training and testing sets
X_train_resampled, X_test_resampled, y_train_resampled, y_test_resampled = train_test_split(
    X_central_resampled, y_central_resampled, test_size=0.2, random_state=42, stratify=y_central_resampled
)

# Create TensorDatasets
train_dataset = TensorDataset(
    torch.tensor(X_train_resampled, dtype=torch.float32),
    torch.tensor(y_train_resampled, dtype=torch.long)
)
test_dataset = TensorDataset(
    torch.tensor(X_test_resampled, dtype=torch.float32),
    torch.tensor(y_test_resampled, dtype=torch.long)
)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Instantiate the TimeSeriesTransformer model
model = TimeSeriesTransformer(
    num_continuous=num_continuous,
    dim=dim,
    depth=depth,
    heads=heads,
    attn_dropout=attn_dropout,
    ff_dropout=ff_dropout,
    output_dim=output_dim,
    mlp_hidden_mults=mlp_hidden_mults,
    mlp_act=mlp_act
)

# Measure and Display Efficiency Metrics
efficiency_metrics = measure_efficiency(model, train_loader, test_loader, device)

# Display the results in a Pandas DataFrame with custom formatting
efficiency_df = pd.DataFrame([efficiency_metrics])
efficiency_df_transposed = efficiency_df.T.rename(columns={0: "Value"})

def format_metric_value(row):
    if isinstance(row['Value'], (float, int)):
        return f"{row['Value']:.6f}"  # Format floats to 6 decimal places
    else:
        return str(row['Value'])

efficiency_df_transposed['Value'] = efficiency_df_transposed.apply(format_metric_value, axis=1)

print("Efficiency Metrics:")
print(efficiency_df_transposed)
# Out:
# Efficiency Metrics:
#                                             Value
# Total Parameters                   6056710.000000
# Model Size (MB)                         23.104515
# Peak Memory Usage (MB)                 189.747070
# Training Throughput (samples/sec)     2526.869859
# Inference Latency (ms/sample)            0.047171
