# %% [markdown]
# # **Importing Modules and Libraries**

# %%
# %pip install transformers scikit-learn matplotlib pandas
# Out:
# Requirement already satisfied: transformers in c:\users\lenovo\appdata\roaming\python\python313\site-packages (4.57.3)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\appdata\roaming\python\python313\site-packages (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\lenovo\appdata\roaming\python\python313\site-packages (3.10.7)
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: filelock in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from requests->transformers) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from requests->transformers) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import pickle
import os

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

from sklearn import metrics
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

import re

# %%
import os
#os.environ['AMD_SERIALIZE_KERNEL'] ='3'
#os.environ['TORCH_USE_HIP_DSA'] ='1'
#os.environ['HIP_VISIBLE_DEVICES']='0'
#os.environ['PYTORCH_ROCM_ARCH'] = '"gfx1031"'
os.environ['HSA_OVERRIDE_GFX_VERSION'] ='10.3.0'

import torch

# Checking if ROCm is available
if torch.backends.mps.is_available():
    print("ROCm backend is available")

# This will list the ROCm-supported devices
if torch.cuda.is_available():
    print(f"Available AMD GPU: {torch.cuda.get_device_name(0)}")
else:
    print("No ROCm-compatible GPU detected")
# Out:
# Available AMD GPU: Tesla T4

# %% [markdown]
# # **Importing Datasets**

# %%
import requests
import zipfile

file_name = 'obfuscated-malware-memory-2022-cic.zip' # Changed to .zip to reflect download
csv_file_name = 'Obfuscated-MalMem2022.csv'
download_url = 'https://www.kaggle.com/api/v1/datasets/download/luccagodoy/obfuscated-malware-memory-2022-cic'

# Check if the CSV file already exists
if not os.path.exists(csv_file_name):
    # Check if the zip file exists
    if not os.path.exists(file_name):
        print(f"{file_name} does not exist. Downloading now...")
        headers = {'User-Agent': 'Mozilla/5.0'} # Kaggle might require User-Agent
        response = requests.get(download_url, headers=headers, stream=True)
        response.raise_for_status() # Raise an exception for bad status codes

        with open(file_name, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print("Download complete.")
    else:
        print(f"{file_name} already exists. Skipping download.")

    # Unzip the file if the CSV does not exist
    print("Unzipping the file...")
    with zipfile.ZipFile(file_name, 'r') as zip_ref:
        zip_ref.extractall('.') # Extract to the current directory
    print("Unzipping complete.")
else:
    print(f"{csv_file_name} already exists. Skipping download and unzip.")
# Out:
# obfuscated-malware-memory-2022-cic.zip does not exist. Downloading now...
# Download complete.
# Unzipping the file...
# Unzipping complete.

# %%
data = pd.read_csv('Obfuscated-MalMem2022.csv')

# %% [markdown]
# #**Data Cleaning**

# %%
data.head(n=5)
# Out:
#   Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# 0   Benign            45            17           10.555556
# 1   Benign            47            19           11.531915
# 2   Benign            40            14           14.725000
# 3   Benign            32            13           13.500000
# 4   Benign            42            16           11.452381
#
#    pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# 0                   0           202.844444           1694
# 1                   0           242.234043           2074
# 2                   0           288.225000           1932
# 3                   0           264.281250           1445
# 4                   0           281.333333           2067
#
#    dlllist.avg_dlls_per_proc  handles.nhandles  handles.avg_handles_per_proc  \
# 0                  38.500000              9129                    212.302326
# 1                  44.127660             11385                    242.234043
# 2                  48.300000             11529                    288.225000
# 3                  45.156250              8457                    264.281250
# 4                  49.214286             11816                    281.333333
#
#    ...  svcscan.kernel_drivers  svcscan.fs_drivers  svcscan.process_services  \
# 0  ...                     221                  26                        24
# 1  ...                     222                  26                        24
# 2  ...                     222                  26                        27
# 3  ...                     222                  26                        27
# 4  ...                     222                  26                        24
#
#    svcscan.shared_process_services  svcscan.interactive_process_services  \
# 0                              116                                     0
# 1                              118                                     0
# 2                              118                                     0
# 3                              118                                     0
# 4                              118                                     0
#
#    svcscan.nactive  callbacks.ncallbacks  callbacks.nanonymous  \
# 0              121                    87                     0
# 1              122                    87                     0
# 2              120                    88                     0
# 3              120                    88                     0
# 4              124                    87                     0
#
#    callbacks.ngeneric   Class
# 0                   8  Benign
# 1                   8  Benign
# 2                   8  Benign
# 3                   8  Benign
# 4                   8  Benign
#
# [5 rows x 57 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58596 entries, 0 to 58595
# Data columns (total 57 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Category                                58596 non-null  object
#  1   pslist.nproc                            58596 non-null  int64
#  2   pslist.nppid                            58596 non-null  int64
#  3   pslist.avg_threads                      58596 non-null  float64
#  4   pslist.nprocs64bit                      58596 non-null  int64
#  5   pslist.avg_handlers                     58596 non-null  float64
#  6   dlllist.ndlls                           58596 non-null  int64
#  7   dlllist.avg_dlls_per_proc               58596 non-null  float64
#  8   handles.nhandles                        58596 non-null  int64
#  9   handles.avg_handles_per_proc            58596 non-null  float64
#  10  handles.nport                           58596 non-null  int64
#  11  handles.nfile                           58596 non-null  int64
#  12  handles.nevent                          58596 non-null  int64
#  13  handles.ndesktop                        58596 non-null  int64
#  14  handles.nkey                            58596 non-null  int64
#  15  handles.nthread                         58596 non-null  int64
#  16  handles.ndirectory                      58596 non-null  int64
#  17  handles.nsemaphore                      58596 non-null  int64
#  18  handles.ntimer                          58596 non-null  int64
#  19  handles.nsection                        58596 non-null  int64
#  20  handles.nmutant                         58596 non-null  int64
#  21  ldrmodules.not_in_load                  58596 non-null  int64
#  22  ldrmodules.not_in_init                  58596 non-null  int64
#  23  ldrmodules.not_in_mem                   58596 non-null  int64
#  24  ldrmodules.not_in_load_avg              58596 non-null  float64
#  25  ldrmodules.not_in_init_avg              58596 non-null  float64
#  26  ldrmodules.not_in_mem_avg               58596 non-null  float64
#  27  malfind.ninjections                     58596 non-null  int64
#  28  malfind.commitCharge                    58596 non-null  int64
#  29  malfind.protection                      58596 non-null  int64
#  30  malfind.uniqueInjections                58596 non-null  float64
#  31  psxview.not_in_pslist                   58596 non-null  int64
#  32  psxview.not_in_eprocess_pool            58596 non-null  int64
#  33  psxview.not_in_ethread_pool             58596 non-null  int64
#  34  psxview.not_in_pspcid_list              58596 non-null  int64
#  35  psxview.not_in_csrss_handles            58596 non-null  int64
#  36  psxview.not_in_session                  58596 non-null  int64
#  37  psxview.not_in_deskthrd                 58596 non-null  int64
#  38  psxview.not_in_pslist_false_avg         58596 non-null  float64
#  39  psxview.not_in_eprocess_pool_false_avg  58596 non-null  float64
#  40  psxview.not_in_ethread_pool_false_avg   58596 non-null  float64
#  41  psxview.not_in_pspcid_list_false_avg    58596 non-null  float64
#  42  psxview.not_in_csrss_handles_false_avg  58596 non-null  float64
#  43  psxview.not_in_session_false_avg        58596 non-null  float64
#  44  psxview.not_in_deskthrd_false_avg       58596 non-null  float64
#  45  modules.nmodules                        58596 non-null  int64
#  46  svcscan.nservices                       58596 non-null  int64
#  47  svcscan.kernel_drivers                  58596 non-null  int64
#  48  svcscan.fs_drivers                      58596 non-null  int64
#  49  svcscan.process_services                58596 non-null  int64
#  50  svcscan.shared_process_services         58596 non-null  int64
#  51  svcscan.interactive_process_services    58596 non-null  int64
#  52  svcscan.nactive                         58596 non-null  int64
#  53  callbacks.ncallbacks                    58596 non-null  int64
#  54  callbacks.nanonymous                    58596 non-null  int64
#  55  callbacks.ngeneric                      58596 non-null  int64
#  56  Class                                   58596 non-null  object
# dtypes: float64(15), int64(40), object(2)
# memory usage: 25.5+ MB

# %% [markdown]
# ##Mengatasi missing value

# %%
data.isnull().sum()
# Out:
# Category                                  0
# pslist.nproc                              0
# pslist.nppid                              0
# pslist.avg_threads                        0
# pslist.nprocs64bit                        0
# pslist.avg_handlers                       0
# dlllist.ndlls                             0
# dlllist.avg_dlls_per_proc                 0
# handles.nhandles                          0
# handles.avg_handles_per_proc              0
# handles.nport                             0
# handles.nfile                             0
# handles.nevent                            0
# handles.ndesktop                          0
# handles.nkey                              0
# handles.nthread                           0
# handles.ndirectory                        0
# handles.nsemaphore                        0
# handles.ntimer                            0
# handles.nsection                          0
# handles.nmutant                           0
# ldrmodules.not_in_load                    0
# ldrmodules.not_in_init                    0
# ldrmodules.not_in_mem                     0
# ldrmodules.not_in_load_avg                0
# ldrmodules.not_in_init_avg                0
# ldrmodules.not_in_mem_avg                 0
# malfind.ninjections                       0
# malfind.commitCharge                      0
# malfind.protection                        0
# malfind.uniqueInjections                  0
# psxview.not_in_pslist                     0
# psxview.not_in_eprocess_pool              0
# psxview.not_in_ethread_pool               0
# psxview.not_in_pspcid_list                0
# psxview.not_in_csrss_handles              0
# psxview.not_in_session                    0
# psxview.not_in_deskthrd                   0
# psxview.not_in_pslist_false_avg           0
# psxview.not_in_eprocess_pool_false_avg    0
# psxview.not_in_ethread_pool_false_avg     0
# psxview.not_in_pspcid_list_false_avg      0
# psxview.not_in_csrss_handles_false_avg    0
# psxview.not_in_session_false_avg          0
# psxview.not_in_deskthrd_false_avg         0
# modules.nmodules                          0
# svcscan.nservices                         0
# svcscan.kernel_drivers                    0
# svcscan.fs_drivers                        0
# svcscan.process_services                  0
# svcscan.shared_process_services           0
# svcscan.interactive_process_services      0
# svcscan.nactive                           0
# callbacks.ncallbacks                      0
# callbacks.nanonymous                      0
# callbacks.ngeneric                        0
# Class                                     0
# dtype: int64

# %%
data.shape
# Out:
# (58596, 57)

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (58596, 57)

# %% [markdown]
# ##Memeriksa distribusi kategori

# %%
data['Category'].value_counts()
# Out:
# Category
# Benign                                                                                    29298
# Ransomware-Pysa-5f3166fc81e2415abe55db02124934be66e02c8ac573bd3f3a0a6d8b73a7a7fc-3.raw        2
# Ransomware-Pysa-5f3166fc81e2415abe55db02124934be66e02c8ac573bd3f3a0a6d8b73a7a7fc-5.raw        2
# Ransomware-Pysa-5f3166fc81e2415abe55db02124934be66e02c8ac573bd3f3a0a6d8b73a7a7fc-6.raw        2
# Ransomware-Pysa-5f3166fc81e2415abe55db02124934be66e02c8ac573bd3f3a0a6d8b73a7a7fc-7.raw        2
#                                                                                           ...
# Ransomware-Ako-0a1e176eded8c1801fcd09e8cf9f796c326bc7e9b51531fb40a32f5214d6ba76-2.raw         1
# Ransomware-Ako-0a1e176eded8c1801fcd09e8cf9f796c326bc7e9b51531fb40a32f5214d6ba76-3.raw         1
# Ransomware-Ako-0a1e176eded8c1801fcd09e8cf9f796c326bc7e9b51531fb40a32f5214d6ba76-4.raw         1
# Ransomware-Ako-0a1e176eded8c1801fcd09e8cf9f796c326bc7e9b51531fb40a32f5214d6ba76-5.raw         1
# Ransomware-Ako-00a2c6bab1e53f679cdd4fdc772cd291928c109b9b747652639a1700d844f719-2.raw         1
# Name: count, Length: 28346, dtype: int64

# %% [markdown]
# ##Merubah Kategori

# %% [markdown]
# Dua kolom ditambahkan seperti *Sub_Category* dan *Main_Category* agar bisa diperjelas

# %%
def extract_category(value):
    match = re.match(r'^[^-]+-[^-]+', value)
    if match:
        return match.group()
    return value

# %%
data['Cleaned_Category'] = data['Category'].apply(extract_category)

# %%
data['Cleaned_Category'].value_counts()
# Out:
# Cleaned_Category
# Benign                  29298
# Spyware-Transponder      2410
# Spyware-Gator            2200
# Ransomware-Shade         2128
# Spyware-CWS              2000
# Trojan-Scar              2000
# Spyware-180solutions     2000
# Ransomware-Ako           2000
# Trojan-Refroso           2000
# Ransomware-Conti         1988
# Trojan-Emotet            1967
# Ransomware-Maze          1958
# Trojan-Zeus              1950
# Ransomware-Pysa          1717
# Trojan-Reconyc           1570
# Spyware-TIBS             1410
# Name: count, dtype: int64

# %%
data['Main_Category'] = data['Cleaned_Category'].apply(lambda x: x.split('-')[0])

# %%
data['Main_Category'].value_counts()
# Out:
# Main_Category
# Benign        29298
# Spyware       10020
# Ransomware     9791
# Trojan         9487
# Name: count, dtype: int64

# %%
data = data[~data['Main_Category'].isin(['Spyware', 'Trojan'])]
data['Main_Category'].value_counts()
# Out:
# Main_Category
# Benign        29298
# Ransomware     9791
# Name: count, dtype: int64

# %%
data['Sub_Category'] = data['Cleaned_Category'].apply(lambda x: x.split('-')[1] if '-' in x else x)

# %%
data['Sub_Category'].value_counts()
# Out:
# Sub_Category
# Benign    29298
# Shade      2128
# Ako        2000
# Conti      1988
# Maze       1958
# Pysa       1717
# Name: count, dtype: int64

# %%
data.drop(columns="Category",inplace=True)
data.drop(columns="Class", inplace=True)
data.drop(columns="Cleaned_Category",inplace=True)
data.drop(columns="Main_Category",inplace=True)

# %%
data.to_csv('data.csv')

# %% [markdown]
# ##**Merubah data menjadi numerik**

# %%
# Identifying different types of columns
nominal_names = data.select_dtypes(include=['object']).columns
integer_names = data.select_dtypes(include=['int', 'int64']).columns
binary_names = []
float_names = data.select_dtypes(include=['float', 'float64']).columns

# %%
# Identifying binary columns (with only two unique values, e.g., 0 and 1)
for c in data.columns:
    if data[c].nunique() == 2 and data[c].dtype in ['int64', 'int', 'float64']:
        binary_names.append(c)

# Converting integer columns to numeric
for c in integer_names:
    data[c] = pd.to_numeric(data[c])

# Converting binary columns to numeric (optional step if already int/float)
for c in binary_names:
    data[c] = pd.to_numeric(data[c])

# Converting float columns to numeric
for c in float_names:
    data[c] = pd.to_numeric(data[c])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39089 entries, 0 to 58595
# Data columns (total 56 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   pslist.nproc                            39089 non-null  int64
#  1   pslist.nppid                            39089 non-null  int64
#  2   pslist.avg_threads                      39089 non-null  float64
#  3   pslist.nprocs64bit                      39089 non-null  int64
#  4   pslist.avg_handlers                     39089 non-null  float64
#  5   dlllist.ndlls                           39089 non-null  int64
#  6   dlllist.avg_dlls_per_proc               39089 non-null  float64
#  7   handles.nhandles                        39089 non-null  int64
#  8   handles.avg_handles_per_proc            39089 non-null  float64
#  9   handles.nport                           39089 non-null  int64
#  10  handles.nfile                           39089 non-null  int64
#  11  handles.nevent                          39089 non-null  int64
#  12  handles.ndesktop                        39089 non-null  int64
#  13  handles.nkey                            39089 non-null  int64
#  14  handles.nthread                         39089 non-null  int64
#  15  handles.ndirectory                      39089 non-null  int64
#  16  handles.nsemaphore                      39089 non-null  int64
#  17  handles.ntimer                          39089 non-null  int64
#  18  handles.nsection                        39089 non-null  int64
#  19  handles.nmutant                         39089 non-null  int64
#  20  ldrmodules.not_in_load                  39089 non-null  int64
#  21  ldrmodules.not_in_init                  39089 non-null  int64
#  22  ldrmodules.not_in_mem                   39089 non-null  int64
#  23  ldrmodules.not_in_load_avg              39089 non-null  float64
#  24  ldrmodules.not_in_init_avg              39089 non-null  float64
#  25  ldrmodules.not_in_mem_avg               39089 non-null  float64
#  26  malfind.ninjections                     39089 non-null  int64
#  27  malfind.commitCharge                    39089 non-null  int64
#  28  malfind.protection                      39089 non-null  int64
#  29  malfind.uniqueInjections                39089 non-null  float64
#  30  psxview.not_in_pslist                   39089 non-null  int64
#  31  psxview.not_in_eprocess_pool            39089 non-null  int64
#  32  psxview.not_in_ethread_pool             39089 non-null  int64
#  33  psxview.not_in_pspcid_list              39089 non-null  int64
#  34  psxview.not_in_csrss_handles            39089 non-null  int64
#  35  psxview.not_in_session                  39089 non-null  int64
#  36  psxview.not_in_deskthrd                 39089 non-null  int64
#  37  psxview.not_in_pslist_false_avg         39089 non-null  float64
#  38  psxview.not_in_eprocess_pool_false_avg  39089 non-null  float64
#  39  psxview.not_in_ethread_pool_false_avg   39089 non-null  float64
#  40  psxview.not_in_pspcid_list_false_avg    39089 non-null  float64
#  41  psxview.not_in_csrss_handles_false_avg  39089 non-null  float64
#  42  psxview.not_in_session_false_avg        39089 non-null  float64
#  43  psxview.not_in_deskthrd_false_avg       39089 non-null  float64
#  44  modules.nmodules                        39089 non-null  int64
#  45  svcscan.nservices                       39089 non-null  int64
#  46  svcscan.kernel_drivers                  39089 non-null  int64
#  47  svcscan.fs_drivers                      39089 non-null  int64
#  48  svcscan.process_services                39089 non-null  int64
#  49  svcscan.shared_process_services         39089 non-null  int64
#  50  svcscan.interactive_process_services    39089 non-null  int64
#  51  svcscan.nactive                         39089 non-null  int64
#  52  callbacks.ncallbacks                    39089 non-null  int64
#  53  callbacks.nanonymous                    39089 non-null  int64
#  54  callbacks.ngeneric                      39089 non-null  int64
#  55  Sub_Category                            39089 non-null  object
# dtypes: float64(15), int64(40), object(1)
# memory usage: 17.0+ MB

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ##**Sub-Class Visualization**

# %%
plt.figure(figsize=(8,8))
plt.pie(data.Sub_Category.value_counts(),labels=data.Sub_Category.unique(),autopct='%0.2f%%')
plt.title('Distribusi diagram lingkaran Sub-Class')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# #**Label Encoding**

# %%
bin_label = pd.DataFrame(data.Sub_Category)

# %%
bin_data = data.copy()

# %%
le1 = preprocessing.LabelEncoder()
enc_label = bin_label.apply(le1.fit_transform)
bin_data['Sub_Category'] = enc_label

# %%
le1.classes_
# Out:
# array(['Ako', 'Benign', 'Conti', 'Maze', 'Pysa', 'Shade'], dtype=object)

# %%
np.save("le1_classes.npy",le1.classes_,allow_pickle=True)

# %% [markdown]
# # **Correlation between features of dataset**

# %%
plt.figure(figsize=(20,8))
corr_bin = bin_data.corr()
sns.heatmap(corr_bin,vmax=1.0,annot=False)
plt.title('Correlation Matrix for Binary Labels',fontsize=16)
plt.show()

# %% [markdown]
# # **Feature Selection**

# %%
corr_ybin = abs(corr_bin['Sub_Category'])
highest_corr_bin = corr_ybin[corr_ybin >= 0.20]
highest_corr_bin.sort_values(ascending=True)
# Out:
# handles.ndesktop                   0.221005
# callbacks.ncallbacks               0.228917
# pslist.nppid                       0.274871
# svcscan.nservices                  0.389798
# ldrmodules.not_in_init             0.414736
# svcscan.nactive                    0.418488
# handles.nkey                       0.438590
# svcscan.process_services           0.440829
# svcscan.shared_process_services    0.459790
# ldrmodules.not_in_mem              0.461366
# ldrmodules.not_in_load             0.461412
# handles.nsemaphore                 0.504964
# dlllist.ndlls                      0.513934
# pslist.avg_threads                 0.514737
# handles.ntimer                     0.526619
# handles.nmutant                    0.530116
# handles.nthread                    0.543016
# handles.nevent                     0.549885
# dlllist.avg_dlls_per_proc          0.576765
# handles.nsection                   0.579873
# Sub_Category                       1.000000
# Name: Sub_Category, dtype: float64

# %%
bin_cols = highest_corr_bin.index
bin_cols
# Out:
# Index(['pslist.nppid', 'pslist.avg_threads', 'dlllist.ndlls',
#        'dlllist.avg_dlls_per_proc', 'handles.nevent', 'handles.ndesktop',
#        'handles.nkey', 'handles.nthread', 'handles.nsemaphore',
#        'handles.ntimer', 'handles.nsection', 'handles.nmutant',
#        'ldrmodules.not_in_load', 'ldrmodules.not_in_init',
#        'ldrmodules.not_in_mem', 'svcscan.nservices',
#        'svcscan.process_services', 'svcscan.shared_process_services',
#        'svcscan.nactive', 'callbacks.ncallbacks', 'Sub_Category'],
#       dtype='object')

# %%
bin_data = bin_data[bin_cols].copy()
bin_data
# Out:
#        pslist.nppid  pslist.avg_threads  dlllist.ndlls  \
# 0                17           10.555556           1694
# 1                19           11.531915           2074
# 2                14           14.725000           1932
# 3                13           13.500000           1445
# 4                16           11.452381           2067
# ...             ...                 ...            ...
# 58591            15           10.108108           1453
# 58592            14            9.945946           1347
# 58593            15            9.842105           1448
# 58594            15           10.243243           1452
# 58595            15            9.868421           1487
#
#        dlllist.avg_dlls_per_proc  handles.nevent  handles.ndesktop  \
# 0                      38.500000            3161                46
# 1                      44.127660            3761                51
# 2                      48.300000            3996                45
# 3                      45.156250            2961                36
# 4                      49.214286            3834                45
# ...                          ...             ...               ...
# 58591                  39.270270            2819                40
# 58592                  36.405405            2394                39
# 58593                  38.105263            2816                40
# 58594                  39.243243            2819                40
# 58595                  39.131579            2843                41
#
#        handles.nkey  handles.nthread  handles.nsemaphore  handles.ntimer  ...  \
# 0               716              887                 671             125  ...
# 1              1011             1030                 766             148  ...
# 2               784             1241                 645             138  ...
# 3               654              792                 567             127  ...
# 4              1252              942                 825             135  ...
# ...             ...              ...                 ...             ...  ...
# 58591           668              664                 596             113  ...
# 58592           555              624                 482             102  ...
# 58593           673              661                 596             113  ...
# 58594           668              667                 596             113  ...
# 58595           683              669                 598             116  ...
#
#        handles.nmutant  ldrmodules.not_in_load  ldrmodules.not_in_init  \
# 0                  257                      53                      95
# 1                  394                      77                     123
# 2                  338                      51                      89
# 3                  242                      31                      62
# 4                  429                     102                     143
# ...                ...                     ...                     ...
# 58591              230                      43                      79
# 58592              203                      43                      79
# 58593              230                      43                      79
# 58594              230                      43                      79
# 58595              236                      44                      81
#
#        ldrmodules.not_in_mem  svcscan.nservices  svcscan.process_services  \
# 0                         53                389                        24
# 1                         77                392                        24
# 2                         51                395                        27
# 3                         31                395                        27
# 4                        102                392                        24
# ...                      ...                ...                       ...
# 58591                     43                389                        24
# 58592                     43                389                        24
# 58593                     43                389                        24
# 58594                     43                389                        24
# 58595                     44                389                        24
#
#        svcscan.shared_process_services  svcscan.nactive  callbacks.ncallbacks  \
# 0                                  116              121                    87
# 1                                  118              122                    87
# 2                                  118              120                    88
# 3                                  118              120                    88
# 4                                  118              124                    87
# ...                                ...              ...                   ...
# 58591                              116              120                    86
# 58592                              116              116                    88
# 58593                              116              120                    88
# 58594                              116              120                    87
# 58595                              116              120                    86
#
#        Sub_Category
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 58591             5
# 58592             5
# 58593             5
# 58594             5
# 58595             5
#
# [39089 rows x 21 columns]

# %%
#value_map = {
#    0: 'Benign',
#    1: 'Ransomware',
#    2: 'Spyware',
#    3: 'Trojan'
#}

#bin_data['Main_Category'] = bin_data['Main_Category'].map(value_map)

# %%
bin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39089 entries, 0 to 58595
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pslist.nppid                     39089 non-null  int64
#  1   pslist.avg_threads               39089 non-null  float64
#  2   dlllist.ndlls                    39089 non-null  int64
#  3   dlllist.avg_dlls_per_proc        39089 non-null  float64
#  4   handles.nevent                   39089 non-null  int64
#  5   handles.ndesktop                 39089 non-null  int64
#  6   handles.nkey                     39089 non-null  int64
#  7   handles.nthread                  39089 non-null  int64
#  8   handles.nsemaphore               39089 non-null  int64
#  9   handles.ntimer                   39089 non-null  int64
#  10  handles.nsection                 39089 non-null  int64
#  11  handles.nmutant                  39089 non-null  int64
#  12  ldrmodules.not_in_load           39089 non-null  int64
#  13  ldrmodules.not_in_init           39089 non-null  int64
#  14  ldrmodules.not_in_mem            39089 non-null  int64
#  15  svcscan.nservices                39089 non-null  int64
#  16  svcscan.process_services         39089 non-null  int64
#  17  svcscan.shared_process_services  39089 non-null  int64
#  18  svcscan.nactive                  39089 non-null  int64
#  19  callbacks.ncallbacks             39089 non-null  int64
#  20  Sub_Category                     39089 non-null  int64
# dtypes: float64(2), int64(19)
# memory usage: 6.6 MB

# %% [markdown]
# # **Data Normalization**

# %%
X_n = bin_data.drop(columns=['Sub_Category'])
y_n = bin_data['Sub_Category']

# %%
# Using boxplots to check for outliers in each feature
plt.figure(figsize=(15, 20))
num_features = X_n.columns

# Creating subplots for each feature to visualize outliers
for i, feature in enumerate(num_features):
    plt.subplot(7, 3, i + 1)  # Creating subplots in a grid of 7 rows and 3 columns
    sns.boxplot(x=X_n[feature], color='lightblue')
    plt.title(feature)
    plt.tight_layout()

plt.show()

# %%
import numpy as np

# Calculate the first and third quartiles
Q1 = np.percentile(X_n, 25, axis=0)
Q3 = np.percentile(X_n, 75, axis=0)
IQR = Q3 - Q1

# Define the outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Create a mask to filter out rows where all features are within the bounds
non_outlier_mask = ((X_n >= lower_bound) & (X_n <= upper_bound)).all(axis=1)

# Filter the dataset
X_no_outliers = X_n[non_outlier_mask]

# X_no_outliers = X_n[non_outlier_mask]

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_no_outliers)

# %%
X_scaled_df = pd.DataFrame(X_scaled, columns=X_n.columns)

# %%
# Using boxplots to check for outliers in each feature
plt.figure(figsize=(15, 20))
num_features_s = X_scaled_df.columns

# Creating subplots for each feature to visualize outliers
for i, feature in enumerate(num_features_s):
    plt.subplot(7, 3, i + 1)  # Creating subplots in a grid of 7 rows and 3 columns
    sns.boxplot(x=X_scaled_df[feature], color='lightblue')
    plt.title(feature)
    plt.tight_layout()

plt.show()

# %%
combined_data = pd.concat([X_scaled_df, y_n.reset_index(drop=True)], axis=1)

# %%
# Total number of rows in the DataFrame
total_rows = len(combined_data)

# Calculate percentage of null values
null_percentage = (combined_data.isnull().sum() / total_rows) * 100

# Display the percentage of null values for each column
print(null_percentage)
# Out:
# pslist.nppid                       15.324004
# pslist.avg_threads                 15.324004
# dlllist.ndlls                      15.324004
# dlllist.avg_dlls_per_proc          15.324004
# handles.nevent                     15.324004
# handles.ndesktop                   15.324004
# handles.nkey                       15.324004
# handles.nthread                    15.324004
# handles.nsemaphore                 15.324004
# handles.ntimer                     15.324004
# handles.nsection                   15.324004
# handles.nmutant                    15.324004
# ldrmodules.not_in_load             15.324004
# ldrmodules.not_in_init             15.324004
# ldrmodules.not_in_mem              15.324004
# svcscan.nservices                  15.324004
# svcscan.process_services           15.324004
# svcscan.shared_process_services    15.324004
# svcscan.nactive                    15.324004
# callbacks.ncallbacks               15.324004
# Sub_Category                        0.000000
# dtype: float64

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
combined_data.iloc[:, :] = imputer.fit_transform(combined_data)

# %%
# Total number of rows in the DataFrame
total_rows = len(combined_data)

# Calculate percentage of null values
null_percentage = (combined_data.isnull().sum() / total_rows) * 100

# Display the percentage of null values for each column
print(null_percentage)
# Out:
# pslist.nppid                       0.0
# pslist.avg_threads                 0.0
# dlllist.ndlls                      0.0
# dlllist.avg_dlls_per_proc          0.0
# handles.nevent                     0.0
# handles.ndesktop                   0.0
# handles.nkey                       0.0
# handles.nthread                    0.0
# handles.nsemaphore                 0.0
# handles.ntimer                     0.0
# handles.nsection                   0.0
# handles.nmutant                    0.0
# ldrmodules.not_in_load             0.0
# ldrmodules.not_in_init             0.0
# ldrmodules.not_in_mem              0.0
# svcscan.nservices                  0.0
# svcscan.process_services           0.0
# svcscan.shared_process_services    0.0
# svcscan.nactive                    0.0
# callbacks.ncallbacks               0.0
# Sub_Category                       0.0
# dtype: float64

# %%
combined_data['Sub_Category'].value_counts()
# Out:
# Sub_Category
# 1    29298
# 5     2128
# 0     2000
# 2     1988
# 3     1958
# 4     1717
# Name: count, dtype: int64

# %%
combined_data.to_csv('bin_data_scaled.csv', index=False)

# %% [markdown]
# # **Data Balancing**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
data_bin = pd.read_csv("bin_data_scaled.csv")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assuming data_bin is your DataFrame with features and 'Sub_Category' as the target column
# Separate features (X) and target (y)
X_bin = data_bin.drop(columns=['Sub_Category']).values
y_bin = data_bin['Sub_Category'].values

# Split central and client data, ensuring stratification of classes
X_central, X_clients, y_central, y_clients = train_test_split(X_bin, y_bin, test_size=0.7, random_state=55, stratify=y_bin)

# Shuffle the indices
indices = np.arange(len(X_clients))
np.random.shuffle(indices)

# Split the shuffled indices into 3 clients
client_splits = np.array_split(indices, 3)

# Create client data based on the new splits
client_data = [(X_clients[split_indices], y_clients[split_indices]) for split_indices in client_splits]

# Export client data to CSV files with the correct feature names
feature_columns = data_bin.drop(columns=['Sub_Category']).columns

for i, (X_client, y_client) in enumerate(client_data, start=1):
    df_client = pd.DataFrame(X_client, columns=feature_columns)  # Use actual feature names
    df_client['Sub_Category'] = y_client
    df_client.to_csv(f"client_data_{i}.csv", index=False)

# %%
# Visualize the distribution before SMOTE
def visualize_distribution(y_data, title):
    counter = Counter(y_data)
    print(counter.keys(),counter.values())
    plt.bar(counter.keys(), counter.values())
    plt.title(title)
    plt.xlabel('Class')
    plt.ylabel('Frequency')
    plt.show()

# %%
# Apply SMOTE to each client and visualize the distribution after SMOTE
smote = SMOTE(random_state=120)

# %%
# Visualize distribution for central data before SMOTE
visualize_distribution(y_central, title='Central Class Distribution Before SMOTE')
# Out:
# dict_keys([np.int64(1), np.int64(2), np.int64(5), np.int64(0), np.int64(3), np.int64(4)]) dict_values([8789, 596, 638, 600, 588, 515])

# %%
# Apply SMOTE to central data and visualize the distribution after SMOTE
X_central_resampled, y_central_resampled = smote.fit_resample(X_central, y_central)
visualize_distribution(y_central_resampled, title='Central Class Distribution After SMOTE')
# Out:
# dict_keys([np.int64(1), np.int64(2), np.int64(5), np.int64(0), np.int64(3), np.int64(4)]) dict_values([8789, 8789, 8789, 8789, 8789, 8789])

# %%
# Visualize distribution for each client before SMOTE
for i, (X_client, y_client) in enumerate(client_data):
    visualize_distribution(y_client, title=f'Client {i+1} Class Distribution Before SMOTE')
# Out:
# dict_keys([np.int64(1), np.int64(5), np.int64(4), np.int64(3), np.int64(2), np.int64(0)]) dict_values([6874, 494, 382, 445, 474, 452])
# dict_keys([np.int64(1), np.int64(4), np.int64(0), np.int64(3), np.int64(2), np.int64(5)]) dict_values([6847, 413, 468, 461, 431, 501])
# dict_keys([np.int64(5), np.int64(1), np.int64(0), np.int64(4), np.int64(2), np.int64(3)]) dict_values([495, 6788, 480, 407, 487, 464])

# %%
client_data_smoted = []
for i, (X_client, y_client) in enumerate(client_data):
    X_client_resampled, y_client_resampled = smote.fit_resample(X_client, y_client)
    client_data_smoted.append((X_client_resampled, y_client_resampled))
    visualize_distribution(y_client_resampled, title=f'Client {i+1} Class Distribution After SMOTE')

# Further split client data into 5 clients
client_splits_smoted = np.array_split(np.arange(len(X_client_resampled)), 3)
# Out:
# dict_keys([np.int64(1), np.int64(5), np.int64(4), np.int64(3), np.int64(2), np.int64(0)]) dict_values([6874, 6874, 6874, 6874, 6874, 6874])
# dict_keys([np.int64(1), np.int64(4), np.int64(0), np.int64(3), np.int64(2), np.int64(5)]) dict_values([6847, 6847, 6847, 6847, 6847, 6847])
# dict_keys([np.int64(5), np.int64(1), np.int64(0), np.int64(4), np.int64(2), np.int64(3)]) dict_values([6788, 6788, 6788, 6788, 6788, 6788])

# %% [markdown]
# # **Training**

# %% [markdown]
# **NOTE** \\
# Penggunaan Variable untuk Balance dan Imbalance sebagai berikut:
# - X_central: Imbalance (untuk Central sebelum SMOTE)
# - X_clients: Imbalance (untuk Client sebelum SMOTE)
# - X_central_resampled: Balanced (untuk Central setelah SMOTE)
# - X_client_resampled: Balanced (untuk masing-masing Client setelah SMOTE)
# - y_central: Imbalance (untuk Central sebelum SMOTE)
# - y_clients: Imbalance (untuk Client sebelum SMOTE)
# - y_central_resampled: Balanced (untuk Central setelah SMOTE)
# - y_client_resampled: Balanced (untuk masing-masing Client setelah SMOTE)

# %%
unique_values = np.unique(y_central)
print(unique_values)
# Out:
# [0 1 2 3 4 5]

# %%
folder_name = 'Imbalanced'

if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    print(f"Folder '{folder_name}' created successfully.")
else:
    print(f"{folder_name} already exists. Skipping Folder Creation.")
# Out:
# Imbalanced already exists. Skipping Folder Creation.

# %%
import torch
import math
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    confusion_matrix,
    roc_auc_score,
)
from torch.utils.data import DataLoader, Subset, TensorDataset, random_split
from sklearn.model_selection import KFold
import numpy as np
import matplotlib.pyplot as plt
import warnings
from torch.optim.lr_scheduler import ReduceLROnPlateau# Import necessary library
from sklearn.model_selection import train_test_split
import itertools

# %%
central_dataset = TensorDataset(
    torch.tensor(X_central, dtype=torch.float32), torch.tensor(y_central, dtype=torch.long)
)
client_datasets = [
    TensorDataset(
        torch.tensor(X_clients[indices], dtype=torch.float32),
        torch.tensor(y_clients[indices], dtype=torch.long),
    )
    for indices in client_splits
]

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("GPU is available and being used" if torch.cuda.is_available() else "Using CPU due to lack of GPU")
# Out:
# Using CPU due to lack of GPU

# %%
class ProbSparseSelfAttention(nn.Module):
    def __init__(self, d_model, n_heads, dropout=0.1, factor=5):
        super(ProbSparseSelfAttention, self).__init__()
        self.n_heads = n_heads
        self.factor = factor
        self.scale = 1 / math.sqrt(d_model // n_heads)
        self.dropout = nn.Dropout(dropout)
        self.qkv_proj = nn.Linear(d_model, d_model * 3)
        self.out_proj = nn.Linear(d_model, d_model)

    def forward(self, x):
        B, L, D = x.size()
        H = self.n_heads
        qkv = (
            self.qkv_proj(x)
            .reshape(B, L, 3, H, D // H)
            .permute(2, 0, 3, 1, 4)
        )  # (3, B, H, L, D_head)
        q, k, v = qkv[0], qkv[1], qkv[2]  # Each is (B, H, L, D_head)
        scores = torch.einsum("bhid,bhjd->bhij", q, k) * self.scale  # (B, H, L, L)
        attn = torch.softmax(scores, dim=-1)
        attn = self.dropout(attn)
        out = torch.einsum("bhij,bhjd->bhid", attn, v)  # (B, H, L, D_head)
        out = out.transpose(1, 2).reshape(B, L, D)
        out = self.out_proj(out)
        return out

class InformerEncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout=0.1, factor=5):
        super(InformerEncoderLayer, self).__init__()
        self.self_attn = ProbSparseSelfAttention(
            d_model, n_heads, dropout=dropout, factor=factor
        )
        self.dropout1 = nn.Dropout(dropout)
        self.norm1 = nn.LayerNorm(d_model)

        self.ffn = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model),
        )
        self.dropout2 = nn.Dropout(dropout)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, src):
        # Self-attention
        src2 = self.self_attn(src)
        src = src + self.dropout1(src2)
        src = self.norm1(src)
        # Feed-forward network
        src2 = self.ffn(src)
        src = src + self.dropout2(src2)
        src = self.norm2(src)

        return src

class InformerEncoder(nn.Module):
    def __init__(self, encoder_layer, num_layers):
        super(InformerEncoder, self).__init__()
        self.layers = nn.ModuleList([encoder_layer for _ in range(num_layers)])

    def forward(self, src):
        for layer in self.layers:
            src = layer(src)
        return src

class InformerModel(nn.Module):
    def __init__(
        self,
        num_continuous,
        d_model,
        d_ff,
        num_layers,
        n_heads,
        output_dim,
        dropout=0.1,
        factor=5,
    ):
        super(InformerModel, self).__init__()
        self.num_continuous = num_continuous
        self.d_model = d_model
        self.value_embedding = nn.Linear(1, d_model)
        self.position_embedding = nn.Parameter(torch.randn(1, num_continuous, d_model))
        encoder_layer = InformerEncoderLayer(
            d_model, n_heads, d_ff, dropout=dropout, factor=factor
        )
        self.encoder = InformerEncoder(encoder_layer, num_layers)
        self.mlp = nn.Sequential(nn.Linear(num_continuous * d_model, output_dim))

    def forward(self, x_cont):
        # x_cont: (batch_size, num_continuous)
        batch_size = x_cont.size(0)
        x = self.value_embedding(x_cont.unsqueeze(-1))  # (batch_size, num_continuous, d_model)
        x += self.position_embedding[:, : self.num_continuous, :]
        x = self.encoder(x)  # (batch_size, num_continuous, d_model)
        x = x.reshape(batch_size, -1)  # (batch_size, num_continuous * d_model)
        out = self.mlp(x)  # (batch_size, output_dim)
        return out

# %%
# Hyperparameters
num_continuous = X_central.shape[1]

dim = 256
depth = 4
heads = 8
attn_dropout = 0.3
ff_dropout = 0.1
mlp_hidden_mults = (4, 2)
mlp_act = nn.GELU()
output_dim = len(np.unique(y_bin))
num_epochs = 10
clients = 3
num_rounds = 3
k_folds = 5
batch_size = 32

# %%
warnings.filterwarnings("ignore")

import pandas as pd  # Import pandas for DataFrame operations
from sklearn.metrics import ConfusionMatrixDisplay
from torch.utils.data import ConcatDataset

# Function to train a local model
def train_local_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=num_epochs, client_id=None, fold=None, round_num=None):
    model.train()
    train_epoch_metrics = {'loss': [], 'accuracy': [], 'precision': [], 'recall': [], 'f1': [], 'roc_auc': []}
    val_epoch_metrics = {'loss': [], 'accuracy': [], 'precision': [], 'recall': [], 'f1': [], 'roc_auc': []}

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        total_loss = 0
        all_probs = []
        all_preds = []
        all_labels = []
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            # Get probabilities and predictions
            probabilities = torch.softmax(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            all_probs.extend(probabilities.detach().cpu().numpy())
            all_preds.extend(predicted.detach().cpu().numpy())
            all_labels.extend(labels.detach().cpu().numpy())

        # Calculate training metrics for the epoch
        accuracy = accuracy_score(all_labels, all_preds)
        precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
        recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)
        f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)
        try:
            roc_auc = roc_auc_score(all_labels, np.array(all_probs), multi_class='ovr')
        except ValueError:
            roc_auc = 0

        avg_loss = total_loss / len(train_loader)
        train_epoch_metrics['loss'].append(avg_loss)
        train_epoch_metrics['accuracy'].append(accuracy)
        train_epoch_metrics['precision'].append(precision)
        train_epoch_metrics['recall'].append(recall)
        train_epoch_metrics['f1'].append(f1)
        train_epoch_metrics['roc_auc'].append(roc_auc)

        print(f'Train Epoch {epoch + 1}')
        print(f'Accuracy: {accuracy:.4f}, Loss: {avg_loss:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}, ROC-AUC: {roc_auc:.4f}')

        # Validation phase
        model.eval()
        val_loss = 0
        val_all_probs = []
        val_all_preds = []
        val_all_labels = []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                probabilities = torch.softmax(outputs, dim=1)
                _, predicted = torch.max(outputs, 1)

                val_all_probs.extend(probabilities.detach().cpu().numpy())
                val_all_preds.extend(predicted.detach().cpu().numpy())
                val_all_labels.extend(labels.detach().cpu().numpy())

        # Calculate validation metrics for the epoch
        val_accuracy = accuracy_score(val_all_labels, val_all_preds)
        val_precision = precision_score(val_all_labels, val_all_preds, average='weighted', zero_division=0)
        val_recall = recall_score(val_all_labels, val_all_preds, average='weighted', zero_division=0)
        val_f1 = f1_score(val_all_labels, val_all_preds, average='weighted', zero_division=0)
        try:
            val_roc_auc = roc_auc_score(val_all_labels, np.array(val_all_probs), multi_class='ovr')
        except ValueError:
            val_roc_auc = 0

        avg_val_loss = val_loss / len(val_loader)
        val_epoch_metrics['loss'].append(avg_val_loss)
        val_epoch_metrics['accuracy'].append(val_accuracy)
        val_epoch_metrics['precision'].append(val_precision)
        val_epoch_metrics['recall'].append(val_recall)
        val_epoch_metrics['f1'].append(val_f1)
        val_epoch_metrics['roc_auc'].append(val_roc_auc)

        print(f'Validation Epoch {epoch + 1}')
        print(f'Accuracy: {val_accuracy:.4f}, Loss: {avg_val_loss:.4f}, Precision: {val_precision:.4f}, Recall: {val_recall:.4f}, F1-Score: {val_f1:.4f}, ROC-AUC: {val_roc_auc:.4f}')
        scheduler.step(val_accuracy)

    # Prepare a DataFrame with the metrics
    epochs = range(1, num_epochs + 1)
    metrics_df = pd.DataFrame({
        'epoch': epochs,
        'train_loss': train_epoch_metrics['loss'],
        'train_accuracy': train_epoch_metrics['accuracy'],
        'train_precision': train_epoch_metrics['precision'],
        'train_recall': train_epoch_metrics['recall'],
        'train_f1': train_epoch_metrics['f1'],
        'train_roc_auc': train_epoch_metrics['roc_auc'],
        'val_loss': val_epoch_metrics['loss'],
        'val_accuracy': val_epoch_metrics['accuracy'],
        'val_precision': val_epoch_metrics['precision'],
        'val_recall': val_epoch_metrics['recall'],
        'val_f1': val_epoch_metrics['f1'],
        'val_roc_auc': val_epoch_metrics['roc_auc']
    })
    # Save the DataFrame to CSV
    metrics_df.to_csv(f'{folder_name}/client_{client_id}_metrics_fold_{fold}_round_{round_num}.csv', index=False)

    print("All metrics saved into CSV file.")

    return model.state_dict()  # Return model weights after training

# Federated Averaging Function
def federated_avg(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.mean(
            torch.stack([client_model[k].float() for client_model in client_models]), dim=0
        )
    global_model.load_state_dict(global_dict)
    return global_model

# Evaluation Function
def evaluate_model(model, data_loader, criterion=None):
    model.eval()
    all_probs = []
    all_preds = []
    all_labels = []
    total_loss = 0
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            if criterion is not None:
                loss = criterion(outputs, labels)
                total_loss += loss.item()
            probabilities = torch.softmax(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            all_probs.extend(probabilities.detach().cpu().numpy())
            all_preds.extend(predicted.detach().cpu().numpy())
            all_labels.extend(labels.detach().cpu().numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)
    precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)

    # Calculate ROC AUC
    try:
        roc_auc = roc_auc_score(all_labels, np.array(all_probs), multi_class='ovr')
    except ValueError:
        roc_auc = 0

    if criterion is not None and len(data_loader) > 0:
        avg_loss = total_loss / len(data_loader)
    else:
        avg_loss = None

    conf_matrix = confusion_matrix(all_labels, all_preds, labels=list(range(output_dim)))
    #conf_matrix = confusion_matrix(all_labels, all_preds)


    return accuracy, f1, precision, recall, roc_auc, conf_matrix, avg_loss

# Initialize tracking lists for global metricsconf_matrix = confusion_matrix(all_labels, all_preds)
global_metrics = {
    'train_loss': [],
    'train_accuracy': [],
    'train_precision': [],
    'train_recall': [],
    'train_f1': [],
    'train_roc_auc': [],
    'val_loss': [],
    'val_accuracy': [],
    'val_precision': [],
    'val_recall': [],
    'val_f1': [],
    'val_roc_auc': []
}

# K-Fold Cross Validation setup
kf = KFold(n_splits=k_folds, shuffle=True, random_state=80)
fold_results = []

for fold, (train_idx, val_idx) in enumerate(kf.split(central_dataset)):
    print(f"\nFold {fold + 1}/{k_folds}")

    # Split the central dataset into train and validation sets for this fold
    train_subset = Subset(central_dataset, train_idx)
    val_subset = Subset(central_dataset, val_idx)

    central_train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    central_val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    # Split each client dataset into training and validation subsets
    client_train_loaders = []
    client_val_loaders = []
    combined_datasets_clients = []

    for client_id, client_dataset in enumerate(client_datasets):
        dataset_size = len(client_dataset)
        val_size = int(0.2 * dataset_size)
        train_size = dataset_size - val_size
        train_subset_client, val_subset_client = random_split(
            client_dataset, [train_size, val_size], generator=torch.Generator().manual_seed(fold + client_id)
        )
        train_loader_client = DataLoader(train_subset_client, batch_size=batch_size, shuffle=True)
        val_loader_client = DataLoader(val_subset_client, batch_size=batch_size, shuffle=False)
        client_train_loaders.append(train_loader_client)
        client_val_loaders.append(val_loader_client)

        # Create combined dataset for the client
        combined_dataset_client = ConcatDataset([train_subset_client, val_subset_client])
        combined_datasets_clients.append(combined_dataset_client)

    # Reset global model and metrics for each fold
    global_model = InformerModel(
        num_continuous=num_continuous,
        d_model=dim,
        d_ff=dim * 4,
        num_layers=depth,
        n_heads=heads,
        output_dim=output_dim,
        dropout=attn_dropout,
        factor=5,
    ).to(device)
    criterion = nn.CrossEntropyLoss()

    # Clear metrics lists for each fold
    for key in global_metrics.keys():
        global_metrics[key].clear()

    # Federated Learning Rounds
    for round in range(num_rounds):
        print(f"\nRound {round+1}/{num_rounds}")
        client_models = []
        client_metrics = []

        for client_id, (train_loader, val_loader) in enumerate(zip(client_train_loaders, client_val_loaders)):
            print(f"\nTraining on Client {client_id + 1}")
            local_model = InformerModel(
                num_continuous=num_continuous,
                d_model=dim,
                d_ff=dim * 4,
                num_layers=depth,
                n_heads=heads,
                output_dim=output_dim,
                dropout=attn_dropout,
                factor=5,
            ).to(device)
            local_model.load_state_dict(global_model.state_dict())  # Start from global model
            optimizer = optim.AdamW(local_model.parameters(), lr=1e-4)
            scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.2, patience=2)
            # Train local model
            print(f"Client {client_id + 1}: Starting training with {len(train_loader)} batches...")
            client_model_weights = train_local_model(
                local_model, train_loader, val_loader, criterion, optimizer, num_epochs, client_id=client_id + 1, fold=fold + 1, round_num=round + 1
            )
            print(f"Client {client_id + 1}: Finished training. Returning model weights.")

            # Create combined loader for the client
            combined_loader = DataLoader(combined_datasets_clients[client_id], batch_size=batch_size, shuffle=False)

            # Evaluate client model on combined training and validation data
            val_accuracy, val_f1, val_precision, val_recall, val_roc_auc, conf_matrix, val_loss = evaluate_model(
                local_model, combined_loader, criterion
            )
            client_metrics.append(
                {
                    "accuracy": val_accuracy,
                    "precision": val_precision,
                    "recall": val_recall,
                    "f1": val_f1,
                    "roc_auc": val_roc_auc,
                    "loss": val_loss
                }
            )

            # Print confusion matrix
            print(f"Client {client_id + 1} Combined Training and Validation Confusion Matrix:")
            print(conf_matrix)

            # Plot and save confusion matrix with round indicator
            classes = [str(i) for i in range(output_dim)]
            disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=classes)
            disp.plot(cmap=plt.cm.Blues)
            plt.title(f'Client {client_id + 1} Confusion Matrix on Combined Data (Fold {fold + 1}, Round {round + 1})')
            plt.savefig(f'{folder_name}/client_{client_id + 1}_confusion_matrix_combined_fold_{fold + 1}_round_{round + 1}.png')
            plt.close()

            client_models.append(client_model_weights)

        # Calculate average client metrics
        avg_client_accuracy = np.mean([metric["accuracy"] for metric in client_metrics])
        avg_client_precision = np.mean([metric["precision"] for metric in client_metrics])
        avg_client_recall = np.mean([metric["recall"] for metric in client_metrics])
        avg_client_f1 = np.mean([metric["f1"] for metric in client_metrics])
        avg_client_roc_auc = np.mean([metric["roc_auc"] for metric in client_metrics])

        # Perform Federated Averaging
        print("Performing Federated Averaging to update the global model...")
        global_model = federated_avg(global_model, client_models)
        print("Global model updated.")

        # Create combined dataset and loader for all clients
        combined_clients_dataset = ConcatDataset(combined_datasets_clients)
        combined_clients_loader = DataLoader(combined_clients_dataset, batch_size=batch_size, shuffle=False)

        # Evaluate the global model on the combined client data (train data)
        train_accuracy, train_f1, train_precision, train_recall, train_roc_auc, train_conf_matrix, train_loss = evaluate_model(
            global_model, combined_clients_loader, criterion
        )
        global_metrics['train_loss'].append(train_loss)
        global_metrics['train_accuracy'].append(train_accuracy)
        global_metrics['train_precision'].append(train_precision)
        global_metrics['train_recall'].append(train_recall)
        global_metrics['train_f1'].append(train_f1)
        global_metrics['train_roc_auc'].append(train_roc_auc)

        # Evaluate the global model on the central validation set
        val_accuracy, val_f1, val_precision, val_recall, val_roc_auc, val_conf_matrix, val_loss = evaluate_model(
            global_model, central_val_loader, criterion
        )
        global_metrics['val_loss'].append(val_loss)
        global_metrics['val_accuracy'].append(val_accuracy)
        global_metrics['val_precision'].append(val_precision)
        global_metrics['val_recall'].append(val_recall)
        global_metrics['val_f1'].append(val_f1)
        global_metrics['val_roc_auc'].append(val_roc_auc)

        # Print confusion matrix for combined client data
        print(f"Global Model Confusion Matrix on Combined Client Data for Fold {fold + 1}, Round {round + 1}:")
        print(train_conf_matrix)

        # Plot and save confusion matrix
        classes = [str(i) for i in range(output_dim)]
        disp = ConfusionMatrixDisplay(confusion_matrix=train_conf_matrix, display_labels=classes)
        disp.plot(cmap=plt.cm.Blues)
        plt.title(f'Global Model Confusion Matrix on Combined Client Data (Fold {fold + 1}, Round {round + 1})')
        plt.savefig(f'{folder_name}/global_model_confusion_matrix_combined_clients_fold_{fold + 1}_round_{round + 1}.png')
        plt.close()

        # Print confusion matrix for central validation data
        print(f"Global Model Validation Confusion Matrix for Fold {fold + 1}, Round {round + 1}:")
        print(val_conf_matrix)

        # Plot and save confusion matrix
        disp = ConfusionMatrixDisplay(confusion_matrix=val_conf_matrix, display_labels=classes)
        disp.plot(cmap=plt.cm.Blues)
        plt.title(f'Global Model Confusion Matrix on Central Validation Data (Fold {fold + 1}, Round {round + 1})')
        plt.savefig(f'{folder_name}/global_model_confusion_matrix_central_val_fold_{fold + 1}_round_{round + 1}.png')
        plt.close()

        print(f"Round {round+1}/{num_rounds}, Global Model Metrics:")
        print(f"On Combined Client Data (Train):")
        print(
            f"Loss: {train_loss:.4f}, Accuracy: {train_accuracy:.4f}, Precision: {train_precision:.4f}, "
            f"Recall: {train_recall:.4f}, F1 Score: {train_f1:.4f}, ROC AUC: {train_roc_auc:.4f}"
        )
        print(f"On Central Validation Data:")
        print(
            f"Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}, Precision: {val_precision:.4f}, "
            f"Recall: {val_recall:.4f}, F1 Score: {val_f1:.4f}, ROC AUC: {val_roc_auc:.4f}"
        )

    # Prepare a DataFrame with the global metrics over rounds
    rounds = range(1, num_rounds + 1)
    global_metrics_df = pd.DataFrame({
        'round': rounds,
        'train_loss': global_metrics['train_loss'],
        'train_accuracy': global_metrics['train_accuracy'],
        'train_precision': global_metrics['train_precision'],
        'train_recall': global_metrics['train_recall'],
        'train_f1': global_metrics['train_f1'],
        'train_roc_auc': global_metrics['train_roc_auc'],
        'val_loss': global_metrics['val_loss'],
        'val_accuracy': global_metrics['val_accuracy'],
        'val_precision': global_metrics['val_precision'],
        'val_recall': global_metrics['val_recall'],
        'val_f1': global_metrics['val_f1'],
        'val_roc_auc': global_metrics['val_roc_auc']
    })
    # Save the DataFrame to CSV
    global_metrics_df.to_csv(f'{folder_name}/global_model_metrics_fold_{fold + 1}.csv', index=False)
    print("Global model metrics over rounds saved into CSV file.")

    # Evaluation on the combined client data and central validation data after federated training for this fold
    # Evaluate on combined client data
    train_accuracy, train_f1, train_precision, train_recall, train_roc_auc, train_conf_matrix, train_loss = evaluate_model(
        global_model, combined_clients_loader, criterion
    )

    # Evaluate on central validation data
    val_accuracy, val_f1, val_precision, val_recall, val_roc_auc, val_conf_matrix, val_loss = evaluate_model(
        global_model, central_val_loader, criterion
    )

    # Print confusion matrix for combined client data
    print(f"Final Global Model Confusion Matrix on Combined Client Data for Fold {fold + 1}:")
    print(train_conf_matrix)

    # Plot and save confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=train_conf_matrix, display_labels=classes)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Final Global Model Confusion Matrix on Combined Client Data (Fold {fold + 1})')
    plt.savefig(f'{folder_name}/final_global_model_confusion_matrix_combined_clients_fold_{fold + 1}.png')
    plt.close()

    # Print confusion matrix for central validation data
    print(f"Final Global Model Validation Confusion Matrix for Fold {fold + 1}:")
    print(val_conf_matrix)

    # Plot and save confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=val_conf_matrix, display_labels=classes)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Final Global Model Confusion Matrix on Central Validation Data (Fold {fold + 1})')
    plt.savefig(f'{folder_name}/final_global_model_confusion_matrix_central_val_fold_{fold + 1}.png')
    plt.close()

    # Store fold results
    fold_results.append(
        {
            "fold": fold + 1,
            "train_accuracy": train_accuracy,
            "train_f1": train_f1,
            "train_precision": train_precision,
            "train_recall": train_recall,
            "train_roc_auc": train_roc_auc,
            "train_loss": train_loss,
            "val_accuracy": val_accuracy,
            "val_f1": val_f1,
            "val_precision": val_precision,
            "val_recall": val_recall,
            "val_roc_auc": val_roc_auc,
            "val_loss": val_loss
        }
    )

# Print overall results
def save_kfold_results(fold_results):
    # Convert fold_results to DataFrame
    fold_results_df = pd.DataFrame(fold_results)
    # Save to CSV
    fold_results_df.to_csv(f'{folder_name}/kfold_metrics.csv', index=False)
    print("K-Fold cross-validation metrics saved into CSV file.")

# Call the function to save K-Fold results
save_kfold_results(fold_results)
# Out:
# Fold 1/5
#
# Round 1/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.
# Accuracy: 0.9024, Loss: 0.2464, Precision: 0.8840, Recall: 0.9024, F1-Score: 0.8763, ROC-AUC: 0.9735
# Train Epoch 10
# Accuracy: 0.8998, Loss: 0.2373, Precision: 0.8781, Recall: 0.8998, F1-Score: 0.8809, ROC-AUC: 0.9744
# Validation Epoch 10
# Accuracy: 0.9008, Loss: 0.2475, Precision: 0.8911, Recall: 0.9008, F1-Score: 0.8720, ROC-AUC: 0.9743
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 399   79    2    0    0    0]
#  [   1 6774   12    0    1    0]
#  [   6  443   35    3    0    0]
#  [   0  342    5  117    0    0]
#  [   0    0    0    0  407    0]
#  [   0    0    0    0    0  495]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 1, Round 1:
# [[ 1176   213    11     0     0     0]
#  [    5 20413    65    26     0     0]
#  [   17  1229   128    18     0     0]
#  [    0  1017    15   338     0     0]
#  [    0    69     0     0  1133     0]
#  [    0     0     0     0     0  1490]]
# Global Model Validation Confusion Matrix for Fold 1, Round 1:
# [[  99   18    1    0    0    0]
#  [   0 1757    4    3    0    0]
#  [   0  110   11    1    0    0]
#  [   0   76    2   31    0    0]
#  [   0    6    0    0  107    0]
#  [   0    0    0    0    0  120]]
# Round 1/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2311, Accuracy: 0.9019, Precision: 0.8896, Recall: 0.9019, F1 Score: 0.8751, ROC AUC: 0.9753
# On Central Validation Data:
# Loss: 0.2335, Accuracy: 0.9058, Precision: 0.8942, Recall: 0.9058, F1 Score: 0.8803, ROC AUC: 0.9750
#
# Round 2/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8915, Loss: 0.2500, Precision: 0.8727, Recall: 0.8915, F1-Score: 0.8767, ROC-AUC: 0.9712
# Validation Epoch 1
# Accuracy: 0.8931, Loss: 0.2730, Precision: 0.8853, Recall: 0.8931, F1-Score: 0.8607, ROC-AUC: 0.9746
# Train Epoch 2
# Accuracy: 0.8904, Loss: 0.2501, Precision: 0.8703, Recall: 0.8904, F1-Score: 0.8754, ROC-AUC: 0.9714
# Validation Epoch 2
# Accuracy: 0.8958, Loss: 0.2406, Precision: 0.8831, Recall: 0.8958, F1-Score: 0.8648, ROC-AUC: 0.9749
# Train Epoch 3
# Accuracy: 0.8905, Loss: 0.2500, Precision: 0.8666, Recall: 0.8905, F1-Score: 0.8728, ROC-AUC: 0.9722
# Validation Epoch 3
# Accuracy: 0.8832, Loss: 0.2666, Precision: 0.9149, Recall: 0.8832, F1-Score: 0.8818, ROC-AUC: 0.9758
# Train Epoch 4
# Accuracy: 0.8852, Loss: 0.2633, Precision: 0.8649, Recall: 0.8852, F1-Score: 0.8712, ROC-AUC: 0.9702
# Validation Epoch 4
# Accuracy: 0.8925, Loss: 0.2555, Precision: 0.8824, Recall: 0.8925, F1-Score: 0.8613, ROC-AUC: 0.9761
# Train Epoch 5
# Accuracy: 0.8912, Loss: 0.2431, Precision: 0.8714, Recall: 0.8912, F1-Score: 0.8765, ROC-AUC: 0.9730
# Validation Epoch 5
# Accuracy: 0.8986, Loss: 0.2348, Precision: 0.9090, Recall: 0.8986, F1-Score: 0.8638, ROC-AUC: 0.9766
# Train Epoch 6
# Accuracy: 0.8894, Loss: 0.2445, Precision: 0.8685, Recall: 0.8894, F1-Score: 0.8737, ROC-AUC: 0.9718
# Validation Epoch 6
# Accuracy: 0.9002, Loss: 0.2378, Precision: 0.8996, Recall: 0.9002, F1-Score: 0.8686, ROC-AUC: 0.9764
# Accuracy: 0.9024, Loss: 0.2535, Precision: 0.8953, Recall: 0.9024, F1-Score: 0.8876, ROC-AUC: 0.9734
# Train Epoch 6
# Accuracy: 0.8928, Loss: 0.2450, Precision: 0.8754, Recall: 0.8928, F1-Score: 0.8803, ROC-AUC: 0.9737
# Validation Epoch 6
# Accuracy: 0.9019, Loss: 0.2522, Precision: 0.8868, Recall: 0.9019, F1-Score: 0.8829, ROC-AUC: 0.9754
# Train Epoch 7
# Accuracy: 0.8915, Loss: 0.2450, Precision: 0.8721, Recall: 0.8915, F1-Score: 0.8777, ROC-AUC: 0.9741
# Validation Epoch 7
# Accuracy: 0.9008, Loss: 0.2542, Precision: 0.8969, Recall: 0.9008, F1-Score: 0.8702, ROC-AUC: 0.9749
# Train Epoch 8
# Accuracy: 0.9011, Loss: 0.2292, Precision: 0.8830, Recall: 0.9011, F1-Score: 0.8848, ROC-AUC: 0.9761
# Validation Epoch 8
# Accuracy: 0.9073, Loss: 0.2343, Precision: 0.8972, Recall: 0.9073, F1-Score: 0.8874, ROC-AUC: 0.9756
# Train Epoch 9
# Accuracy: 0.9008, Loss: 0.2242, Precision: 0.8826, Recall: 0.9008, F1-Score: 0.8845, ROC-AUC: 0.9770
# Validation Epoch 9
# Accuracy: 0.9062, Loss: 0.2354, Precision: 0.8987, Recall: 0.9062, F1-Score: 0.8958, ROC-AUC: 0.9756
# Train Epoch 10
# Accuracy: 0.9031, Loss: 0.2246, Precision: 0.8850, Recall: 0.9031, F1-Score: 0.8863, ROC-AUC: 0.9770
# Validation Epoch 10
# Accuracy: 0.9079, Loss: 0.2346, Precision: 0.8942, Recall: 0.9079, F1-Score: 0.8915, ROC-AUC: 0.9767
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 399   71    9    1    0    0]
#  [   0 6729   31   28    0    0]
#  [   0  384   80   23    0    0]
#  [   0  279   17  168    0    0]
#  [   0    0    0    0  407    0]
#  [   0    0    0    0    0  495]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 1, Round 2:
# [[ 1171   195    34     0     0     0]
#  [    0 20309   192     8     0     0]
#  [    1  1085   296    10     0     0]
#  [    0   962    70   338     0     0]
#  [    0     0     0     0  1202     0]
#  [    0     0     0     0     0  1490]]
# Global Model Validation Confusion Matrix for Fold 1, Round 2:
# [[  99   14    5    0    0    0]
#  [   0 1746   18    0    0    0]
#  [   0  100   21    1    0    0]
#  [   0   75    6   28    0    0]
#  [   0    0    0    0  113    0]
#  [   0    0    0    0    0  120]]
# Round 2/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2215, Accuracy: 0.9066, Precision: 0.8975, Recall: 0.9066, F1 Score: 0.8868, ROC AUC: 0.9773
# On Central Validation Data:
# Loss: 0.2217, Accuracy: 0.9066, Precision: 0.8948, Recall: 0.9066, F1 Score: 0.8866, ROC AUC: 0.9773
#
# Round 3/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8930, Loss: 0.2502, Precision: 0.8708, Recall: 0.8930, F1-Score: 0.8756, ROC-AUC: 0.9713
# Validation Epoch 1
# Accuracy: 0.8997, Loss: 0.2466, Precision: 0.8959, Recall: 0.8997, F1-Score: 0.8661, ROC-AUC: 0.9750
# Train Epoch 2
# Accuracy: 0.8994, Loss: 0.2313, Precision: 0.8804, Recall: 0.8994, F1-Score: 0.8830, ROC-AUC: 0.9738
# Validation Epoch 2
# Accuracy: 0.9002, Loss: 0.2637, Precision: 0.9003, Recall: 0.9002, F1-Score: 0.8674, ROC-AUC: 0.9756
# Train Epoch 3
# Validation Epoch 2
# Accuracy: 0.9068, Loss: 0.2336, Precision: 0.8727, Recall: 0.9068, F1-Score: 0.8754, ROC-AUC: 0.9748
# Train Epoch 3
# Accuracy: 0.8972, Loss: 0.2495, Precision: 0.8780, Recall: 0.8972, F1-Score: 0.8819, ROC-AUC: 0.9734
# Validation Epoch 3
# Accuracy: 0.9062, Loss: 0.2261, Precision: 0.8912, Recall: 0.9062, F1-Score: 0.8913, ROC-AUC: 0.9762
# Train Epoch 4
# Accuracy: 0.9005, Loss: 0.2348, Precision: 0.8818, Recall: 0.9005, F1-Score: 0.8867, ROC-AUC: 0.9748
# Validation Epoch 4
# Accuracy: 0.9106, Loss: 0.2296, Precision: 0.8968, Recall: 0.9106, F1-Score: 0.8987, ROC-AUC: 0.9759
# Train Epoch 5
# Accuracy: 0.9017, Loss: 0.2320, Precision: 0.8831, Recall: 0.9017, F1-Score: 0.8869, ROC-AUC: 0.9745
# Validation Epoch 5
# Accuracy: 0.9068, Loss: 0.2251, Precision: 0.8803, Recall: 0.9068, F1-Score: 0.8857, ROC-AUC: 0.9752
# Train Epoch 6
# Accuracy: 0.9028, Loss: 0.2426, Precision: 0.8854, Recall: 0.9028, F1-Score: 0.8885, ROC-AUC: 0.9740
# Validation Epoch 6
# Accuracy: 0.8816, Loss: 0.2376, Precision: 0.8921, Recall: 0.8816, F1-Score: 0.8854, ROC-AUC: 0.9758
# Train Epoch 7
# Accuracy: 0.8983, Loss: 0.2407, Precision: 0.8801, Recall: 0.8983, F1-Score: 0.8852, ROC-AUC: 0.9737
# Validation Epoch 7
# Accuracy: 0.9062, Loss: 0.2437, Precision: 0.8764, Recall: 0.9062, F1-Score: 0.8764, ROC-AUC: 0.9751
# Train Epoch 8
# Accuracy: 0.9075, Loss: 0.2242, Precision: 0.8916, Recall: 0.9075, F1-Score: 0.8909, ROC-AUC: 0.9757
# Validation Epoch 8
# Accuracy: 0.9090, Loss: 0.2173, Precision: 0.8908, Recall: 0.9090, F1-Score: 0.8880, ROC-AUC: 0.9768
# Train Epoch 9
# Accuracy: 0.9098, Loss: 0.2179, Precision: 0.8952, Recall: 0.9098, F1-Score: 0.8929, ROC-AUC: 0.9772
# Validation Epoch 9
# Accuracy: 0.9084, Loss: 0.2165, Precision: 0.8907, Recall: 0.9084, F1-Score: 0.8919, ROC-AUC: 0.9773
# Train Epoch 10
# Accuracy: 0.9098, Loss: 0.2182, Precision: 0.8964, Recall: 0.9098, F1-Score: 0.8938, ROC-AUC: 0.9768
# Validation Epoch 10
# Accuracy: 0.9095, Loss: 0.2170, Precision: 0.8873, Recall: 0.9095, F1-Score: 0.8882, ROC-AUC: 0.9773
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 389   70    8    1    0    0]
#  [   0 6795   28   24    0    0]
#  [   0  350   65   16    0    0]
#  [   0  321   13  127    0    0]
#  [   0    0    0    0  413    0]
#  [   0    0    0    0    0  501]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.
0]
#  [   0    0    0    0    0  495]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 1, Round 3:
# [[ 1171   184    37     8     0     0]
#  [    0 20284   198    27     0     0]
#  [    0  1046   315    31     0     0]
#  [    0   938    74   358     0     0]
#  [    0     0     0     0  1202     0]
#  [    0     0     0     0     0  1490]]
# Global Model Validation Confusion Matrix for Fold 1, Round 3:
# [[  99   15    3    1    0    0]
#  [   0 1741   20    3    0    0]
#  [   0  103   18    1    0    0]
#  [   0   74    6   29    0    0]
#  [   0    0    0    0  113    0]
#  [   0    0    0    0    0  120]]
# Round 3/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2225, Accuracy: 0.9071, Precision: 0.8946, Recall: 0.9071, F1 Score: 0.8886, ROC AUC: 0.9777
# On Central Validation Data:
# Loss: 0.2249, Accuracy: 0.9037, Precision: 0.8864, Recall: 0.9037, F1 Score: 0.8833, ROC AUC: 0.9770
# Global model metrics over rounds saved into CSV file.
# Final Global Model Confusion Matrix on Combined Client Data for Fold 1:
# [[ 1171   184    37     8     0     0]
#  [    0 20284   198    27     0     0]
#  [    0  1046   315    31     0     0]
#  [    0   938    74   358     0     0]
#  [    0     0     0     0  1202     0]
#  [    0     0     0     0     0  1490]]
# Final Global Model Validation Confusion Matrix for Fold 1:
# [[  99   15    3    1    0    0]
#  [   0 1741   20    3    0    0]
#  [   0  103   18    1    0    0]
#  [   0   74    6   29    0    0]
#  [   0    0    0    0  113    0]
#  [   0    0    0    0    0  120]]
#
# Fold 2/5
#
# Round 1/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.7298, Loss: 0.7020, Precision: 0.6529, Recall: 0.7298, F1-Score: 0.6849, ROC-AUC: 0.8499
# Validation Epoch 1
# Accuracy: 0.7697, Loss: 0.5687, Precision: 0.5928, Recall: 0.7697, F1-Score: 0.6698, ROC-AUC: 0.9093
# Train Epoch 2
# Accuracy: 0.7798, Loss: 0.5497, Precision: 0.7347, Recall: 0.7798, F1-Score: 0.7509, ROC-AUC: 0.9133
# Validation Epoch 2
# Accuracy: 0.8717, Loss: 0.3728, Precision: 0.8355, Recall: 0.8717, F1-Score: 0.8501, ROC-AUC: 0.9556
# Train Epoch 3
# Accuracy: 0.8517, Loss: 0.3982, Precision: 0.8265, Recall: 0.8517, F1-Score: 0.8327, ROC-AUC: 0.9519
# Validation Epoch 3
# Accuracy: 0.8832, Loss: 0.3208, Precision: 0.8114, Recall: 0.8832, F1-Score: 0.8439, ROC-AUC: 0.9678
# Train Epoch 4
# Accuracy: 0.8667, Loss: 0.3352, Precision: 0.8382, Recall: 0.8667, F1-Score: 0.8486, ROC-AUC: 0.9612
# Validation Epoch 4
# Accuracy: 0.8975, Loss: 0.2447, Precision: 0.8924, Recall: 0.8975, F1-Score: 0.8941, ROC-AUC: 0.9739
# Train Epoch 5
# Accuracy: 0.8776, Loss: 0.2942, Precision: 0.8513, Recall: 0.8776, F1-Score: 0.8603, ROC-AUC: 0.9654
# Validation Epoch 5
# Accuracy: 0.8799, Loss: 0.2522, Precision: 0.9329, Recall: 0.8799, F1-Score: 0.8966, ROC-AUC: 0.9751
# Train Epoch 6
# Accuracy: 0.8826, Loss: 0.2757, Precision: 0.8610, Recall: 0.8826, F1-Score: 0.8683, ROC-AUC: 0.9682
# Validation Epoch 6
# Accuracy: 0.9062, Loss: 0.2352, Precision: 0.9146, Recall: 0.9062, F1-Score: 0.8761, ROC-AUC: 0.9749
# Accuracy: 0.8890, Loss: 0.2751, Precision: 0.8695, Recall: 0.8890, F1-Score: 0.8753, ROC-AUC: 0.9690
# Validation Epoch 6
# Accuracy: 0.9013, Loss: 0.2570, Precision: 0.8956, Recall: 0.9013, F1-Score: 0.8720, ROC-AUC: 0.9723
# Train Epoch 7
# Accuracy: 0.8895, Loss: 0.2660, Precision: 0.8679, Recall: 0.8895, F1-Score: 0.8737, ROC-AUC: 0.9711
# Validation Epoch 7
# Accuracy: 0.9079, Loss: 0.2319, Precision: 0.9009, Recall: 0.9079, F1-Score: 0.8798, ROC-AUC: 0.9734
# Train Epoch 8
# Accuracy: 0.8883, Loss: 0.2626, Precision: 0.8646, Recall: 0.8883, F1-Score: 0.8725, ROC-AUC: 0.9705
# Validation Epoch 8
# Accuracy: 0.8690, Loss: 0.2629, Precision: 0.9027, Recall: 0.8690, F1-Score: 0.8833, ROC-AUC: 0.9693
# Train Epoch 9
# Accuracy: 0.8919, Loss: 0.2631, Precision: 0.8716, Recall: 0.8919, F1-Score: 0.8772, ROC-AUC: 0.9719
# Validation Epoch 9
# Accuracy: 0.8613, Loss: 0.2701, Precision: 0.9147, Recall: 0.8613, F1-Score: 0.8813, ROC-AUC: 0.9697
# Train Epoch 10
# Accuracy: 0.8839, Loss: 0.2779, Precision: 0.8660, Recall: 0.8839, F1-Score: 0.8726, ROC-AUC: 0.9701
# Validation Epoch 10
# Accuracy: 0.8821, Loss: 0.2792, Precision: 0.9085, Recall: 0.8821, F1-Score: 0.8754, ROC-AUC: 0.9685
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 389   52    1   26    0    0]
#  [   0 6453    2  385    0    7]
#  [   0  255   24  145    0    7]
#  [   0  181    8  266    0    6]
#  [   0   22    0    0  391    0]
#  [   0    0    0    0    0  501]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.7250, Loss: 0.7196, Precision: 0.6484, Recall: 0.7250, F1-Score: 0.6792, ROC-AUC: 0.8478
# Validation Epoch 1
# Accuracy: 0.7637, Loss: 0.6122, Precision: 0.6951, Recall: 0.7637, F1-Score: 0.7189, ROC-AUC: 0.9104
# Train Epoch 2
# Accuracy: 0.7674, Loss: 0.5744, Precision: 0.7315, Recall: 0.7674, F1-Score: 0.7445, ROC-AUC: 0.9054
# Validation Epoch 2
# Accuracy: 0.8416, Loss: 0.4272, Precision: 0.8181, Recall: 0.8416, F1-Score: 0.8258, ROC-AUC: 0.9524
# Train Epoch 3
# Accuracy: 0.8421, Loss: 0.4161, Precision: 0.8139, Recall: 0.8421, F1-Score: 0.8215, ROC-AUC: 0.9487
# Validation Epoch 3
# Accuracy: 0.8690, Loss: 0.3423, Precision: 0.8322, Recall: 0.8690, F1-Score: 0.8465, ROC-AUC: 0.9697
# Train Epoch 4
# Accuracy: 0.8605, Loss: 0.3488, Precision: 0.8388, Recall: 0.8605, F1-Score: 0.8465, ROC-AUC: 0.9609
# Validation Epoch 4
# Accuracy: 0.8591, Loss: 0.2739, Precision: 0.9020, Recall: 0.8591, F1-Score: 0.8755, ROC-AUC: 0.9742
# Train Epoch 5
# Accuracy: 0.8736, Loss: 0.3010, Precision: 0.8521, Recall: 0.8736, F1-Score: 0.8597, ROC-AUC: 0.9665
# Validation Epoch 5
# Accuracy: 0.8854, Loss: 0.2498, Precision: 0.8822, Recall: 0.8854, F1-Score: 0.8771, ROC-AUC: 0.9747
# Train Epoch 6
# Accuracy: 0.8794, Loss: 0.2864, Precision: 0.8536, Recall: 0.8794, F1-Score: 0.8622, ROC-AUC: 0.9679
# Validation Epoch 6
# Accuracy: 0.8586, Loss: 0.2816, Precision: 0.8833, Recall: 0.8586, F1-Score: 0.8663, ROC-AUC: 0.9745
# Train Epoch 7
# Accuracy: 0.8749, Loss: 0.2908, Precision: 0.8505, Recall: 0.8749, F1-Score: 0.8593, ROC-AUC: 0.9672
# Validation Epoch 7
# Accuracy: 0.9079, Loss: 0.2151, Precision: 0.8977, Recall: 0.9079, F1-Score: 0.8832, ROC-AUC: 0.9777
# Train Epoch 8
# Accuracy: 0.8789, Loss: 0.2864, Precision: 0.8620, Recall: 0.8789, F1-Score: 0.8681, ROC-AUC: 0.9694
# Validation Epoch 8
# Accuracy: 0.8684, Loss: 0.2897, Precision: 0.9134, Recall: 0.8684, F1-Score: 0.8761, ROC-AUC: 0.9762
# Train Epoch 9
# Accuracy: 0.8787, Loss: 0.2855, Precision: 0.8561, Recall: 0.8787, F1-Score: 0.8641, ROC-AUC: 0.9679
# Validation Epoch 9
# Accuracy: 0.8947, Loss: 0.2206, Precision: 0.8836, Recall: 0.8947, F1-Score: 0.8882, ROC-AUC: 0.9773
# Train Epoch 10
# Accuracy: 0.8850, Loss: 0.2632, Precision: 0.8618, Recall: 0.8850, F1-Score: 0.8688, ROC-AUC: 0.9711
# Validation Epoch 10
# Accuracy: 0.9101, Loss: 0.2118, Precision: 0.8962, Recall: 0.9101, F1-Score: 0.8861, ROC-AUC: 0.9783
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 400   73    7    0    0    0]
#  [   2 6749   37    0    0    0]
#  [   5  413   66    3    0    0]
#  [   3  323   21  117    0    0]
#  [   0    0    0    0  407    0]
#  [   0    0    0    0    0  495]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 2, Round 1:
# [[ 1172   186    31    11     0     0]
#  [    5 20077   169   258     0     0]
#  [   16  1060   215   101     0     0]
#  [   13   837    91   429     0     0]
#  [    0    69     0     0  1133     0]
#  [    0     0     0     0     0  1490]]
# Global Model Validation Confusion Matrix for Fold 2, Round 1:
# [[  93   20    1    0    0    0]
#  [   0 1729   14   18    0    0]
#  [   1   91   18   11    0    0]
#  [   2   71    7   47    0    0]
#  [   0    8    0    0   88    0]
#  [   0    0    0    0    0  126]]
# Round 1/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2360, Accuracy: 0.8960, Precision: 0.8736, Recall: 0.8960, F1 Score: 0.8786, ROC AUC: 0.9746
# On Central Validation Data:
# Loss: 0.2358, Accuracy: 0.8959, Precision: 0.8751, Recall: 0.8959, F1 Score: 0.8782, ROC AUC: 0.9754
#
# Round 2/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8839, Loss: 0.2618, Precision: 0.8567, Recall: 0.8839, F1-Score: 0.8658, ROC-AUC: 0.9699
# Validation Epoch 1
# Accuracy: 0.9139, Loss: 0.2193, Precision: 0.9046, Recall: 0.9139, F1-Score: 0.8864, ROC-AUC: 0.9760
# Train Epoch 2
# Accuracy: 0.8864, Loss: 0.2621, Precision: 0.8622, Recall: 0.8864, F1-Score: 0.8700, ROC-AUC: 0.9706
# Validation Epoch 2
0]
#  [   0    0    0    0  413    0]
#  [   0    0    0    0    0  501]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8843, Loss: 0.2737, Precision: 0.8626, Recall: 0.8843, F1-Score: 0.8693, ROC-AUC: 0.9695
# Validation Epoch 1
# Accuracy: 0.9095, Loss: 0.2289, Precision: 0.8984, Recall: 0.9095, F1-Score: 0.8809, ROC-AUC: 0.9779
# Train Epoch 2
# Accuracy: 0.8854, Loss: 0.2772, Precision: 0.8645, Recall: 0.8854, F1-Score: 0.8710, ROC-AUC: 0.9697
# Validation Epoch 2
# Accuracy: 0.8717, Loss: 0.2436, Precision: 0.9343, Recall: 0.8717, F1-Score: 0.8918, ROC-AUC: 0.9781
# Train Epoch 3
# Accuracy: 0.8857, Loss: 0.2715, Precision: 0.8701, Recall: 0.8857, F1-Score: 0.8748, ROC-AUC: 0.9714
# Validation Epoch 3
# Accuracy: 0.9024, Loss: 0.2298, Precision: 0.8981, Recall: 0.9024, F1-Score: 0.8896, ROC-AUC: 0.9759
# Train Epoch 4
# Accuracy: 0.8863, Loss: 0.2721, Precision: 0.8662, Recall: 0.8863, F1-Score: 0.8717, ROC-AUC: 0.9690
# Validation Epoch 4
# Accuracy: 0.9008, Loss: 0.2356, Precision: 0.8753, Recall: 0.9008, F1-Score: 0.8786, ROC-AUC: 0.9764
# Train Epoch 5
# Accuracy: 0.8975, Loss: 0.2381, Precision: 0.8771, Recall: 0.8975, F1-Score: 0.8777, ROC-AUC: 0.9747
# Validation Epoch 5
# Accuracy: 0.9106, Loss: 0.2074, Precision: 0.8970, Recall: 0.9106, F1-Score: 0.8857, ROC-AUC: 0.9797
# Train Epoch 6
# Accuracy: 0.8994, Loss: 0.2386, Precision: 0.8823, Recall: 0.8994, F1-Score: 0.8791, ROC-AUC: 0.9742
# Validation Epoch 6
# Accuracy: 0.9101, Loss: 0.2044, Precision: 0.8964, Recall: 0.9101, F1-Score: 0.8892, ROC-AUC: 0.9798
# Train Epoch 7
# Accuracy: 0.8993, Loss: 0.2348, Precision: 0.8802, Recall: 0.8993, F1-Score: 0.8796, ROC-AUC: 0.9754
# Validation Epoch 7
# Accuracy: 0.9084, Loss: 0.2060, Precision: 0.8922, Recall: 0.9084, F1-Score: 0.8856, ROC-AUC: 0.9796
# Train Epoch 8
# Accuracy: 0.8994, Loss: 0.2335, Precision: 0.8807, Recall: 0.8994, F1-Score: 0.8803, ROC-AUC: 0.9757
# Validation Epoch 8
# Accuracy: 0.9106, Loss: 0.2062, Precision: 0.8929, Recall: 0.9106, F1-Score: 0.8884, ROC-AUC: 0.9800
# Train Epoch 9
# Accuracy: 0.9011, Loss: 0.2320, Precision: 0.8827, Recall: 0.9011, F1-Score: 0.8805, ROC-AUC: 0.9760
# Validation Epoch 9
# Accuracy: 0.9123, Loss: 0.2026, Precision: 0.8935, Recall: 0.9123, F1-Score: 0.8933, ROC-AUC: 0.9800
# Train Epoch 10
# Accuracy: 0.9017, Loss: 0.2313, Precision: 0.8831, Recall: 0.9017, F1-Score: 0.8824, ROC-AUC: 0.9756
# Validation Epoch 10
# Accuracy: 0.9117, Loss: 0.2038, Precision: 0.8989, Recall: 0.9117, F1-Score: 0.8898, ROC-AUC: 0.9799
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 399   71    9    1    0    0]
#  [   0 6749   33    6    0    0]
#  [   1  400   81    5    0    0]
#  [   0  318   18  128    0    0]
#  [   0    0    0    0  407    0]
#  [   0    0    0    0    0  495]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 2, Round 2:
# [[ 1171   202    27     0     0     0]
#  [    0 20368   134     7     0     0]
#  [    1  1152   236     3     0     0]
#  [    0   989    58   323     0     0]
#  [    0     0     0     0  1202     0]
#  [    0     0     0     0     0  1490]]
# Global Model Validation Confusion Matrix for Fold 2, Round 2:
# [[  92   17    5    0    0    0]
#  [   0 1751   10    0    0    0]
#  [   0  105   16    0    0    0]
#  [   0   82    6   39    0    0]
#  [   0    0    0    0   96    0]
#  [   0    0    0    0    0  126]]
# Round 2/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2209, Accuracy: 0.9060, Precision: 0.8966, Recall: 0.9060, F1 Score: 0.8834, ROC AUC: 0.9770
# On Central Validation Data:
# Loss: 0.2222, Accuracy: 0.9041, Precision: 0.8924, Recall: 0.9041, F1 Score: 0.8817, ROC AUC: 0.9775
#
# Round 3/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8900, Loss: 0.2498, Precision: 0.8685, Recall: 0.8900, F1-Score: 0.8740, ROC-AUC: 0.9718
# Validation Epoch 1
# Accuracy: 0.9167, Loss: 0.2071, Precision: 0.9099, Recall: 0.9167, F1-Score: 0.8978, ROC-AUC: 0.9768
# Train Epoch 2
# Accuracy: 0.8898, Loss: 0.2708, Precision: 0.8717, Recall: 0.8898, F1-Score: 0.8769, ROC-AUC: 0.9702
# Validation Epoch 2
# Accuracy: 0.9062, Loss: 0.2166, Precision: 0.9266, Recall: 0.9062, F1-Score: 0.9055, ROC-AUC: 0.9763
# Train Epoch 3
# Accuracy: 0.8878, Loss: 0.2503, Precision: 0.8733, Recall: 0.8878, F1-Score: 0.8756, ROC-AUC: 0.9726
# Validation Epoch 3
# Accuracy: 0.9172, Loss: 0.2070, Precision: 0.9118, Recall: 0.9172, F1-Score: 0.8993, ROC-AUC: 0.9779
# Train Epoch 4
# Accuracy: 0.8932, Loss: 0.2457, Precision: 0.8702, Recall: 0.8932, F1-Score: 0.8742, ROC-AUC: 0.9720
# Validation Epoch 4
# Accuracy: 0.9112, Loss: 0.2066, Precision: 0.8978, Recall: 0.9112, F1-Score: 0.8992, ROC-AUC: 0.9771
# Train Epoch 5
# ...
# Accuracy: 0.9035, Loss: 0.2631, Precision: 0.9028, Recall: 0.9035, F1-Score: 0.8724, ROC-AUC: 0.9700
# Train Epoch 3
# Accuracy: 0.8938, Loss: 0.2518, Precision: 0.8729, Recall: 0.8938, F1-Score: 0.8782, ROC-AUC: 0.9721
# Validation Epoch 3
# Accuracy: 0.8953, Loss: 0.2547, Precision: 0.8855, Recall: 0.8953, F1-Score: 0.8819, ROC-AUC: 0.9722
# Train Epoch 4
# Accuracy: 0.8991, Loss: 0.2402, Precision: 0.8799, Recall: 0.8991, F1-Score: 0.8847, ROC-AUC: 0.9737
# Validation Epoch 4
# Accuracy: 0.9024, Loss: 0.2714, Precision: 0.9065, Recall: 0.9024, F1-Score: 0.8682, ROC-AUC: 0.9694
# Train Epoch 5
# Accuracy: 0.8839, Loss: 0.2757, Precision: 0.8642, Recall: 0.8839, F1-Score: 0.8713, ROC-AUC: 0.9702
# Validation Epoch 5
# Accuracy: 0.9019, Loss: 0.2659, Precision: 0.8912, Recall: 0.9019, F1-Score: 0.8784, ROC-AUC: 0.9694
# Train Epoch 6
# Accuracy: 0.9008, Loss: 0.2324, Precision: 0.8812, Recall: 0.9008, F1-Score: 0.8815, ROC-AUC: 0.9744
# Validation Epoch 6
# Accuracy: 0.9013, Loss: 0.2456, Precision: 0.8925, Recall: 0.9013, F1-Score: 0.8773, ROC-AUC: 0.9713
# Train Epoch 7
# Accuracy: 0.9028, Loss: 0.2277, Precision: 0.8847, Recall: 0.9028, F1-Score: 0.8838, ROC-AUC: 0.9762
# Validation Epoch 7
# Accuracy: 0.9035, Loss: 0.2408, Precision: 0.8923, Recall: 0.9035, F1-Score: 0.8840, ROC-AUC: 0.9715
# Train Epoch 8
# Accuracy: 0.9048, Loss: 0.2289, Precision: 0.8871, Recall: 0.9048, F1-Score: 0.8864, ROC-AUC: 0.9752
# Validation Epoch 8
# Accuracy: 0.9041, Loss: 0.2388, Precision: 0.8884, Recall: 0.9041, F1-Score: 0.8806, ROC-AUC: 0.9721
# Train Epoch 9
# Accuracy: 0.9056, Loss: 0.2229, Precision: 0.8907, Recall: 0.9056, F1-Score: 0.8878, ROC-AUC: 0.9763
# Validation Epoch 9
# Accuracy: 0.9052, Loss: 0.2379, Precision: 0.9007, Recall: 0.9052, F1-Score: 0.8762, ROC-AUC: 0.9718
# Train Epoch 10
# Accuracy: 0.9067, Loss: 0.2214, Precision: 0.8901, Recall: 0.9067, F1-Score: 0.8888, ROC-AUC: 0.9762
# Validation Epoch 10
# Accuracy: 0.9052, Loss: 0.2387, Precision: 0.8924, Recall: 0.9052, F1-Score: 0.8790, ROC-AUC: 0.9722
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 389   73    6    0    0    0]
#  [   0 6829   13    3    2    0]
#  [   0  380   44    4    3    0]
#  [   0  349    9  103    0    0]
#  [   0    0    0    0  413    0]
#  [   0    0    0    0    0  501]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8879, Loss: 0.2692, Precision: 0.8646, Recall: 0.8879, F1-Score: 0.8724, ROC-AUC: 0.9696
# Validation Epoch 1
# Accuracy: 0.8684, Loss: 0.2751, Precision: 0.9149, Recall: 0.8684, F1-Score: 0.8748, ROC-AUC: 0.9728
# Train Epoch 2
# Accuracy: 0.8868, Loss: 0.2607, Precision: 0.8715, Recall: 0.8868, F1-Score: 0.8741, ROC-AUC: 0.9707
# Validation Epoch 2
# Accuracy: 0.8865, Loss: 0.2549, Precision: 0.8806, Recall: 0.8865, F1-Score: 0.8720, ROC-AUC: 0.9742
# Train Epoch 3
# Accuracy: 0.8912, Loss: 0.2538, Precision: 0.8729, Recall: 0.8912, F1-Score: 0.8762, ROC-AUC: 0.9710
# Validation Epoch 3
# Accuracy: 0.8887, Loss: 0.2569, Precision: 0.8793, Recall: 0.8887, F1-Score: 0.8694, ROC-AUC: 0.9751
# Train Epoch 4
# Accuracy: 0.8968, Loss: 0.2398, Precision: 0.8769, Recall: 0.8968, F1-Score: 0.8820, ROC-AUC: 0.9742
# Validation Epoch 4
# Accuracy: 0.8980, Loss: 0.2485, Precision: 0.8797, Recall: 0.8980, F1-Score: 0.8777, ROC-AUC: 0.9741
# Train Epoch 5
# Accuracy: 0.8963, Loss: 0.2420, Precision: 0.8783, Recall: 0.8963, F1-Score: 0.8837, ROC-AUC: 0.9735
# Validation Epoch 5
# Accuracy: 0.8750, Loss: 0.2557, Precision: 0.8950, Recall: 0.8750, F1-Score: 0.8836, ROC-AUC: 0.9740
# Train Epoch 6
# Accuracy: 0.8950, Loss: 0.2557, Precision: 0.8777, Recall: 0.8950, F1-Score: 0.8823, ROC-AUC: 0.9734
# Validation Epoch 6
# Accuracy: 0.8969, Loss: 0.2497, Precision: 0.8792, Recall: 0.8969, F1-Score: 0.8825, ROC-AUC: 0.9755
# Train Epoch 7
# Accuracy: 0.8894, Loss: 0.2582, Precision: 0.8732, Recall: 0.8894, F1-Score: 0.8785, ROC-AUC: 0.9714
# Validation Epoch 7
# Accuracy: 0.8953, Loss: 0.2559, Precision: 0.8883, Recall: 0.8953, F1-Score: 0.8652, ROC-AUC: 0.9758
# Train Epoch 8
# Accuracy: 0.9041, Loss: 0.2259, Precision: 0.8859, Recall: 0.9041, F1-Score: 0.8858, ROC-AUC: 0.9763
# Validation Epoch 8
# Accuracy: 0.8947, Loss: 0.2404, Precision: 0.8828, Recall: 0.8947, F1-Score: 0.8731, ROC-AUC: 0.9769
# Train Epoch 9
# Accuracy: 0.9050, Loss: 0.2223, Precision: 0.8884, Recall: 0.9050, F1-Score: 0.8879, ROC-AUC: 0.9765
# Validation Epoch 9
# Accuracy: 0.8936, Loss: 0.2442, Precision: 0.8793, Recall: 0.8936, F1-Score: 0.8704, ROC-AUC: 0.9769
# Train Epoch 10
# Accuracy: 0.9052, Loss: 0.2247, Precision: 0.8880, Recall: 0.9052, F1-Score: 0.8887, ROC-AUC: 0.9761
# Validation Epoch 10
# Accuracy: 0.8958, Loss: 0.2413, Precision: 0.8862, Recall: 0.8958, F1-Score: 0.8680, ROC-AUC: 0.9772
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 400   74    6    0    0    0]
#  [   1 6769   15    3    0    0]
#  [   2  436   45    4    0    0]
#  [   0  332    4  128    0    0]
#  [   0    0    0    0  407    0]
#  [   0    0    0    0    0  495]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 5, Round 2:
# [[ 1171   220     9     0     0     0]
#  [    0 20409    95     3     2     0]
#  [    1  1225   163     0     3     0]
#  [    0  1042    24   304     0     0]
#  [    0     0     0     0  1202     0]
#  [    0     0     0     0     0  1490]]
# Global Model Validation Confusion Matrix for Fold 5, Round 2:
# [[ 108   17    1    0    0    0]
#  [   0 1736    5    1    0    0]
#  [   0  103    9    0    1    0]
#  [   0   83    3   24    0    0]
#  [   0    0    0    0  116    0]
#  [   0    0    0    0    0  138]]
# Round 2/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2252, Accuracy: 0.9041, Precision: 0.8955, Recall: 0.9041, F1 Score: 0.8777, ROC AUC: 0.9770
# On Central Validation Data:
# Loss: 0.2204, Accuracy: 0.9087, Precision: 0.8958, Recall: 0.9087, F1 Score: 0.8817, ROC AUC: 0.9770
#
# Round 3/3
#
# Training on Client 1
# Client 1: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8919, Loss: 0.2545, Precision: 0.8733, Recall: 0.8919, F1-Score: 0.8778, ROC-AUC: 0.9722
# Validation Epoch 1
# Accuracy: 0.8712, Loss: 0.2636, Precision: 0.9409, Recall: 0.8712, F1-Score: 0.8860, ROC-AUC: 0.9746
# Train Epoch 2
# Accuracy: 0.8926, Loss: 0.2500, Precision: 0.8756, Recall: 0.8926, F1-Score: 0.8792, ROC-AUC: 0.9723
# Validation Epoch 2
# Accuracy: 0.9052, Loss: 0.2225, Precision: 0.8873, Recall: 0.9052, F1-Score: 0.8788, ROC-AUC: 0.9750
# Train Epoch 3
# Accuracy: 0.8948, Loss: 0.2375, Precision: 0.8727, Recall: 0.8948, F1-Score: 0.8780, ROC-AUC: 0.9729
# Validation Epoch 3
# Accuracy: 0.8898, Loss: 0.2261, Precision: 0.8838, Recall: 0.8898, F1-Score: 0.8844, ROC-AUC: 0.9753
# Train Epoch 4
# Accuracy: 0.8975, Loss: 0.2418, Precision: 0.8790, Recall: 0.8975, F1-Score: 0.8835, ROC-AUC: 0.9732
# Validation Epoch 4
# Accuracy: 0.8893, Loss: 0.2338, Precision: 0.8947, Recall: 0.8893, F1-Score: 0.8787, ROC-AUC: 0.9741
# Train Epoch 5
# Accuracy: 0.8912, Loss: 0.2515, Precision: 0.8715, Recall: 0.8912, F1-Score: 0.8744, ROC-AUC: 0.9720
# Validation Epoch 5
# Accuracy: 0.8849, Loss: 0.2233, Precision: 0.8990, Recall: 0.8849, F1-Score: 0.8871, ROC-AUC: 0.9752
# Train Epoch 6
# Accuracy: 0.8997, Loss: 0.2247, Precision: 0.8850, Recall: 0.8997, F1-Score: 0.8816, ROC-AUC: 0.9754
# Validation Epoch 6
# Accuracy: 0.9062, Loss: 0.2180, Precision: 0.8940, Recall: 0.9062, F1-Score: 0.8835, ROC-AUC: 0.9746
# Train Epoch 7
# Accuracy: 0.9037, Loss: 0.2219, Precision: 0.8899, Recall: 0.9037, F1-Score: 0.8850, ROC-AUC: 0.9762
# Validation Epoch 7
# Accuracy: 0.8986, Loss: 0.2184, Precision: 0.8994, Recall: 0.8986, F1-Score: 0.8864, ROC-AUC: 0.9757
# Train Epoch 8
# Accuracy: 0.9012, Loss: 0.2196, Precision: 0.8849, Recall: 0.9012, F1-Score: 0.8818, ROC-AUC: 0.9772
# Validation Epoch 8
# Accuracy: 0.9046, Loss: 0.2186, Precision: 0.8998, Recall: 0.9046, F1-Score: 0.8882, ROC-AUC: 0.9750
# Train Epoch 9
# Accuracy: 0.9019, Loss: 0.2227, Precision: 0.8853, Recall: 0.9019, F1-Score: 0.8835, ROC-AUC: 0.9774
# Validation Epoch 9
# Accuracy: 0.9035, Loss: 0.2206, Precision: 0.8971, Recall: 0.9035, F1-Score: 0.8860, ROC-AUC: 0.9750
# Train Epoch 10
# Accuracy: 0.9061, Loss: 0.2167, Precision: 0.8934, Recall: 0.9061, F1-Score: 0.8870, ROC-AUC: 0.9775
# Validation Epoch 10
# Accuracy: 0.9062, Loss: 0.2193, Precision: 0.8941, Recall: 0.9062, F1-Score: 0.8836, ROC-AUC: 0.9750
# All metrics saved into CSV file.
# Client 1: Finished training. Returning model weights.
# Client 1 Combined Training and Validation Confusion Matrix:
# [[ 383   62    7    0    0    0]
#  [   0 6819   52    3    0    0]
#  [   0  381   90    3    0    0]
#  [   0  319   20  106    0    0]
#  [   0    0    0    0  382    0]
#  [   0    0    0    0    0  494]]
#
# Training on Client 2
# Client 2: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8998, Loss: 0.2378, Precision: 0.8817, Recall: 0.8998, F1-Score: 0.8855, ROC-AUC: 0.9730
# Validation Epoch 1
# Accuracy: 0.8920, Loss: 0.2595, Precision: 0.8706, Recall: 0.8920, F1-Score: 0.8730, ROC-AUC: 0.9727
# Train Epoch 2
# Accuracy: 0.8950, Loss: 0.2430, Precision: 0.8763, Recall: 0.8950, F1-Score: 0.8826, ROC-AUC: 0.9727
# Validation Epoch 2
# Accuracy: 0.8882, Loss: 0.2548, Precision: 0.9003, Recall: 0.8882, F1-Score: 0.8787, ROC-AUC: 0.9702
# Train Epoch 3
# Accuracy: 0.8994, Loss: 0.2308, Precision: 0.8808, Recall: 0.8994, F1-Score: 0.8859, ROC-AUC: 0.9747
# Validation Epoch 3
# Accuracy: 0.9024, Loss: 0.2478, Precision: 0.8863, Recall: 0.9024, F1-Score: 0.8693, ROC-AUC: 0.9728
# Train Epoch 4
# Accuracy: 0.9013, Loss: 0.2318, Precision: 0.8847, Recall: 0.9013, F1-Score: 0.8875, ROC-AUC: 0.9741
# Validation Epoch 4
# Accuracy: 0.9035, Loss: 0.2391, Precision: 0.8895, Recall: 0.9035, F1-Score: 0.8772, ROC-AUC: 0.9721
# Train Epoch 5
# Accuracy: 0.9013, Loss: 0.2309, Precision: 0.8841, Recall: 0.9013, F1-Score: 0.8869, ROC-AUC: 0.9755
# Validation Epoch 5
# Accuracy: 0.8953, Loss: 0.2462, Precision: 0.8936, Recall: 0.8953, F1-Score: 0.8847, ROC-AUC: 0.9708
# Train Epoch 6
# Accuracy: 0.9020, Loss: 0.2341, Precision: 0.8836, Recall: 0.9020, F1-Score: 0.8880, ROC-AUC: 0.9751
# Validation Epoch 6
# Accuracy: 0.8728, Loss: 0.2590, Precision: 0.9266, Recall: 0.8728, F1-Score: 0.8829, ROC-AUC: 0.9726
# Train Epoch 7
# Accuracy: 0.8963, Loss: 0.2431, Precision: 0.8812, Recall: 0.8963, F1-Score: 0.8841, ROC-AUC: 0.9734
# Validation Epoch 7
# Accuracy: 0.9052, Loss: 0.2336, Precision: 0.8874, Recall: 0.9052, F1-Score: 0.8798, ROC-AUC: 0.9741
# Train Epoch 8
# Accuracy: 0.9002, Loss: 0.2384, Precision: 0.8840, Recall: 0.9002, F1-Score: 0.8856, ROC-AUC: 0.9741
# Validation Epoch 8
# Accuracy: 0.8531, Loss: 0.6885, Precision: 0.8567, Recall: 0.8531, F1-Score: 0.8429, ROC-AUC: 0.9564
# Train Epoch 9
# Accuracy: 0.9031, Loss: 0.2315, Precision: 0.8849, Recall: 0.9031, F1-Score: 0.8886, ROC-AUC: 0.9751
# Validation Epoch 9
# Accuracy: 0.9057, Loss: 0.2429, Precision: 0.9002, Recall: 0.9057, F1-Score: 0.8881, ROC-AUC: 0.9734
# Train Epoch 10
# Accuracy: 0.9001, Loss: 0.2327, Precision: 0.8848, Recall: 0.9001, F1-Score: 0.8868, ROC-AUC: 0.9746
# Validation Epoch 10
# Accuracy: 0.9046, Loss: 0.2402, Precision: 0.8827, Recall: 0.9046, F1-Score: 0.8772, ROC-AUC: 0.9726
# All metrics saved into CSV file.
# Client 2: Finished training. Returning model weights.
# Client 2 Combined Training and Validation Confusion Matrix:
# [[ 389   74    2    3    0    0]
#  [   0 6829   11    7    0    0]
#  [   0  381   35   15    0    0]
#  [   0  340    4  117    0    0]
#  [   0    0    0    0  413    0]
#  [   0    0    0    0    0  501]]
#
# Training on Client 3
# Client 3: Starting training with 229 batches...
# Train Epoch 1
# Accuracy: 0.8900, Loss: 0.2447, Precision: 0.8675, Recall: 0.8900, F1-Score: 0.8733, ROC-AUC: 0.9722
# Validation Epoch 1
# Accuracy: 0.8783, Loss: 0.2596, Precision: 0.9189, Recall: 0.8783, F1-Score: 0.8846, ROC-AUC: 0.9736
# Train Epoch 2
# Accuracy: 0.8980, Loss: 0.2441, Precision: 0.8791, Recall: 0.8980, F1-Score: 0.8833, ROC-AUC: 0.9736
# Validation Epoch 2
# Accuracy: 0.8876, Loss: 0.2484, Precision: 0.8744, Recall: 0.8876, F1-Score: 0.8774, ROC-AUC: 0.9738
# Train Epoch 3
# Accuracy: 0.8948, Loss: 0.2473, Precision: 0.8758, Recall: 0.8948, F1-Score: 0.8803, ROC-AUC: 0.9726
# Validation Epoch 3
# Accuracy: 0.8739, Loss: 0.2550, Precision: 0.9220, Recall: 0.8739, F1-Score: 0.8824, ROC-AUC: 0.9739
# Train Epoch 4
# Accuracy: 0.8990, Loss: 0.2392, Precision: 0.8817, Recall: 0.8990, F1-Score: 0.8847, ROC-AUC: 0.9730
# Validation Epoch 4
# Accuracy: 0.8925, Loss: 0.2408, Precision: 0.8795, Recall: 0.8925, F1-Score: 0.8794, ROC-AUC: 0.9767
# Train Epoch 5
# Accuracy: 0.8995, Loss: 0.2334, Precision: 0.8822, Recall: 0.8995, F1-Score: 0.8862, ROC-AUC: 0.9762
# Validation Epoch 5
# Accuracy: 0.8799, Loss: 0.2757, Precision: 0.9181, Recall: 0.8799, F1-Score: 0.8818, ROC-AUC: 0.9730
# Train Epoch 6
# Accuracy: 0.8923, Loss: 0.2438, Precision: 0.8760, Recall: 0.8923, F1-Score: 0.8792, ROC-AUC: 0.9734
# Validation Epoch 6
# Accuracy: 0.8958, Loss: 0.2532, Precision: 0.8824, Recall: 0.8958, F1-Score: 0.8711, ROC-AUC: 0.9757
# Train Epoch 7
# Accuracy: 0.8995, Loss: 0.2338, Precision: 0.8848, Recall: 0.8995, F1-Score: 0.8878, ROC-AUC: 0.9750
# Validation Epoch 7
# Accuracy: 0.8772, Loss: 0.2666, Precision: 0.9164, Recall: 0.8772, F1-Score: 0.8918, ROC-AUC: 0.9759
# Train Epoch 8
# Accuracy: 0.8924, Loss: 0.2442, Precision: 0.8756, Recall: 0.8924, F1-Score: 0.8795, ROC-AUC: 0.9736
# Validation Epoch 8
# Accuracy: 0.8969, Loss: 0.2399, Precision: 0.8771, Recall: 0.8969, F1-Score: 0.8759, ROC-AUC: 0.9763
# Train Epoch 9
# Accuracy: 0.8991, Loss: 0.2443, Precision: 0.8824, Recall: 0.8991, F1-Score: 0.8863, ROC-AUC: 0.9754
# Validation Epoch 9
# Accuracy: 0.8997, Loss: 0.2386, Precision: 0.8821, Recall: 0.8997, F1-Score: 0.8815, ROC-AUC: 0.9764
# Train Epoch 10
# Accuracy: 0.8994, Loss: 0.2371, Precision: 0.8796, Recall: 0.8994, F1-Score: 0.8837, ROC-AUC: 0.9744
# Validation Epoch 10
# Accuracy: 0.8953, Loss: 0.2503, Precision: 0.8894, Recall: 0.8953, F1-Score: 0.8757, ROC-AUC: 0.9751
# All metrics saved into CSV file.
# Client 3: Finished training. Returning model weights.
# Client 3 Combined Training and Validation Confusion Matrix:
# [[ 400   68   12    0    0    0]
#  [   0 6729   58    1    0    0]
#  [   1  381  104    1    0    0]
#  [   0  316   39  109    0    0]
#  [   0    0    0    0  407    0]
#  [   0    0    0    0    0  495]]
# Performing Federated Averaging to update the global model...
# Global model updated.
# Global Model Confusion Matrix on Combined Client Data for Fold 5, Round 3:
# [[ 1171   209    20     0     0     0]
#  [    0 20395   112     2     0     0]
#  [    0  1171   218     2     1     0]
#  [    0  1006    52   312     0     0]
#  [    0     0     0     0  1202     0]
#  [    0     0     0     0     0  1490]]
# Global Model Validation Confusion Matrix for Fold 5, Round 3:
# [[ 108   17    1    0    0    0]
#  [   0 1729   13    0    0    0]
#  [   0  100   13    0    0    0]
#  [   0   82    4   24    0    0]
#  [   0    0    0    0  116    0]
#  [   0    0    0    0    0  138]]
# Round 3/3, Global Model Metrics:
# On Combined Client Data (Train):
# Loss: 0.2203, Accuracy: 0.9059, Precision: 0.8975, Recall: 0.9059, F1 Score: 0.8821, ROC AUC: 0.9777
# On Central Validation Data:
# Loss: 0.2173, Accuracy: 0.9075, Precision: 0.8953, Recall: 0.9075, F1 Score: 0.8834, ROC AUC: 0.9773
# Global model metrics over rounds saved into CSV file.
# Final Global Model Confusion Matrix on Combined Client Data for Fold 5:
# [[ 1171   209    20     0     0     0]
#  [    0 20395   112     2     0     0]
#  [    0  1171   218     2     1     0]
#  [    0  1006    52   312     0     0]
#  [    0     0     0     0  1202     0]
#  [    0     0     0     0     0  1490]]
# Final Global Model Validation Confusion Matrix for Fold 5:
# [[ 108   17    1    0    0    0]
#  [   0 1729   13    0    0    0]
#  [   0  100   13    0    0    0]
#  [   0   82    4   24    0    0]
#  [   0    0    0    0  116    0]
#  [   0    0    0    0    0  138]]
# K-Fold cross-validation metrics saved into CSV file.

# %%
def measure_efficiency(model, train_loader, test_loader, device):
    metrics = {}
    return metrics
print("Function `measure_efficiency` defined.")
# Out:
# Function `measure_efficiency` defined.

# %%
def measure_efficiency(model, train_loader, test_loader, device):
    metrics = {}

    # 1. Calculate total number of learnable parameters
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    metrics['Total Parameters'] = total_params

    # 2. Estimate model's memory usage in bytes (assuming Float32 = 4 bytes per parameter)
    model_size_bytes = total_params * 4

    # 3. Convert memory usage to megabytes (MB)
    model_size_mb = model_size_bytes / (1024 * 1024)
    metrics['Model Size (MB)'] = model_size_mb

    return metrics
print("Function `measure_efficiency` updated with model size calculation.")
# Out:
# Function `measure_efficiency` updated with model size calculation.

# %%
def measure_efficiency(model, train_loader, test_loader, device):
    metrics = {}

    # 1. Calculate total number of learnable parameters
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    metrics['Total Parameters'] = total_params

    # 2. Estimate model's memory usage in bytes (assuming Float32 = 4 bytes per parameter)
    model_size_bytes = total_params * 4

    # 3. Convert memory usage to megabytes (MB)
    model_size_mb = model_size_bytes / (1024 * 1024)
    metrics['Model Size (MB)'] = model_size_mb

    # Move model to device
    model.to(device)

    # Measure Peak VRAM Usage
    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats(device=device)

        # Get one batch of data for VRAM measurement
        # Ensure train_loader is not empty and has iter()
        try:
            data_batch, labels_batch = next(iter(train_loader))
        except StopIteration:
            print("Train loader is empty, cannot measure peak VRAM.")
            metrics['Peak VRAM (MB)'] = 'N/A'
            return metrics # Exit if loader is empty

        data_batch = data_batch.to(device)
        labels_batch = labels_batch.to(device)

        model.train() # Set model to training mode

        # Forward pass
        outputs = model(data_batch)

        # Dummy loss for backward pass
        # If outputs is a single value, use it directly for loss calculation
        # Otherwise, calculate a simple loss that forces gradients
        if outputs.numel() == 1:
            loss = outputs.mean() # Simple loss for single-element output
        else:
            # Use a dummy target to calculate loss if output is multi-dimensional
            # This is just to trigger a backward pass for VRAM measurement
            dummy_target = torch.randint(0, outputs.size(1), (outputs.size(0),), device=device)
            loss_fn = nn.CrossEntropyLoss() # A common loss function
            loss = loss_fn(outputs, dummy_target)

        loss.backward() # Backward pass

        # Record peak memory allocated
        peak_vram_bytes = torch.cuda.max_memory_allocated(device=device)
        peak_vram_mb = peak_vram_bytes / (1024 * 1024)
        metrics['Peak VRAM (MB)'] = peak_vram_mb
    else:
        metrics['Peak VRAM (MB)'] = 'N/A'

    return metrics
print("Function `measure_efficiency` updated with model size and peak VRAM calculation.")
# Out:
# Function `measure_efficiency` updated with model size and peak VRAM calculation.

# %%
import time
import torch.optim as optim

def measure_efficiency(model, train_loader, test_loader, device):
    metrics = {}

    # 1. Calculate total number of learnable parameters
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    metrics['Total Parameters'] = total_params

    # 2. Estimate model's memory usage in bytes (assuming Float32 = 4 bytes per parameter)
    model_size_bytes = total_params * 4

    # 3. Convert memory usage to megabytes (MB)
    model_size_mb = model_size_bytes / (1024 * 1024)
    metrics['Model Size (MB)'] = model_size_mb

    # Move model to device
    model.to(device)

    # Measure Peak VRAM Usage
    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats(device=device)

        # Get one batch of data for VRAM measurement
        try:
            data_batch, labels_batch = next(iter(train_loader))
        except StopIteration:
            print("Train loader is empty, cannot measure peak VRAM.")
            metrics['Peak VRAM (MB)'] = 'N/A'
            return metrics # Exit if loader is empty

        data_batch = data_batch.to(device)
        labels_batch = labels_batch.to(device)

        model.train() # Set model to training mode

        # Forward pass
        outputs = model(data_batch)

        # Dummy loss for backward pass
        if outputs.numel() == 1:
            loss = outputs.mean() # Simple loss for single-element output
        else:
            dummy_target = torch.randint(0, outputs.size(1), (outputs.size(0),), device=device)
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(outputs, dummy_target)

        loss.backward() # Backward pass

        peak_vram_bytes = torch.cuda.max_memory_allocated(device=device)
        peak_vram_mb = peak_vram_bytes / (1024 * 1024)
        metrics['Peak VRAM (MB)'] = peak_vram_mb
    else:
        metrics['Peak VRAM (MB)'] = 'N/A'

    # Measure Training Speed
    model.train() # Ensure model is in training mode
    optimizer = optim.SGD(model.parameters(), lr=0.01) # Dummy optimizer for measurement
    criterion = nn.CrossEntropyLoss() # Dummy loss function

    start_time = time.time()
    total_samples_processed = 0

    try:
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            total_samples_processed += len(data)
    except StopIteration:
        print("Train loader is empty, cannot measure training speed.")
        metrics['Time per Epoch (s)'] = 'N/A'
        metrics['Samples per Second'] = 'N/A'
        return metrics # Exit if loader is empty

    end_time = time.time()
    time_per_epoch = end_time - start_time
    samples_per_second = total_samples_processed / time_per_epoch if time_per_epoch > 0 else 0

    metrics['Time per Epoch (s)'] = time_per_epoch
    metrics['Samples per Second'] = samples_per_second

    return metrics
print("Function `measure_efficiency` updated with training speed calculation.")
# Out:
# Function `measure_efficiency` updated with training speed calculation.

# %%
import time
import torch.optim as optim

def measure_efficiency(model, train_loader, test_loader, device):
    metrics = {}

    # 1. Calculate total number of learnable parameters
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    metrics['Total Parameters'] = total_params

    # 2. Estimate model's memory usage in bytes (assuming Float32 = 4 bytes per parameter)
    model_size_bytes = total_params * 4

    # 3. Convert memory usage to megabytes (MB)
    model_size_mb = model_size_bytes / (1024 * 1024)
    metrics['Model Size (MB)'] = model_size_mb

    # Move model to device
    model.to(device)

    # Measure Peak VRAM Usage
    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats(device=device)

        # Get one batch of data for VRAM measurement
        try:
            data_batch, labels_batch = next(iter(train_loader))
        except StopIteration:
            print("Train loader is empty, cannot measure peak VRAM.")
            metrics['Peak VRAM (MB)'] = 'N/A'
            return metrics # Exit if loader is empty

        data_batch = data_batch.to(device)
        labels_batch = labels_batch.to(device)

        model.train() # Set model to training mode

        # Forward pass
        outputs = model(data_batch)

        # Dummy loss for backward pass
        if outputs.numel() == 1:
            loss = outputs.mean() # Simple loss for single-element output
        else:
            dummy_target = torch.randint(0, outputs.size(1), (outputs.size(0),), device=device)
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(outputs, dummy_target)

        loss.backward() # Backward pass

        peak_vram_bytes = torch.cuda.max_memory_allocated(device=device)
        peak_vram_mb = peak_vram_bytes / (1024 * 1024)
        metrics['Peak VRAM (MB)'] = peak_vram_mb
    else:
        metrics['Peak VRAM (MB)'] = 'N/A'

    # Measure Training Speed
    model.train() # Ensure model is in training mode
    optimizer = optim.SGD(model.parameters(), lr=0.01) # Dummy optimizer for measurement
    criterion = nn.CrossEntropyLoss() # Dummy loss function

    start_time_train = time.time()
    total_samples_processed = 0

    try:
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            total_samples_processed += len(data)
    except StopIteration:
        print("Train loader is empty, cannot measure training speed.")
        metrics['Time per Epoch (s)'] = 'N/A'
        metrics['Samples per Second'] = 'N/A'
        return metrics # Exit if loader is empty

    end_time_train = time.time()
    time_per_epoch = end_time_train - start_time_train
    samples_per_second = total_samples_processed / time_per_epoch if time_per_epoch > 0 else 0

    metrics['Time per Epoch (s)'] = time_per_epoch
    metrics['Samples per Second'] = samples_per_second

    # Measure Inference Latency
    model.eval() # Set model to evaluation mode
    total_inference_time = 0.0
    total_samples_inferred = 0

    with torch.no_grad(): # Disable gradient calculations
        try:
            for data, _ in test_loader:
                data = data.to(device)
                start_time_batch = time.time()
                _ = model(data)
                end_time_batch = time.time()
                total_inference_time += (end_time_batch - start_time_batch)
                total_samples_inferred += len(data)
        except StopIteration:
            print("Test loader is empty, cannot measure inference latency.")
            metrics['Average Inference Latency (ms/sample)'] = 'N/A'
            return metrics # Exit if loader is empty

    if total_samples_inferred > 0:
        average_inference_latency_s = total_inference_time / total_samples_inferred
        average_inference_latency_ms = average_inference_latency_s * 1000 # Convert to milliseconds
        metrics['Average Inference Latency (ms/sample)'] = average_inference_latency_ms
    else:
        metrics['Average Inference Latency (ms/sample)'] = 'N/A'

    return metrics
print("Function `measure_efficiency` updated with inference latency calculation.")
# Out:
# Function `measure_efficiency` updated with inference latency calculation.

# %%
import time
import torch.optim as optim
import pandas as pd
import torch # Ensure torch is imported
import torch.cuda # Ensure torch.cuda is available

def measure_efficiency(model, train_loader, test_loader, device):
    # Initialize all requested metrics with None, which will be 'N/A' if not computed
    metrics = {
        'Model Size (MB)': None,
        'Peak Memory Usage (MB)': None,
        'Training Throughput (samples/sec)': None,
        'Inference Latency (ms/sample)': None
    }

    # 1. Calculate Model Size (MB)
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    model_size_bytes = total_params * 4 # Assuming Float32 = 4 bytes per parameter
    model_size_mb = model_size_bytes / (1024 * 1024)
    metrics['Model Size (MB)'] = model_size_mb

    # Move model to device
    model.to(device)

    # Measure Peak Memory Usage (MB)
    if torch.cuda.is_available():
        torch.cuda.reset_peak_memory_stats(device=device)

        try:
            data_batch, labels_batch = next(iter(train_loader))
        except StopIteration:
            print("Train loader is empty, cannot measure peak VRAM.")
            metrics['Peak Memory Usage (MB)'] = 'N/A'
            efficiency_df = pd.DataFrame([metrics])
            return efficiency_df

        data_batch = data_batch.to(device)
        labels_batch = labels_batch.to(device)

        model.train() # Set model to training mode

        outputs = model(data_batch)

        if outputs.numel() == 1:
            loss = outputs.mean()
        else:
            dummy_target = torch.randint(0, outputs.size(1), (outputs.size(0),), device=device)
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(outputs, dummy_target)

        loss.backward()

        peak_vram_bytes = torch.cuda.max_memory_allocated(device=device)
        peak_vram_mb = peak_vram_bytes / (1024 * 1024)
        metrics['Peak Memory Usage (MB)'] = peak_vram_mb
    else:
        metrics['Peak Memory Usage (MB)'] = 'N/A'

    # Measure Training Throughput (samples/sec)
    model.train() # Ensure model is in training mode
    optimizer = optim.SGD(model.parameters(), lr=0.01) # Dummy optimizer for measurement
    criterion = nn.CrossEntropyLoss() # Dummy loss function

    start_time_train = time.time()
    total_samples_processed = 0

    try:
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            total_samples_processed += len(data)
    except StopIteration:
        print("Train loader is empty, cannot measure training throughput.")
        metrics['Training Throughput (samples/sec)'] = 'N/A'
        efficiency_df = pd.DataFrame([metrics])
        return efficiency_df

    end_time_train = time.time()
    time_per_epoch = end_time_train - start_time_train
    samples_per_second = total_samples_processed / time_per_epoch if time_per_epoch > 0 else 0

    metrics['Training Throughput (samples/sec)'] = samples_per_second

    # Measure Inference Latency (ms/sample)
    model.eval() # Set model to evaluation mode
    total_inference_time_ms = 0.0 # Will store time in milliseconds
    total_samples_inferred = 0

    with torch.no_grad(): # Disable gradient calculations
        try:
            # Warm-up (if CUDA is available and test_loader is not empty)
            if torch.cuda.is_available() and len(test_loader) > 0:
                for _ in range(min(len(test_loader), 1)): # Warm up with at least 1 batch
                    data, _ = next(iter(test_loader))
                    data = data.to(device)
                    _ = model(data)
                torch.cuda.synchronize() # Wait for warm-up to finish

            # Setup CUDA events for accurate timing if GPU is used
            if torch.cuda.is_available():
                start_event = torch.cuda.Event(enable_timing=True)
                end_event = torch.cuda.Event(enable_timing=True)
            else:
                start_event, end_event = None, None # Placeholder for CPU timing

            for data, _ in test_loader:
                data = data.to(device)

                if torch.cuda.is_available():
                    start_event.record()
                    _ = model(data)
                    end_event.record()
                    torch.cuda.synchronize() # Wait for GPU to finish
                    total_inference_time_ms += start_event.elapsed_time(end_event) # Time in ms
                else:
                    start_time_batch = time.time()
                    _ = model(data)
                    end_time_batch = time.time()
                    total_inference_time_ms += (end_time_batch - start_time_batch) * 1000 # Convert to ms

                total_samples_inferred += len(data)

        except StopIteration:
            print("Test loader is empty, cannot measure inference latency.")
            metrics['Inference Latency (ms/sample)'] = 'N/A'
            efficiency_df = pd.DataFrame([metrics])
            return efficiency_df

    if total_samples_inferred > 0:
        average_inference_latency_ms = total_inference_time_ms / total_samples_inferred
        metrics['Inference Latency (ms/sample)'] = average_inference_latency_ms
    else:
        metrics['Inference Latency (ms/sample)'] = 'N/A'

    # Convert metrics dictionary to Pandas DataFrame
    efficiency_df = pd.DataFrame([metrics])

    return efficiency_df
print("Function `measure_efficiency` updated to calculate the specified four metrics.")
# Out:
# Function `measure_efficiency` updated to calculate the specified four metrics.

# %%
#Terdapat perbedaan nilai efisiensi dengan di laporan, karena kode ini saya jalankan kembali
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
import torch # Import torch

# Explicitly define num_continuous and output_dim based on previous notebook state
# From cell KMi37A4raPto, bin_data has 20 feature columns.
num_continuous = 20
# From cell mlhhPynmB4GD, np.unique(y_central) shows 6 unique classes.
output_dim = 6

# 1. Instantiate the InformerModel using the hyperparameters defined in cell Fhh1606kB4GD
model = InformerModel(
    num_continuous=num_continuous,
    d_model=dim,
    d_ff=dim * 4, # d_ff was 4x d_model in the original InformerEncoderLayer definition
    num_layers=depth,
    n_heads=heads,
    output_dim=output_dim,
    dropout=attn_dropout
)

# 2. Create dummy data
batch_size = 32
num_samples = 100 # Total samples for dummy dataset

X_dummy = torch.randn(num_samples, num_continuous)
y_dummy = torch.randint(0, output_dim, (num_samples,))

# 3. Create TensorDataset instances
train_dataset = TensorDataset(X_dummy, y_dummy)
test_dataset = TensorDataset(X_dummy, y_dummy)

# 4. Create DataLoader instances
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 5. Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# 6. Call the measure_efficiency function
efficiency_df = measure_efficiency(model, train_loader, test_loader, device)

# 7. Print the resulting DataFrame
print("\n--- Efficiency Metrics (InformerModel) ---")
print(efficiency_df)
# Out:
# Using device: cuda
#
# --- Efficiency Metrics (InformerModel) ---
#    Model Size (MB)  Peak Memory Usage (MB)  Training Throughput (samples/sec)  \
# 0          3.15139               61.171387                        2156.221693
#
#    Inference Latency (ms/sample)
# 0                        0.15495
